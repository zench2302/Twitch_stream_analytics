# %% [markdown]
# # Environment setup

# %%
# !pip install irc
# Out:
# Collecting irc
#   Downloading irc-20.5.0-py3-none-any.whl.metadata (10 kB)
# Collecting jaraco.collections (from irc)
#   Downloading jaraco.collections-5.1.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting jaraco.text>=3.14 (from irc)
#   Downloading jaraco.text-4.0.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting jaraco.logging (from irc)
#   Downloading jaraco.logging-3.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting jaraco.functools>=1.20 (from irc)
#   Downloading jaraco.functools-4.1.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting jaraco.stream (from irc)
#   Downloading jaraco.stream-3.0.4-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from irc) (2025.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from irc) (10.6.0)
# Collecting tempora>=1.6 (from irc)
#   Downloading tempora-5.8.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from irc) (6.5.2)
# Collecting jaraco.context>=4.1 (from jaraco.text>=3.14->irc)
#   Downloading jaraco.context-6.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting autocommand (from jaraco.text>=3.14->irc)
#   Downloading autocommand-2.2.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from tempora>=1.6->irc) (2.8.2)
# Collecting backports.tarfile (from jaraco.context>=4.1->jaraco.text>=3.14->irc)
#   Downloading backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->tempora>=1.6->irc) (1.17.0)
# Downloading irc-20.5.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 2.9 MB/s eta 0:00:00
# Downloading jaraco.functools-4.1.0-py3-none-any.whl (10 kB)
# Downloading jaraco.text-4.0.0-py3-none-any.whl (11 kB)
# Downloading tempora-5.8.0-py3-none-any.whl (14 kB)
# Downloading jaraco.collections-5.1.0-py3-none-any.whl (11 kB)
# Downloading jaraco.logging-3.3.0-py3-none-any.whl (4.8 kB)
# Downloading jaraco.stream-3.0.4-py3-none-any.whl (6.1 kB)
# Downloading jaraco.context-6.0.1-py3-none-any.whl (6.8 kB)
# Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Downloading backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Installing collected packages: jaraco.stream, jaraco.functools, backports.tarfile, autocommand, tempora, jaraco.context, jaraco.text, jaraco.logging, jaraco.collections, irc
# Successfully installed autocommand-2.2.2 backports.tarfile-1.2.0 irc-20.5.0 jaraco.collections-5.1.0 jaraco.context-6.0.1 jaraco.functools-4.1.0 jaraco.logging-3.3.0 jaraco.stream-3.0.4 jaraco.text-4.0.0 tempora-5.8.0

# %%
import socket
import re
import requests
import time
import os
from datetime import datetime
from threading import Thread, Lock
import pandas as pd
from google.colab import drive

# %%
# mount to Google drive
drive.mount('/content/drive')

# output dir on google drive
OUTPUT_DIR = "/content/drive/MyDrive/twitch_chat_logs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

today = datetime.utcnow().strftime("%Y%m%d")
OUTPUT_FILE = os.path.join(OUTPUT_DIR, f"twitch_chat_log_{today}.csv")

# Twitch API settings
CLIENT_ID = "gp762nuuoqcoxypju8c569th9wz7q5"
OAUTH_TOKEN = "oauth:mb053vdgfqc0u2m7folpig78vgxdke"
USERNAME = "danieljia36"
API_URL = "https://api.twitch.tv/helix/streams"
GAMES_API_URL = "https://api.twitch.tv/helix/games"

# Twitch IRC settings
IRC_SERVER = "irc.chat.twitch.tv"
IRC_PORT = 6667

# game list
GAME_LIST = [
    "League of Legends", "Counter-Strike", "Grand Theft Auto V",
    "Assassin's Creed Shadows", "Fortnite", "VALORANT",
    "Marvel Rivals", "Apex Legends", "Rainbow Six Siege"
]

# save mappings between channels and games
joined_channels = {}
sock = None
sock_lock = Lock()
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Store data into Google drive

# %%
def connect():
    global sock
    while True:
        try:
            s = socket.socket()
            s.settimeout(60)
            s.connect((IRC_SERVER, IRC_PORT))
            s.send(f"PASS {OAUTH_TOKEN}\n".encode("utf-8"))
            s.send(f"NICK {USERNAME}\n".encode("utf-8"))
            print("✅ connected to Twitch IRC")
            with sock_lock:
                sock = s
            return s
        except Exception as e:
            print(f"⚠ connection failed，try again in 10s...: {e}")
            time.sleep(10)

OUTPUT_FILE = "/content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv"
def insert_chat_data_batch(rows):
    """ 追加聊天数据到同一个 CSV 文件 """
    if not rows:
        return
    df = pd.DataFrame(rows)
    # 检查文件是否存在
    file_exists = os.path.isfile(OUTPUT_FILE)
    # 追加写入，第一次写入时带 header，之后不带 header
    df.to_csv(OUTPUT_FILE, mode='a', index=False, encoding='utf-8', header=not file_exists)
    print(f"✅ inserted {len(rows)} of data into {OUTPUT_FILE}")

def get_game_ids(game_names):
    headers = {
        "Client-ID": CLIENT_ID,
        "Authorization": f"Bearer {OAUTH_TOKEN.split(':')[1]}"
    }
    game_ids = {}
    for name in game_names:
        response = requests.get(GAMES_API_URL, headers=headers, params={"name": name})
        if response.status_code == 200:
            data = response.json()
            for game in data.get("data", []):
                game_ids[game["name"]] = game["id"]
        else:
            print(f"failed to get game id ({name}): {response.text}")
    return game_ids

def get_live_channels(game_ids):
    headers = {
        "Client-ID": CLIENT_ID,
        "Authorization": f"Bearer {OAUTH_TOKEN.split(':')[1]}"
    }
    live_channels = {}
    for game_name, game_id in game_ids.items():
        params = {"game_id": game_id, "first": 20}
        response = requests.get(API_URL, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()
            live_channels[game_name] = [stream["user_login"] for stream in data.get("data", [])]
        else:
            print(f"get {game_name} stream list failed: {response.text}")
    return live_channels

def connect_to_channel(s, channel, game_name):
    try:
        s.send(f"JOIN #{channel}\n".encode("utf-8"))
        joined_channels[channel] = game_name
        print(f"joined channel: {channel} (game: {game_name})")
    except Exception as e:
        print(f"join channel {channel} fail: {e}")
        new_sock = connect()
        connect_to_channel(new_sock, channel, game_name)

def listen_chat():
    global sock
    buffer = []
    last_flush = time.time()
    while True:
        try:
            with sock_lock:
                s = sock
            resp = s.recv(2048).decode("utf-8").strip()
            if not resp:
                print("⚠ received empty messages，reconnection...")
                s = connect()
                continue
            if resp.startswith("PING"):
                s.send("PONG :tmi.twitch.tv\n".encode("utf-8"))
                continue
            if "JOIN" in resp:
                print(f"✅ joined channel confirmation: {resp}")
                continue
            if "PRIVMSG" in resp:
                try:
                    user_name = re.search(r":(\w+)!", resp).group(1)
                    message_match = re.search(r"PRIVMSG #([\w]+) :(.*)", resp)
                    channel = message_match.group(1)
                    chat_message = message_match.group(2)
                    timestamp = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
                    game_name = joined_channels.get(channel, "Unknown Game")
                    row = {
                        "timestamp": timestamp,
                        "game_name": game_name,
                        "channel": channel,
                        "user_name": user_name,
                        "message": chat_message
                    }
                    buffer.append(row)
                    if len(buffer) >= 20 or (time.time() - last_flush) >= 5:
                        insert_chat_data_batch(buffer)
                        buffer.clear()
                        last_flush = time.time()
                except Exception as parse_e:
                    print(f"parse messages failed: {parse_e}")
                    continue
        except socket.timeout:
            print("⚠ 60 s no new messages，reconnection...")
            s = connect()
            continue
        except (socket.error, BrokenPipeError) as e:
            print(f"⚠ connection failure: {e}，reconnection...")
            s = connect()
            continue

def update_channels():
    global sock
    game_ids = get_game_ids(GAME_LIST)
    while True:
        live_channels = get_live_channels(game_ids)
        for game_name, channels in live_channels.items():
            for channel in channels:
                with sock_lock:
                    s = sock
                connect_to_channel(s, channel, game_name)
                time.sleep(2)
        time.sleep(60)

# %%
if __name__ == "__main__":
    sock = connect()
    t_listen = Thread(target=listen_chat, daemon=True)
    t_update = Thread(target=update_channels, daemon=True)
    t_listen.start()
    t_update.start()
    t_listen.join()
    t_update.join()
# Out:
# ✅ connected to Twitch IRC
# joined channel: caedrel (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #caedrel
# joined channel: lck (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #lck
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #lck :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #lck :End of /NAMES list
# joined channel: otplol_ (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #otplol_
# ✅ inserted 8 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: lck_carry (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #lck_carry
# joined channel: traytonlol (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #traytonlol
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: lplenglish (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #lplenglish
# joined channel: tolkin (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #tolkin
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: takayaspecial (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #takayaspecial
# joined channel: skyyart (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #skyyart
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: broxah (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #broxah
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #broxah :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #broxah :End of /NAMES list
# :knightedx!knightedx@knightedx.tmi.twitch.tv PRIVMSG #caedrel :AlrightchatImgonnarunadsYouknowthedrillHeresabigkiss
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: drututt (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #drututt
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #drututt :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #drututt :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: iwdominate (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #iwdominate
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: baiano (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #baiano
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: mfreak00 (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #mfreak00
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #mfreak00 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #mfreak00 :End of /NAMES list
# joined channel: sixentv (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sixentv
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #sixentv :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #sixentv :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: yukiofps14 (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #yukiofps14
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #yukiofps14 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #yukiofps14 :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: guanweiboy (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #guanweiboy
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #guanweiboy :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #guanweiboy :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: skain (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #skain
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: karasmai (game: League of Legends)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #karasmai
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: m3wsu (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #m3wsu
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: hypetried (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #hypetried
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #hypetried :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #hypetried :End of /NAMES list
# joined channel: olofmeister (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #olofmeister
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: skillz0r1337 (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #skillz0r1337
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: acl (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #acl
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #acl :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #acl :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: predator_cc (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #predator_cc
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: happychucky (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #happychucky
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: del1ght (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #del1ght
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: szelioficjalnie (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #szelioficjalnie
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #szelioficjalnie :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #szelioficjalnie :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: krl_stream (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #krl_stream
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #krl_stream :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #krl_stream :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: shoxiejesuss (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #shoxiejesuss
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: sneakylol (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sneakylol
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: renyan (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #renyan
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #renyan :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #renyan :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: m3traneo (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #m3traneo
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: kasanofff (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kasanofff
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: raifcs (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #raifcs
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: eslcs (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #eslcs
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: zonixxcs (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #zonixxcs
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: get_right (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #get_right
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: cct_cs (game: Counter-Strike)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #cct_cs
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #cct_cs :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #cct_cs :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ajikichi (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ajikichi
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #ajikichi :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #ajikichi :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: beezynyc (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #beezynyc
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #beezynyc :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #beezynyc :End of /NAMES list
# :skykocbik1337!skykocbik1337@skykocbik1337.tmi.twitch.tv PRIVMSG #skillz0r1337 :Я СКАЙКОЦЫК ВАСЬ
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: e36_kimitosu (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #e36_kimitosu
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #e36_kimitosu :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #e36_kimitosu :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: capp (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #capp
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #capp :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #capp :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: james_yjt (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #james_yjt
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #james_yjt :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #james_yjt :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: kentsumeshi_heyoo (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kentsumeshi_heyoo
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #kentsumeshi_heyoo :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #kentsumeshi_heyoo :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ran_hinokuma (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ran_hinokuma
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #ran_hinokuma :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #ran_hinokuma :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: amauta_sau (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #amauta_sau
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #amauta_sau :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #amauta_sau :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: xah0b (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #xah0b
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: r_k7den (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #r_k7den
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: solionzi (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #solionzi
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: mdswervin (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #mdswervin
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #mdswervin :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #mdswervin :End of /NAMES list
# :hl314159!hl314159@hl314159.tmi.twitch.tv PRIVMSG #lck_carry :@runnse 小楷只有頭
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: defac3d (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #defac3d
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #defac3d :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #defac3d :End of /NAMES list
# :nicoleguap!nicoleguap@nicoleguap.tmi.twitch.tv PRIVMSG #capp :my fault.
# :huntspointbronx420!huntspointbronx420@huntspointbronx420.tmi.twitch.tv PRIVMSG #caedrel :nice xddmunch
# :replay2315!replay2315@replay2315.tmi.twitch.tv PRIVMSG #caedrel :IRON 4 MAN Kappa
# :skychips1337!skychips1337@skychips1337.tmi.twitch.tv PRIVMSG #skillz0r1337 :НАСТОЯЩИЙ ДОЛБАЕБ LOL
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: abdulhd (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #abdulhd
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #abdulhd :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #abdulhd :End of /NAMES list
# :purppuraslang!purppuraslang@purppuraslang.tmi.twitch.tv PRIVMSG #caedrel :Iron man LUL
# :yaguchi8!yaguchi8@yaguchi8.tmi.twitch.tv PRIVMSG #caedrel :unc
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: nekemaru614 (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #nekemaru614
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #nekemaru614 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #nekemaru614 :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: dedadam (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #dedadam
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: xyungeenace2x (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #xyungeenace2x
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: float735 (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #float735
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: stray_whitecat_ (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #stray_whitecat_
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ice_miruku (game: Grand Theft Auto V)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ice_miruku
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #ice_miruku :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #ice_miruku :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: danzucatv (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #danzucatv
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #danzucatv :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #danzucatv :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ramalhosccp1 (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :derkommlss!derkommlss@derkommlss.tmi.twitch.tv PRIVMSG #guanweiboy :@比爾班長 WutFace
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ramalhosccp1
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #ramalhosccp1 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #ramalhosccp1 :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: shellp (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #shellp
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #shellp :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #shellp :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: jessierabbitt (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :k0ssm_!k0ssm_@k0ssm_.tmi.twitch.tv PRIVMSG #xah0b :АСУ
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jessierabbitt
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #jessierabbitt :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #jessierabbitt :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: manue_tv (game: Assassin's Creed Shadows)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #manue_tv
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #manue_tv :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #manue_tv :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ronnytvspass (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ronnytvspass
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: carmenpilar26 (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #carmenpilar26
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #carmenpilar26 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #carmenpilar26 :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: binmajan (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #binmajan
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #binmajan :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #binmajan :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: unbrix__ (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #unbrix__
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #unbrix__ :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #unbrix__ :End of /NAMES list
# :louluu27!louluu27@louluu27.tmi.twitch.tv PRIVMSG #manue_tv :@tchhoouutchhoouu coucouuu, ça va mieux?
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: miss_papouille (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #miss_papouille
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #miss_papouille :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #miss_papouille :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: dzarwinn (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #dzarwinn
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #dzarwinn :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #dzarwinn :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: isabella (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #isabella
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: urlocaldruggie_ (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #urlocaldruggie_
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: fierce_aussie (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fierce_aussie
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #fierce_aussie :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #fierce_aussie :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: vodudu1986 (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :kaktycw!kaktycw@kaktycw.tmi.twitch.tv PRIVMSG #skillz0r1337 :стася
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #vodudu1986
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #vodudu1986 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #vodudu1986 :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ryntyrell (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ryntyrell
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #ryntyrell :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #ryntyrell :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: arkt1c0 (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #arkt1c0
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #arkt1c0 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #arkt1c0 :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: cynicvash808 (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #cynicvash808
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #cynicvash808 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #cynicvash808 :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: skycejeremy (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #skycejeremy
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #skycejeremy :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #skycejeremy :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: marumalp (game: Assassin's Creed Shadows)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #marumalp
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #marumalp :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #marumalp :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: loeya (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #loeya
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: oatley (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #oatley
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #oatley :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #oatley :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: emip (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #emip
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #emip :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #emip :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ache (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ache
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: hitsquadgodfather (game: Fortnite)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #hitsquadgodfather
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #hitsquadgodfather :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #hitsquadgodfather :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: levilaingarc0n (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #levilaingarc0n
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: xiuder_ (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #xiuder_
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: raskology (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #raskology
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: mrlust (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #mrlust
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: rugaal (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #rugaal
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #rugaal :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #rugaal :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: volx (game: Fortnite)
# ✅ joined channel confirmation: :pantry_zero!pantry_zero@pantry_zero.tmi.twitch.tv PRIVMSG #hitsquadgodfather :!CHest4
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #volx
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #volx :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #volx :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: emxxrrr (game: Fortnite)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #emxxrrr
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #emxxrrr :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #emxxrrr :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: bloodx (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #bloodx
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #bloodx :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #bloodx :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: clixoffline (game: Fortnite)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #clixoffline
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #clixoffline :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #clixoffline :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: heartoftheregion (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #heartoftheregion
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: mayucca (game: Fortnite)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #mayucca
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #mayucca :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #mayucca :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: peterbot247official (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #peterbot247official
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #peterbot247official :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #peterbot247official :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: revenja_fn (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #revenja_fn
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #revenja_fn :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #revenja_fn :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: rekinss (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #rekinss
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #rekinss :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #rekinss :End of /NAMES list
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: stizo_ (game: Fortnite)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #stizo_
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: gofns (game: VALORANT)
# ✅ joined channel confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gofns
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #gofns :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #gofns :End of /NAMES list
# :vanderlog01!vanderlog01@vanderlog01.tmi.twitch.tv PRIVMSG #del1ght :Ну тебя по фактам разнесли
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: lazvell (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: valorant_pacific (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: valorant_jpn (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: krapycoco (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: sliggytv (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: assentw (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ade3_3 (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: superbuss_ (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: spicyuuu (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: relaxcis (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: im_mittiii (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: starwraith (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: crazyfacetw (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: wipr (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: bijusan (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: grimm (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: valorant_th (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: sideshow (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: sweetcampercs (game: VALORANT)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: fandy (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: diegosaurs (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: kephrii (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: yznsa (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: nodamagerocket (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: timthetatmanvods (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: infinite_sge (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: comixfans (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: m4rchgg (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: thatpunchkid (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: rezsuu (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: fliiqzy (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: suppress (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: benchpowerr (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: 9xlazy (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: basimzb (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: sinatraavod (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: camloso (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: popello3433 (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: meeeows (game: Marvel Rivals)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: mande (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: oraxe (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: dmf_kyochan (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: schrodingerlee (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: 9impulse (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: dttodot (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: curihara0807 (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: gdolphn (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ranches (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: tiffajessi (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: 4rmy_o (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: vunlucky2 (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: ooharameeen (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: kasellos (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: hiswattson247 (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: forgetdattv (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: hartly (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: lstarshunshun (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: moonzinha (game: Apex Legends)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: thxfreeman (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: fastanne (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: senvale (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: jynxzioffline_ (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: vetelcito01 (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: tuskitv (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: zander (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: kinggeorgeoffline (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: proxima (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: mozqrk (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: enemyn1 (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: valkja (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: bstaaard (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: swish (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: caramel_ya (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: unsweetqueen (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: evilgrandpaaa (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: airhead022 (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: xtuffxgongx (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
# joined channel: leinuoke (game: Tom Clancy's Rainbow Six Siege)
# ✅ inserted 20 of data into /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv
