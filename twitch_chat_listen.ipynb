# %%
import socket
import re
import requests
import json
import time
import threading
from datetime import datetime
from google.cloud import bigquery

# GCP configuration
PROJECT_ID = "twitch-realtime-chats"
DATASET_ID = "202503200809"
TABLE_ID = "twich_chat_log_partitioned"
# CREDENTIALS_PATH = "/content/twitch-realtime-chats-e6edd4d2d2ab.json"

# initialise BigQuery
bq_client = bigquery.Client()

# Twitch configuration
CLIENT_ID = "gp762nuuoqcoxypju8c569th9wz7q5"
OAUTH_TOKEN = "oauth:mb053vdgfqc0u2m7folpig78vgxdke"
USERNAME = "danieljia36"
API_URL = "https://api.twitch.tv/helix/streams"
GAMES_API_URL = "https://api.twitch.tv/helix/games"


GAME_LIST = [
    "League of Legends",
    "Counter-Strike",
    # "Grand Theft Auto V",
    # "Assassin's Creed Shadows",
    "Fortnite",
    "VALORANT",
    "Marval Rivals"
]

# Twitch IRC server info
IRC_SERVER = "irc.chat.twitch.tv"
IRC_PORT = 6667

# joined channels in accordance with games
joined_channels = {}


def connect():
    """ Connecting to Twitch IRC server ... """
    while True:
        try:
            sock = socket.socket()
            sock.settimeout(60)
            sock.connect((IRC_SERVER, IRC_PORT))
            sock.send(f"PASS {OAUTH_TOKEN}\n".encode("utf-8"))
            sock.send(f"NICK {USERNAME}\n".encode("utf-8"))
            print("✅ Connected to Twitch")
            return sock
        except Exception as e:
            print(f"⚠ Connection failure，retry after 10 seconds... Error: {e}")
            time.sleep(10)


def write_to_bigquery(rows):
    """ Write batch to BigQuery """
    table_ref = f"{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}"

    for row in rows:
        if isinstance(row["timestamp"], datetime):
            row["timestamp"] = row["timestamp"].strftime("%Y-%m-%d %H:%M:%S")

    errors = bq_client.insert_rows_json(table_ref, rows)

    if errors:
        print(f"❌ BigQuery writing error: {errors}")
    else:
        print(f"✅ Data loaded into BigQuery: {len(rows)} rows")


def listen_chat(sock):
    """ Listen to multiple channels chats """
    chat_buffer = []
    last_write_time = time.time()

    while True:
        try:
            resp = sock.recv(2048).decode("utf-8").strip()

            # 🚀 print message length to aoid empty messages.
            print(f"📩 Meta data ({len(resp)} byte): {resp}")

            if not resp:
                print("⚠ Empty message, reconnecting...")
                sock = connect()
                continue

            # sending Twitch PING to keep the connection
            if resp.startswith("PING"):
                sock.send("PONG :tmi.twitch.tv\n".encode("utf-8"))
                print("✅ sending PONG")
                continue

            # joined channel successfully
            if "JOIN" in resp:
                print(f"✅ Channel joined: {resp}")
                continue

            #
            if "PRIVMSG" in resp:
                try:
                    username = re.search(r":(\w+)!", resp).group(1)
                    message = re.search(r"PRIVMSG #([\w]+) :(.*)", resp)
                    channel = message.group(1)
                    chat_message = message.group(2)
                    timestamp = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
                    game_name = joined_channels.get(channel, "Unknown Game")

                    print(f"💬 [{timestamp}] [{game_name}] [{channel}] [{username}]: {chat_message}")

                    chat_buffer.append({
                        "timestamp": timestamp,
                        "game_name": game_name,
                        "channel": channel,
                        "user_name": username,
                        "message": chat_message
                    })

                    # write to BigQuery every 20 rows or five seconds
                    if len(chat_buffer) >= 20 or time.time() - last_write_time > 5:
                        write_to_bigquery(chat_buffer)
                        chat_buffer.clear()
                        last_write_time = time.time()

                except AttributeError:
                    continue

        except socket.timeout:
            print("⚠ 60s no new messages，reconnecting to Twitch")
            sock = connect()
            continue

        except (socket.error, BrokenPipeError) as e:
            print(f"⚠ Connecction lost, reconnecting... Error: {e}")
            sock = connect()
            continue


def update_channels(sock):
    """ Keep updating channels on live, and add on new ones """
    while True:
        try:
            game_ids = get_game_ids(GAME_LIST)
            live_channels = get_live_channels(game_ids)

            for game_name, channels in live_channels.items():
                for channel in channels:
                    try:
                        connect_to_channel(sock, channel, game_name)
                        time.sleep(2)  # Wait for 2s every time joining a channel, to avoide Twitch limits.
                    except (BrokenPipeError, socket.error):
                        print(f"⚠ connectiong lost, reconnecting...")
                        sock = connect()
                        connect_to_channel(sock, channel, game_name)

            time.sleep(60)

        except Exception as e:
            print(f"⚠ Error: {e}")
            time.sleep(10)  # retry after 10 seconds

if __name__ == "__main__":
    sock = connect()

    # start listening pipeline
    listen_thread = threading.Thread(target=listen_chat, args=(sock,), daemon=True)
    listen_thread.start()

    # keep updating channels
    update_channels(sock)

    # make sure the listening process doesn't get cut off.
    listen_thread.join()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 📩 Meta data (155 byte): :bracizo!bracizo@bracizo.tmi.twitch.tv PRIVMSG #mictia00 :Jajjss
# :rkurupt!rkurupt@rkurupt.tmi.twitch.tv PRIVMSG #valorant_northamerica :we playing or nah?
# 💬 [2025-03-20 22:51:39] [VALORANT] [mictia00] [bracizo]: Jajjss
# ✅ Data loaded into BigQuery: 20 rows
# 📩 Meta data (402 byte): :askirt_kura!askirt_kura@askirt_kura.tmi.twitch.tv PRIVMSG #noway4u_sir :full crit gehen ohne gauntlet weiß ich ja nicht HmmmOK
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #k1ng :xD
# :miozor_ya!miozor_ya@miozor_ya.tmi.twitch.tv PRIVMSG #lonely__me :если лера покажет настройки, надо будет сделать команду настроек с клипом
# :leamoremii!leamoremii@leamoremii.tmi.twitch.tv PRIVMSG #olesha :654321
# 💬 [2025-03-20 22:51:39] [League of Legends] [noway4u_sir] [askirt_kura]: full crit gehen ohne gauntlet weiß ich ja nicht HmmmOK
# 📩 Meta data (578 byte): :alckasher!alckasher@alckasher.tmi.twitch.tv PRIVMSG #olesha :654321
# :nathanjzn!nathanjzn@nathanjzn.tmi.twitch.tv PRIVMSG #xarola_ :kkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# :cxnfinement!cxnfinement@cxnfinement.tmi.twitch.tv PRIVMSG #mooda :NO WAY
# :kriseyy!kriseyy@kriseyy.tmi.twitch.tv PRIVMSG #velja_lol :tristana
# :lmarashdeh!lmarashdeh@lmarashdeh.tmi.twitch.tv PRIVMSG #clix :You have the voice chat off
# :w3ula!w3ula@w3ula.tmi.twitch.tv PRIVMSG #olesha :33
# :8hamim!8hamim@8hamim.tmi.twitch.tv PRIVMSG #valorant_northamerica :does anyone acctually knw the reason for the tech pause?
# 💬 [2025-03-20 22:51:39] [Counter-Strike] [olesha] [alckasher]: 654321
# 📩 Meta data (65 byte): :zess04ka!zess04ka@zess04ka.tmi.twitch.tv PRIVMSG #olesha :987534
# 💬 [2025-03-20 22:51:39] [Counter-Strike] [olesha] [zess04ka]: 987534
# 📩 Meta data (474 byte): :carolusmagnus!carolusmagnus@carolusmagnus.tmi.twitch.tv PRIVMSG #slipix :Pas à nous
# :goddess__nyx!goddess__nyx@goddess__nyx.tmi.twitch.tv PRIVMSG #sgares :PICKEMS ?!?!?!
# :lsaeiah!lsaeiah@lsaeiah.tmi.twitch.tv PRIVMSG #mooda :ofc he is rich
# :pyrite19!pyrite19@pyrite19.tmi.twitch.tv PRIVMSG #arrowcs :heisenberg LOL
# :danicosmic00!danicosmic00@danicosmic00.tmi.twitch.tv PRIVMSG #mictia00 :que decia
# :diegop932!diegop932@diegop932.tmi.twitch.tv PRIVMSG #mictia00 :JAJAJA
# 💬 [2025-03-20 22:51:39] [League of Legends] [slipix] [carolusmagnus]: Pas à nous
# 📩 Meta data (472 byte): :hellinwartonight!hellinwartonight@hellinwartonight.tmi.twitch.tv PRIVMSG #foolish :nt
# :tranzifero!tranzifero@tranzifero.tmi.twitch.tv PRIVMSG #xarola_ :ACHOU QUE ERA MACHADINHA É?
# :sfetlaok00!sfetlaok00@sfetlaok00.tmi.twitch.tv PRIVMSG #olesha :Ну скажи число уже
# :aguirredylan16!aguirredylan16@aguirredylan16.tmi.twitch.tv PRIVMSG #mictia00 :ke?
# :bestzinho!bestzinho@bestzinho.tmi.twitch.tv PRIVMSG #lobanjicaa :💀🤜timeless / float / valhalla crazy mode !!@lobanjicaa
# 💬 [2025-03-20 22:51:39] [VALORANT] [foolish] [hellinwartonight]: nt
# 📩 Meta data (417 byte): :pattidatti_!pattidatti_@pattidatti_.tmi.twitch.tv PRIVMSG #olesha :777
# :slip_katiabell6!slip_katiabell6@slip_katiabell6.tmi.twitch.tv PRIVMSG #slipix :oué oué Kappa
# :incarnar!incarnar@incarnar.tmi.twitch.tv PRIVMSG #drututt :SUSSY
# :arqueiroooooooo!arqueiroooooooo@arqueiroooooooo.tmi.twitch.tv PRIVMSG #xarola_ :?
# :generalwilric01!generalwilric01@generalwilric01.tmi.twitch.tv PRIVMSG #drututt :@47xbilal STONING
# 💬 [2025-03-20 22:51:39] [Counter-Strike] [olesha] [pattidatti_]: 777
# 📩 Meta data (88 byte): :macflayyy!macflayyy@macflayyy.tmi.twitch.tv PRIVMSG #xarola_ :a carinha dele kkkkkkkkkk
# 💬 [2025-03-20 22:51:39] [VALORANT] [xarola_] [macflayyy]: a carinha dele kkkkkkkkkk
# 📩 Meta data (355 byte): :mrwilly76!mrwilly76@mrwilly76.tmi.twitch.tv PRIVMSG #loltyler1 :<Message deleted>
# :godyr_khan!godyr_khan@godyr_khan.tmi.twitch.tv PRIVMSG #slipix :LUL LUL LUL LUL
# :jirafeytwitch!jirafeytwitch@jirafeytwitch.tmi.twitch.tv PRIVMSG #velja_lol :@clcifr prob top doesnt play or they not scared
# :nickxzz_!nickxzz_@nickxzz_.tmi.twitch.tv PRIVMSG #suetam1v4 :K
# 💬 [2025-03-20 22:51:39] [League of Legends] [loltyler1] [mrwilly76]: <Message deleted>
# 📩 Meta data (90 byte): :takedown79!takedown79@takedown79.tmi.twitch.tv PRIVMSG #pobelter :you have prestige kaisa
# 💬 [2025-03-20 22:51:39] [League of Legends] [pobelter] [takedown79]: you have prestige kaisa
# 📩 Meta data (147 byte): :oliveiraig_!oliveiraig_@oliveiraig_.tmi.twitch.tv PRIVMSG #blackoutz :jogou mt
# :hogendani!hogendani@hogendani.tmi.twitch.tv PRIVMSG #cr_rion :えへへ
# 💬 [2025-03-20 22:51:40] [Fortnite] [blackoutz] [oliveiraig_]: jogou mt
# 📩 Meta data (238 byte): :merytz!merytz@merytz.tmi.twitch.tv PRIVMSG #aussieantics :give him a second
# :creepy_void!creepy_void@creepy_void.tmi.twitch.tv PRIVMSG #reetlol :!dampening
# :daniaa_____!daniaa_____@daniaa_____.tmi.twitch.tv PRIVMSG #happyhappygal :loll
# 💬 [2025-03-20 22:51:40] [Fortnite] [aussieantics] [merytz]: give him a second
# 📩 Meta data (189 byte): :surrealzeether!surrealzeether@surrealzeether.tmi.twitch.tv PRIVMSG #pobelter :also who hovers J4 and then doesn't blind pick it
# :dulet_!dulet_@dulet_.tmi.twitch.tv PRIVMSG #olesha :098765
# 💬 [2025-03-20 22:51:40] [League of Legends] [pobelter] [surrealzeether]: also who hovers J4 and then doesn't blind pick it
# 📩 Meta data (352 byte): :friendlyscarecrow!friendlyscarecrow@friendlyscarecrow.tmi.twitch.tv PRIVMSG #olesha :6
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #reetlol :Creepy_Void, Reet has his dampening time set to 0.
# :hellenzokinha!hellenzokinha@hellenzokinha.tmi.twitch.tv PRIVMSG #xarola_ :OH TREM FEI
# :makexz01!makexz01@makexz01.tmi.twitch.tv PRIVMSG #mictia00 :So
# 💬 [2025-03-20 22:51:40] [Counter-Strike] [olesha] [friendlyscarecrow]: 6
# 📩 Meta data (95 byte): :panelinha_hd!panelinha_hd@panelinha_hd.tmi.twitch.tv PRIVMSG #olui :Mano essa AR e muito forte
# 💬 [2025-03-20 22:51:40] [Fortnite] [olui] [panelinha_hd]: Mano essa AR e muito forte
# 📩 Meta data (315 byte): :jim_picklecat00!jim_picklecat00@jim_picklecat00.tmi.twitch.tv PRIVMSG #mictia00 :juanit124Wajajaja juanit124Wajajaja juanit124Wajajaja
# :ookaee!ookaee@ookaee.tmi.twitch.tv PRIVMSG #mooda :LOL
# :xxgeee!xxgeee@xxgeee.tmi.twitch.tv PRIVMSG #jxness7 :poe
# :wanoxes!wanoxes@wanoxes.tmi.twitch.tv PRIVMSG #olesha :123456
# 💬 [2025-03-20 22:51:40] [VALORANT] [mictia00] [jim_picklecat00]: juanit124Wajajaja juanit124Wajajaja juanit124Wajajaja
# 📩 Meta data (166 byte): :natoosaa!natoosaa@natoosaa.tmi.twitch.tv PRIVMSG #smurf_tv :@VORUN5 я каждую весну иду на вич проверяться из-за количества болезней и зараз которые у меня появляются
# 💬 [2025-03-20 22:51:40] [League of Legends] [smurf_tv] [natoosaa]: @VORUN5 я каждую весну иду на вич проверяться из-за количества болезней и зараз которые у меня появляются
# 📩 Meta data (271 byte): :lettuce_tt_00!lettuce_tt_00@lettuce_tt_00.tmi.twitch.tv PRIVMSG #mictia00 :so  󠀀
# :twohurefo!twohurefo@twohurefo.tmi.twitch.tv PRIVMSG #olesha :999999
# :sakuraleyla!sakuraleyla@sakuraleyla.tmi.twitch.tv PRIVMSG #kubafps :Heute am Hamburger Hafen fast ins wasser Geflogen
# 💬 [2025-03-20 22:51:40] [VALORANT] [mictia00] [lettuce_tt_00]: so  󠀀
# 📩 Meta data (512 byte): :lovellsos!lovellsos@lovellsos.tmi.twitch.tv PRIVMSG #loltyler1 :om
# :blauertoastfps!blauertoastfps@blauertoastfps.tmi.twitch.tv PRIVMSG #kubafps :also ich bin treuer Impulse G spieler kubaAIM kubaKEK
# :7msn__!7msn__@7msn__.tmi.twitch.tv PRIVMSG #clix :!settings
# :elancemert!elancemert@elancemert.tmi.twitch.tv PRIVMSG #velja_lol :0/10 yasuo game deal
# :jovke228!jovke228@jovke228.tmi.twitch.tv PRIVMSG #olesha :4763
# :ichbineric2!ichbineric2@ichbineric2.tmi.twitch.tv PRIVMSG #noway4u_sir :@kayn_trace tuckk  󠀀
# 💬 [2025-03-20 22:51:40] [League of Legends] [loltyler1] [lovellsos]: om
# 📩 Meta data (281 byte): :avocado__bread!avocado__bread@avocado__bread.tmi.twitch.tv PRIVMSG #noway4u_sir :Still believe
# :krispfn6!krispfn6@krispfn6.tmi.twitch.tv PRIVMSG #clix :LL
# :cherufee!cherufee@cherufee.tmi.twitch.tv PRIVMSG #nissaxter :202
# :bzfafa!bzfafa@bzfafa.tmi.twitch.tv PRIVMSG #slipix :sus
# 💬 [2025-03-20 22:51:40] [League of Legends] [noway4u_sir] [avocado__bread]: Still believe
# 📩 Meta data (246 byte): :shebo_x!shebo_x@shebo_x.tmi.twitch.tv PRIVMSG #clix :EU BRO
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #clix :ACTION 7msn__, Clix's updated 2025 settings https://www.twitch.tv/clix/clip/InterestingYawningBoarTBTacoLeft-L7d0-CNFP-TPKBGf
# 💬 [2025-03-20 22:51:40] [Fortnite] [clix] [shebo_x]: EU BRO
# ✅ Data loaded into BigQuery: 20 rows
# 📩 Meta data (505 byte): :sirye_!sirye_@sirye_.tmi.twitch.tv PRIVMSG #mooda :portch
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #strakatv :GGDROP¡Te esperan giros gratis! Usa la promoción NSPNQ66 y consigue tu bono de ruleta.Además, ¡no te pierdas el código STRAKA para obtener un +11% al recargar en https://ggdrop.art/strakatv!¡Salta a la acción! ¡No te lo pierdas!
# :sir_santik!sir_santik@sir_santik.tmi.twitch.tv PRIVMSG #synd1cat :@synd1cat если не убиваешь в этой катке с Зевса, то не можешь говорить Мурзику «сосал?»
# 💬 [2025-03-20 22:51:40] [VALORANT] [mooda] [sirye_]: portch
# 📩 Meta data (568 byte): :bech_is_me!bech_is_me@bech_is_me.tmi.twitch.tv PRIVMSG #tenz :hello
# :briixtney!briixtney@briixtney.tmi.twitch.tv PRIVMSG #mooda :WTF
# :itsgzone!itsgzone@itsgzone.tmi.twitch.tv PRIVMSG #sommerset :!cmd edit lb $(touser) div 1 cup day 2 https://fortnitetracker.com/events/epicgames_S34_FNCSDivisionalCup_Division1_NAC
# :bracizo!bracizo@bracizo.tmi.twitch.tv PRIVMSG #mictia00 :Xddddd
# :pidoykt!pidoykt@pidoykt.tmi.twitch.tv PRIVMSG #olesha :0
# :wikkent!wikkent@wikkent.tmi.twitch.tv PRIVMSG #olesha :322222
# :legisir!legisir@legisir.tmi.twitch.tv PRIVMSG #olesha :2012
# 💬 [2025-03-20 22:51:40] [VALORANT] [tenz] [bech_is_me]: hello
# 📩 Meta data (73 byte): :takedown79!takedown79@takedown79.tmi.twitch.tv PRIVMSG #pobelter :whaatt
# 💬 [2025-03-20 22:51:41] [League of Legends] [pobelter] [takedown79]: whaatt
# 📩 Meta data (78 byte): :seminal_000!seminal_000@seminal_000.tmi.twitch.tv PRIVMSG #mooda :lol subroza
# 💬 [2025-03-20 22:51:41] [VALORANT] [mooda] [seminal_000]: lol subroza
# 📩 Meta data (338 byte): :smegmamommyboy!smegmamommyboy@smegmamommyboy.tmi.twitch.tv PRIVMSG #olesha :987654
# :rybak07!rybak07@rybak07.tmi.twitch.tv PRIVMSG #drututt :@47xbilal STONING
# :patasdexayah!patasdexayah@patasdexayah.tmi.twitch.tv PRIVMSG #nissaxter :Ya empezó ResidentSleeper
# :tirimen1225!tirimen1225@tirimen1225.tmi.twitch.tv PRIVMSG #cr_rion :wwwwwww
# 💬 [2025-03-20 22:51:41] [Counter-Strike] [olesha] [smegmamommyboy]: 987654
# 📩 Meta data (268 byte): :streamelements!streamelements@streamelements.tmi.twitch.tv PRIVMSG #sommerset :@itsgzone, successfully updated command lb.
# :dresdiaz18!dresdiaz18@dresdiaz18.tmi.twitch.tv PRIVMSG #tvander :uy uy uy uy uy uy
# :mrcl_0!mrcl_0@mrcl_0.tmi.twitch.tv PRIVMSG #pobelter :yes
# 💬 [2025-03-20 22:51:41] [Fortnite] [sommerset] [streamelements]: @itsgzone, successfully updated command lb.
# 📩 Meta data (381 byte): :maxence0049!maxence0049@maxence0049.tmi.twitch.tv PRIVMSG #slipix :sussssssssssssss
# :geto_og!geto_og@geto_og.tmi.twitch.tv PRIVMSG #mooda :gt3 VALID %
# :panconqueso927!panconqueso927@panconqueso927.tmi.twitch.tv PRIVMSG #mictia00 :XDDD
# :ziven90!ziven90@ziven90.tmi.twitch.tv PRIVMSG #kuentinlol :@ClolD claro, por eso a mí el flameo por content me parece lo más rancio del mundo
# 💬 [2025-03-20 22:51:41] [League of Legends] [slipix] [maxence0049]: sussssssssssssss
# 📩 Meta data (629 byte): :rain125_!rain125_@rain125_.tmi.twitch.tv PRIVMSG #lobanjicaa :7 0 6 LOBA TRY CRAZY MODE 3х Loba 3х GK68 3х Enchanted @Lobanjicaa
# :wul1g!wul1g@wul1g.tmi.twitch.tv PRIVMSG #olesha :297500
# :ellokitodelaguerra!ellokitodelaguerra@ellokitodelaguerra.tmi.twitch.tv PRIVMSG #k1ng :!tabla
# :iuizim!iuizim@iuizim.tmi.twitch.tv PRIVMSG #suetam1v4 :KKKKKKKKKKKKKK
# :m8_grey13!m8_grey13@m8_grey13.tmi.twitch.tv PRIVMSG #locklear :CROIVEUR GANG locklearGANG locklearGANG locklearGANG locklearGANG locklearGANG
# :rehfqz!rehfqz@rehfqz.tmi.twitch.tv PRIVMSG #xarola_ :tome
# :sclfl_!sclfl_@sclfl_.tmi.twitch.tv PRIVMSG #strakatv :sdjlñaksjkdlña
# 💬 [2025-03-20 22:51:41] [Counter-Strike] [lobanjicaa] [rain125_]: 7 0 6 LOBA TRY CRAZY MODE 3х Loba 3х GK68 3х Enchanted @Lobanjicaa
# 📩 Meta data (208 byte): :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #k1ng :https://osirion.gg/tournaments/S34_FNCSDivisionalCup_Division1_Week3Day1_BR?leaderboardId=epicgames_S34_FNCSDivisionalCup_Division1_BR_Week3_cumulative
# 💬 [2025-03-20 22:51:41] [Fortnite] [k1ng] [nightbot]: https://osirion.gg/tournaments/S34_FNCSDivisionalCup_Division1_Week3Day1_BR?leaderboardId=epicgames_S34_FNCSDivisionalCup_Division1_BR_Week3_cumulative
# 📩 Meta data (365 byte): :jeludok_babochki!jeludok_babochki@jeludok_babochki.tmi.twitch.tv PRIVMSG #olesha :72
# :w0nxy!w0nxy@w0nxy.tmi.twitch.tv PRIVMSG #noway4u_sir :LUL LUL LUL
# :silverikitai!silverikitai@silverikitai.tmi.twitch.tv PRIVMSG #cr_rion :ゼファーって今どこのチーム？
# :zakob__!zakob__@zakob__.tmi.twitch.tv PRIVMSG #mrdzinold :Rozkminka to prawda ze poczciwy Krzychu robił ci mke @MrDzinold
# 💬 [2025-03-20 22:51:41] [Counter-Strike] [olesha] [jeludok_babochki]: 72
# 📩 Meta data (436 byte): :locoo99!locoo99@locoo99.tmi.twitch.tv PRIVMSG #velja_lol :better Baus to learn Rene than Velja more Maokai xD
# :neversubfeelsgoodman!neversubfeelsgoodman@neversubfeelsgoodman.tmi.twitch.tv PRIVMSG #drututt :buub
# :its_cudii!its_cudii@its_cudii.tmi.twitch.tv PRIVMSG #happyhappygal :@americandad0hehde please don’t share personal information in chat 💗
# :skute1ebi!skute1ebi@skute1ebi.tmi.twitch.tv PRIVMSG #mrdzinold :ogladasz lakersow?
# 💬 [2025-03-20 22:51:41] [League of Legends] [velja_lol] [locoo99]: better Baus to learn Rene than Velja more Maokai xD
# 📩 Meta data (749 byte): :quarterkiera!quarterkiera@quarterkiera.tmi.twitch.tv PRIVMSG #sgares :im so smart
# :heinz__inator!heinz__inator@heinz__inator.tmi.twitch.tv PRIVMSG #krokoboss :@mazeb8 loslassen
# :akaiyya!akaiyya@akaiyya.tmi.twitch.tv PRIVMSG #mooda :a porch?
# :oli_181!oli_181@oli_181.tmi.twitch.tv PRIVMSG #kubafps :@chat haben sie gewonnen?
# :frickson13!frickson13@frickson13.tmi.twitch.tv PRIVMSG #vadeal :@Mods skip
# :johanperez98!johanperez98@johanperez98.tmi.twitch.tv PRIVMSG #nissaxter :Y PARA CUANDO LA BODA ESTAFADORA OSFrog OSFrog OSFrog OSFrog OSFrog Y PARA CUANDO LA BODA ESTAFADORA OSFrog OSFrog OSFrog OSFrog OSFrogY PARA CUANDO LA BODA ESTAFADORA OSFrog OSFrog OSFrog OSFrog OSFrogY PARA CUANDO LA BODA ESTAFADORA OSFrog OSFrog OSFrog OSFrog OSFrog
# 💬 [2025-03-20 22:51:41] [VALORANT] [sgares] [quarterkiera]: im so smart
# 📩 Meta data (235 byte): :dimaaaa33!dimaaaa33@dimaaaa33.tmi.twitch.tv PRIVMSG #olesha :880055
# :befali!befali@befali.tmi.twitch.tv PRIVMSG #mooda :subroza's vod channel been hitting lately
# :samed0om!samed0om@samed0om.tmi.twitch.tv PRIVMSG #rugaal :NotLikeThis
# 💬 [2025-03-20 22:51:41] [Counter-Strike] [olesha] [dimaaaa33]: 880055
# 📩 Meta data (260 byte): :bieuconn!bieuconn@bieuconn.tmi.twitch.tv PRIVMSG #xarola_ :TOMOU NIU CU
# :vxrsefv!vxrsefv@vxrsefv.tmi.twitch.tv PRIVMSG #clix :@Clix
# :peira__!peira__@peira__.tmi.twitch.tv PRIVMSG #mrdzinold :AGATAAA
# :xxgeee!xxgeee@xxgeee.tmi.twitch.tv PRIVMSG #jxness7 :poe
# 💬 [2025-03-20 22:51:41] [VALORANT] [xarola_] [bieuconn]: TOMOU NIU CU
# 📩 Meta data (270 byte): :lukass2209!lukass2209@lukass2209.tmi.twitch.tv PRIVMSG #xtom223 :smutne ale prawdziwe
# :cristinio10!cristinio10@cristinio10.tmi.twitch.tv PRIVMSG #loltyler1 :!followage
# :melodic_mondongo!melodic_mondongo@melodic_mondongo.tmi.twitch.tv PRIVMSG #mictia00 :JASJAJSJASJASJ
# 💬 [2025-03-20 22:51:41] [Counter-Strike] [xtom223] [lukass2209]: smutne ale prawdziwe
# 📩 Meta data (57 byte): :lucky20!lucky20@lucky20.tmi.twitch.tv PRIVMSG #olesha :0
# 💬 [2025-03-20 22:51:42] [Counter-Strike] [olesha] [lucky20]: 0
# 📩 Meta data (425 byte): :314tre!314tre@314tre.tmi.twitch.tv PRIVMSG #loupiote3 :@crousti03 t'as fait quoi après je suis encore dedans perso
# :isthatblxurr!isthatblxurr@isthatblxurr.tmi.twitch.tv PRIVMSG #mooda :1000% hamy clears u
# :stinnnaler!stinnnaler@stinnnaler.tmi.twitch.tv PRIVMSG #olesha :964312
# :mose555!mose555@mose555.tmi.twitch.tv PRIVMSG #velja_lol :naafiri DinoDance
# :liff4ik_!liff4ik_@liff4ik_.tmi.twitch.tv PRIVMSG #olesha :4071505
# 💬 [2025-03-20 22:51:42] [VALORANT] [loupiote3] [314tre]: @crousti03 t'as fait quoi après je suis encore dedans perso
# 📩 Meta data (301 byte): :leesinsemprewin!leesinsemprewin@leesinsemprewin.tmi.twitch.tv PRIVMSG #doublelift :@Doublelift you shipping the pc to Brazil ?
# :momoetokig!momoetokig@momoetokig.tmi.twitch.tv PRIVMSG #loltyler1 :@Infiltrator_Irelia thanks :3
# :paulscottqro!paulscottqro@paulscottqro.tmi.twitch.tv PRIVMSG #rugaal :эм
# 💬 [2025-03-20 22:51:42] [League of Legends] [doublelift] [leesinsemprewin]: @Doublelift you shipping the pc to Brazil ?
# 📩 Meta data (274 byte): :keruqueru!keruqueru@keruqueru.tmi.twitch.tv PRIVMSG #velja_lol :chat whats the song
# :m2lk139!m2lk139@m2lk139.tmi.twitch.tv PRIVMSG #synd1cat :@synd1cat го после катки iq тест пройдешь?? ))
# :davidturnerfgi!davidturnerfgi@davidturnerfgi.tmi.twitch.tv PRIVMSG #rugaal :!join
# 💬 [2025-03-20 22:51:42] [League of Legends] [velja_lol] [keruqueru]: chat whats the song
# 📩 Meta data (170 byte): :fivediabeticyordles!fivediabeticyordles@fivediabeticyordles.tmi.twitch.tv PRIVMSG #loltyler1 :@xi__jingping sus
# :xio_f!xio_f@xio_f.tmi.twitch.tv PRIVMSG #olesha :123456
# 💬 [2025-03-20 22:51:42] [League of Legends] [loltyler1] [fivediabeticyordles]: @xi__jingping sus
# ✅ Data loaded into BigQuery: 20 rows
# 📩 Meta data (405 byte): :deathsyther025!deathsyther025@deathsyther025.tmi.twitch.tv PRIVMSG #batmanbugha :where’s the fat ginger
# :germflog!germflog@germflog.tmi.twitch.tv PRIVMSG #mictia00 :que
# :masterrrson!masterrrson@masterrrson.tmi.twitch.tv PRIVMSG #mooda :full of tnt?
# :sai__ke!sai__ke@sai__ke.tmi.twitch.tv PRIVMSG #blackoutz :O TDH bateu ksksks
# :tranzifero!tranzifero@tranzifero.tmi.twitch.tv PRIVMSG #xarola_ :TOMA AI
# 💬 [2025-03-20 22:51:42] [Fortnite] [batmanbugha] [deathsyther025]: where’s the fat ginger
# 📩 Meta data (667 byte): :rafikdz09!rafikdz09@rafikdz09.tmi.twitch.tv PRIVMSG #lobanjicaa :6 can you try mental,goalie,dig deep 3v3 on win @Lobanjicaa
# :allieee____!allieee____@allieee____.tmi.twitch.tv PRIVMSG #sommerset :@simplyannaa oh! square up
# :sierraboltz!sierraboltz@sierraboltz.tmi.twitch.tv PRIVMSG #b0rja :BORJA, XINESCO ESTA FATAL, escríbele cuando puedas borjita porfa, lo veo fatal : (
# :relictraven!relictraven@relictraven.tmi.twitch.tv PRIVMSG #olesha :1000000
# :st_miyo!st_miyo@st_miyo.tmi.twitch.tv PRIVMSG #slipix :ETRANGE
# :slip_siola14!slip_siola14@slip_siola14.tmi.twitch.tv PRIVMSG #slipix :Doubt Keepo
# :krispfn6!krispfn6@krispfn6.tmi.twitch.tv PRIVMSG #clix :LLLLLLL
# 💬 [2025-03-20 22:51:42] [Counter-Strike] [lobanjicaa] [rafikdz09]: 6 can you try mental,goalie,dig deep 3v3 on win @Lobanjicaa
# 📩 Meta data (422 byte): :fossabot!fossabot@fossabot.tmi.twitch.tv PRIVMSG #rugaal :@davidturnerfgi Why can't eggs have love? They will break up too soon.
# :magazencs!magazencs@magazencs.tmi.twitch.tv PRIVMSG #lobanjicaa :float 4x , Shaken 3x , valhalla 3x 3v3  󠀀
# :kiittykate13!kiittykate13@kiittykate13.tmi.twitch.tv PRIVMSG #happyhappygal :my friends and I now do that lol
# :two_dooor!two_dooor@two_dooor.tmi.twitch.tv PRIVMSG #velja_lol :!opgg
# 💬 [2025-03-20 22:51:42] [Fortnite] [rugaal] [fossabot]: @davidturnerfgi Why can't eggs have love? They will break up too soon.
# 📩 Meta data (252 byte): :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #loltyler1 :@cristinio10 has been following @loltyler1 for 7 years, 5 days, 6 hours, 36 seconds.
# :xarcor123!xarcor123@xarcor123.tmi.twitch.tv PRIVMSG #valorant_northamerica :What's taking so longgggggg
# 💬 [2025-03-20 22:51:42] [League of Legends] [loltyler1] [nightbot]: @cristinio10 has been following @loltyler1 for 7 years, 5 days, 6 hours, 36 seconds.
# 📩 Meta data (619 byte): :fastxnz!fastxnz@fastxnz.tmi.twitch.tv PRIVMSG #xarola_ :JERÔNIMO 2.0
# :sinkingisland!sinkingisland@sinkingisland.tmi.twitch.tv PRIVMSG #sgares :Can u do a leaderboard again mhm
# :koveihv!koveihv@koveihv.tmi.twitch.tv PRIVMSG #olesha :57229
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #velja_lol :https://www.op.gg/multisearch/euw?summoners=LR+Velja%232203%2C+VELJA+DEL+REY%232203%2C+VELJA+THE+MENACE%232203%2C
# :nathanjzn!nathanjzn@nathanjzn.tmi.twitch.tv PRIVMSG #xarola_ :niaum vei
# :livsfarans!livsfarans@livsfarans.tmi.twitch.tv PRIVMSG #drututt :Doesn’t some part of your passive scale with level? @Drututt
# 💬 [2025-03-20 22:51:42] [VALORANT] [xarola_] [fastxnz]: JERÔNIMO 2.0
# 📩 Meta data (72 byte): :iuizim!iuizim@iuizim.tmi.twitch.tv PRIVMSG #suetam1v4 :KKKKKKKKKKKKKKKK
# 💬 [2025-03-20 22:51:42] [Fortnite] [suetam1v4] [iuizim]: KKKKKKKKKKKKKKKK
# 📩 Meta data (164 byte): :santycosmic00!santycosmic00@santycosmic00.tmi.twitch.tv PRIVMSG #mictia00 :quemo
# :samosval_l_uc!samosval_l_uc@samosval_l_uc.tmi.twitch.tv PRIVMSG #olesha :1000000
# 💬 [2025-03-20 22:51:42] [VALORANT] [mictia00] [santycosmic00]: quemo
# 📩 Meta data (246 byte): :chocs_!chocs_@chocs_.tmi.twitch.tv PRIVMSG #mooda :porch??
# :thisnameisjustsixwords!thisnameisjustsixwords@thisnameisjustsixwords.tmi.twitch.tv PRIVMSG #sgares :CONTROL YOURSELVES CHAT
# :dnd_222!dnd_222@dnd_222.tmi.twitch.tv PRIVMSG #foolish :om
# 💬 [2025-03-20 22:51:42] [VALORANT] [mooda] [chocs_]: porch??
# 📩 Meta data (104 byte): :magazencs!magazencs@magazencs.tmi.twitch.tv PRIVMSG #lobanjicaa :float 4x , Shaken 3x , valhalla 3x 3v3
# 💬 [2025-03-20 22:51:43] [Counter-Strike] [lobanjicaa] [magazencs]: float 4x , Shaken 3x , valhalla 3x 3v3
# 📩 Meta data (78 byte): :wavy200083!wavy200083@wavy200083.tmi.twitch.tv PRIVMSG #clix :use fncs picaxe
# 💬 [2025-03-20 22:51:43] [Fortnite] [clix] [wavy200083]: use fncs picaxe
# 📩 Meta data (236 byte): :walaier34!walaier34@walaier34.tmi.twitch.tv PRIVMSG #nissaxter :Qué más da xdd
# :sbotkin!sbotkin@sbotkin.tmi.twitch.tv PRIVMSG #smurf_tv :@VORUN5 выздоравливай!
# :danilgran_!danilgran_@danilgran_.tmi.twitch.tv PRIVMSG #olesha :66666666
# 💬 [2025-03-20 22:51:43] [League of Legends] [nissaxter] [walaier34]: Qué más da xdd
# 📩 Meta data (366 byte): :k7edi!k7edi@k7edi.tmi.twitch.tv PRIVMSG #lobanjicaa :nikoooooooooooooooooooooo
# :pr3st1ge12!pr3st1ge12@pr3st1ge12.tmi.twitch.tv PRIVMSG #valorant_northamerica :@respectedmale I'd have 3
# :chopy00!chopy00@chopy00.tmi.twitch.tv PRIVMSG #mictia00 :mm
# :bastero_ivan!bastero_ivan@bastero_ivan.tmi.twitch.tv PRIVMSG #mictia00 :ahora que vas a hacer esque acabo de entrar
# 💬 [2025-03-20 22:51:43] [Counter-Strike] [lobanjicaa] [k7edi]: nikoooooooooooooooooooooo
# 📩 Meta data (321 byte): :infinite0908!infinite0908@infinite0908.tmi.twitch.tv PRIVMSG #sgares :@deemunny27 lol wtf
# :cutltefish!cutltefish@cutltefish.tmi.twitch.tv PRIVMSG #olesha :987654321
# :johnyboyrl!johnyboyrl@johnyboyrl.tmi.twitch.tv PRIVMSG #dantes :@nonamebuthappy huh
# :gasha337!gasha337@gasha337.tmi.twitch.tv PRIVMSG #olesha :21032025
# 💬 [2025-03-20 22:51:43] [VALORANT] [sgares] [infinite0908]: @deemunny27 lol wtf
# 📩 Meta data (102 byte): :siegfried20771!siegfried20771@siegfried20771.tmi.twitch.tv PRIVMSG #nissaxter :!showemote Buhhloon  󠀀
# 💬 [2025-03-20 22:51:43] [League of Legends] [nissaxter] [siegfried20771]: !showemote Buhhloon  󠀀
# 📩 Meta data (405 byte): :businesspepega!businesspepega@businesspepega.tmi.twitch.tv PRIVMSG #olesha :95
# :maktniy!maktniy@maktniy.tmi.twitch.tv PRIVMSG #olesha :27
# :fossabot!fossabot@fossabot.tmi.twitch.tv PRIVMSG #mooda :SUB FOR THE BEST EMOTES ON TWITCH 👉 moodafSens moodafSquat moodafSound moodafFlowstate moodafYap moodafRage moodafGG moodafStare moodafMatrix moodafLove moodafJackripped moodafEyes moodafEminem moodaf9tails
# 💬 [2025-03-20 22:51:43] [Counter-Strike] [olesha] [businesspepega]: 95
# 📩 Meta data (246 byte): :ezeew01!ezeew01@ezeew01.tmi.twitch.tv PRIVMSG #strakatv :ashjdashjkasasdhjkhjkasasdhjkd
# :josephcamolle!josephcamolle@josephcamolle.tmi.twitch.tv PRIVMSG #xarola_ :tome
# :prikollisik!prikollisik@prikollisik.tmi.twitch.tv PRIVMSG #olesha :828 404
# 💬 [2025-03-20 22:51:43] [Counter-Strike] [strakatv] [ezeew01]: ashjdashjkasasdhjkhjkasasdhjkd
# 📩 Meta data (356 byte): :duckduck1237!duckduck1237@duckduck1237.tmi.twitch.tv PRIVMSG #cr_rion :えへへ
# :ytkazavrik!ytkazavrik@ytkazavrik.tmi.twitch.tv PRIVMSG #olesha :0987665
# :apenasfelipe1!apenasfelipe1@apenasfelipe1.tmi.twitch.tv PRIVMSG #sgares :@sgares Verno is a Spanish speaker, MIBR not speaking in English lets go
# :ookaee!ookaee@ookaee.tmi.twitch.tv PRIVMSG #mooda :NOWAY
# 💬 [2025-03-20 22:51:43] [VALORANT] [cr_rion] [duckduck1237]: えへへ
# 📩 Meta data (185 byte): :pacolo004!pacolo004@pacolo004.tmi.twitch.tv PRIVMSG #nissaxter :Que dice este mono color cucaracha
# :clapitotv!clapitotv@clapitotv.tmi.twitch.tv PRIVMSG #velja_lol :just play viego mid
# 💬 [2025-03-20 22:51:43] [League of Legends] [nissaxter] [pacolo004]: Que dice este mono color cucaracha
# 📩 Meta data (79 byte): :yaelsh2133!yaelsh2133@yaelsh2133.tmi.twitch.tv PRIVMSG #mictia00 :SJKLDADHAKDH
# 💬 [2025-03-20 22:51:43] [VALORANT] [mictia00] [yaelsh2133]: SJKLDADHAKDH
# 📩 Meta data (142 byte): :manuuuu__00!manuuuu__00@manuuuu__00.tmi.twitch.tv PRIVMSG #mictia00 :??
# :ziafv!ziafv@ziafv.tmi.twitch.tv PRIVMSG #clix :DO X/TWITCH GIVEAWAY
# 💬 [2025-03-20 22:51:43] [VALORANT] [mictia00] [manuuuu__00]: ??
# ✅ Data loaded into BigQuery: 20 rows
# 📩 Meta data (458 byte): :andre2411__!andre2411__@andre2411__.tmi.twitch.tv PRIVMSG #krokoboss :@latheless es wird sonntag jetzt
# :tiniyris!tiniyris@tiniyris.tmi.twitch.tv PRIVMSG #olesha :теперь это не закончится.
# :bluntbumpin!bluntbumpin@bluntbumpin.tmi.twitch.tv PRIVMSG #kamet0 :good kk meaning
# :lqgendi!lqgendi@lqgendi.tmi.twitch.tv PRIVMSG #b0rja :por la risa
# :surrealzeether!surrealzeether@surrealzeether.tmi.twitch.tv PRIVMSG #pobelter :one of the best blind pick junglers
# 💬 [2025-03-20 22:51:44] [League of Legends] [krokoboss] [andre2411__]: @latheless es wird sonntag jetzt
# 📩 Meta data (591 byte): :chaoticpunchie!chaoticpunchie@chaoticpunchie.tmi.twitch.tv PRIVMSG #mooda :SAY WALLAH
# :koro995!koro995@koro995.tmi.twitch.tv PRIVMSG #noway4u_sir :jetzt kommt der win
# :6khaa!6khaa@6khaa.tmi.twitch.tv PRIVMSG #olesha :123456
# :marungito!marungito@marungito.tmi.twitch.tv PRIVMSG #nissaxter :QUEREMOS QUE SE VAYA EL ÑAVI  PopNemo    FootYellow   QUEREMOS QUE SE VAYA EL ÑAVI  PopNemo    FootYellow   QUEREMOS QUE SE VAYA EL ÑAVI  PopNemo    FootYellow   QUEREMOS QUE SE VAYA EL ÑAVI  PopNemo    FootYellow   QUEREMOS QUE SE VAYA EL ÑAVI  PopNemo    FootYellow   QUEREMOS QUE SE VAYA EL ÑAVI
# 💬 [2025-03-20 22:51:44] [VALORANT] [mooda] [chaoticpunchie]: SAY WALLAH
# 📩 Meta data (232 byte): :lwzinn021!lwzinn021@lwzinn021.tmi.twitch.tv PRIVMSG #blackoutz :@bks_eduu nossa sim 👄👄👄
# :piyyy!piyyy@piyyy.tmi.twitch.tv PRIVMSG #lonely__me :даров
# :teozg123!teozg123@teozg123.tmi.twitch.tv PRIVMSG #velja_lol :bravo velja doktore
# 💬 [2025-03-20 22:51:44] [Fortnite] [blackoutz] [lwzinn021]: @bks_eduu nossa sim 👄👄👄
# 📩 Meta data (275 byte): :kimonoska!kimonoska@kimonoska.tmi.twitch.tv PRIVMSG #smurf_tv :@lolmasiro А дальше PausersHype
# :qtnecros!qtnecros@qtnecros.tmi.twitch.tv PRIVMSG #coreano :q posição a los ta?
# :speedialhooker!speedialhooker@speedialhooker.tmi.twitch.tv PRIVMSG #meilizzz :who is ur duoooooo
# 💬 [2025-03-20 22:51:44] [League of Legends] [smurf_tv] [kimonoska]: @lolmasiro А дальше PausersHype
# 📩 Meta data (274 byte): :risingshiningmoon!risingshiningmoon@risingshiningmoon.tmi.twitch.tv PRIVMSG #olesha :691337
# :briixtney!briixtney@briixtney.tmi.twitch.tv PRIVMSG #mooda :AINT NO WAY.
# :irisinferno!irisinferno@irisinferno.tmi.twitch.tv PRIVMSG #tubbo :sorry for ping peepoLove i fail emoted
# 💬 [2025-03-20 22:51:44] [Counter-Strike] [olesha] [risingshiningmoon]: 691337
# 📩 Meta data (332 byte): :pxon_!pxon_@pxon_.tmi.twitch.tv PRIVMSG #clix :can we 1v1
# :cherufee!cherufee@cherufee.tmi.twitch.tv PRIVMSG #nissaxter :203
# :xxgeee!xxgeee@xxgeee.tmi.twitch.tv PRIVMSG #jxness7 :´pode
# :femboy_uvvu!femboy_uvvu@femboy_uvvu.tmi.twitch.tv PRIVMSG #olesha :89
# :daviliyo_tq!daviliyo_tq@daviliyo_tq.tmi.twitch.tv PRIVMSG #tvander :sad
# 💬 [2025-03-20 22:51:44] [Fortnite] [clix] [pxon_]: can we 1v1
# 📩 Meta data (528 byte): :iuizim!iuizim@iuizim.tmi.twitch.tv PRIVMSG #suetam1v4 :KKKKKKKKKKKKKKKKKKK
# :gonzalorivero3656!gonzalorivero3656@gonzalorivero3656.tmi.twitch.tv PRIVMSG #rugaal :SeemsGood
# :yourgirlever!yourgirlever@yourgirlever.tmi.twitch.tv PRIVMSG #happyhappygal :heck yeah
# :teamlechpoznan7!teamlechpoznan7@teamlechpoznan7.tmi.twitch.tv PRIVMSG #mrdzinold :@w4lczak spoko
# :manucavalcanti!manucavalcanti@manucavalcanti.tmi.twitch.tv PRIVMSG #xarola_ :@biel_xt potiguar
# :anticonned!anticonned@anticonned.tmi.twitch.tv PRIVMSG #clix :suh bs
# 💬 [2025-03-20 22:51:44] [Fortnite] [suetam1v4] [iuizim]: KKKKKKKKKKKKKKKKKKK
# 📩 Meta data (103 byte): :amedelavallee!amedelavallee@amedelavallee.tmi.twitch.tv PRIVMSG #slipix :malgré ça ils ont win la game
# 💬 [2025-03-20 22:51:44] [League of Legends] [slipix] [amedelavallee]: malgré ça ils ont win la game
# 📩 Meta data (307 byte): :romzvac!romzvac@romzvac.tmi.twitch.tv PRIVMSG #lobanjicaa :ll Try Raw Loba Eyyyop, Crazy
# :wertolen!wertolen@wertolen.tmi.twitch.tv PRIVMSG #olesha :273892
# :unaqu_!unaqu_@unaqu_.tmi.twitch.tv PRIVMSG #olesha :151
# :not_cool_guy228!not_cool_guy228@not_cool_guy228.tmi.twitch.tv PRIVMSG #olesha :88000555355
# 💬 [2025-03-20 22:51:44] [Counter-Strike] [lobanjicaa] [romzvac]: ll Try Raw Loba Eyyyop, Crazy
# 📩 Meta data (379 byte): :ugrumtrip1!ugrumtrip1@ugrumtrip1.tmi.twitch.tv PRIVMSG #olesha :4080
# :nushoniok!nushoniok@nushoniok.tmi.twitch.tv PRIVMSG #olesha :5984
# :wikkent!wikkent@wikkent.tmi.twitch.tv PRIVMSG #olesha :322222 󠀀
# :momoniqiee!momoniqiee@momoniqiee.tmi.twitch.tv PRIVMSG #velja_lol :Lissandra mid?
# :bryanzz7!bryanzz7@bryanzz7.tmi.twitch.tv PRIVMSG #valorant_northamerica :mods xenofobicos
# 💬 [2025-03-20 22:51:44] [Counter-Strike] [olesha] [ugrumtrip1]: 4080
# 📩 Meta data (409 byte): :pelmenbskartoshkai!pelmenbskartoshkai@pelmenbskartoshkai.tmi.twitch.tv PRIVMSG #olesha :123
# :juanitoelmascapito00!juanitoelmascapito00@juanitoelmascapito00.tmi.twitch.tv PRIVMSG #mictia00 :bro encima con partner JDSADASJDASJDKJDS
# :elxavi_en_acapulco!elxavi_en_acapulco@elxavi_en_acapulco.tmi.twitch.tv PRIVMSG #nissaxter :que más da
# :reki99!reki99@reki99.tmi.twitch.tv PRIVMSG #locklear :dsl j'y crois pas
# 💬 [2025-03-20 22:51:44] [Counter-Strike] [olesha] [pelmenbskartoshkai]: 123
# 📩 Meta data (61 byte): :value1x!value1x@value1x.tmi.twitch.tv PRIVMSG #clix :Capping
# 💬 [2025-03-20 22:51:44] [Fortnite] [clix] [value1x]: Capping
# 📩 Meta data (227 byte): :taro_tanaka!taro_tanaka@taro_tanaka.tmi.twitch.tv PRIVMSG #cr_rion :ゆのしーよりrionのほうが抜ける
# :delegeend!delegeend@delegeend.tmi.twitch.tv PRIVMSG #lobanjicaa :176 Can you please open float for me you Will profit trust me @lobanjicaa
# 💬 [2025-03-20 22:51:44] [VALORANT] [cr_rion] [taro_tanaka]: ゆのしーよりrionのほうが抜ける
# 📩 Meta data (94 byte): :favula3!favula3@favula3.tmi.twitch.tv PRIVMSG #k1nzxn1kki :@nekeramdit227 так ебать воообще 0
# 💬 [2025-03-20 22:51:44] [Fortnite] [k1nzxn1kki] [favula3]: @nekeramdit227 так ебать воообще 0
# 📩 Meta data (266 byte): :mog1la_belausa!mog1la_belausa@mog1la_belausa.tmi.twitch.tv PRIVMSG #olesha :252525
# :beanieweenie123!beanieweenie123@beanieweenie123.tmi.twitch.tv PRIVMSG #happyhappygal :my little cousin was SO BAD too, I would have to shut off his Xbox from yelling and screaming!
# 💬 [2025-03-20 22:51:45] [Counter-Strike] [olesha] [mog1la_belausa]: 252525
# 📩 Meta data (97 byte): :jatethil_murilo!jatethil_murilo@jatethil_murilo.tmi.twitch.tv PRIVMSG #jxness7 :E live de Fort 🙃
# 💬 [2025-03-20 22:51:45] [Fortnite] [jxness7] [jatethil_murilo]: E live de Fort 🙃
# 📩 Meta data (495 byte): :santycosmic00!santycosmic00@santycosmic00.tmi.twitch.tv PRIVMSG #mictia00 :quemo mucho
# :itzshoff!itzshoff@itzshoff.tmi.twitch.tv PRIVMSG #lobanjicaa :28 | 3x Psycho, 3x Shaken, 3x Valhalla - 3v3 crazy jackpot
# :916joao!916joao@916joao.tmi.twitch.tv PRIVMSG #suetam1v4 :gg
# :andreuplanelless!andreuplanelless@andreuplanelless.tmi.twitch.tv PRIVMSG #rugaal :отрасти еще ниже бороду
# :tomzinhofdp_!tomzinhofdp_@tomzinhofdp_.tmi.twitch.tv PRIVMSG #k1ng :dudaste en leer el nombre fring estas pillo
# 💬 [2025-03-20 22:51:45] [VALORANT] [mictia00] [santycosmic00]: quemo mucho
# 📩 Meta data (84 byte): :wtb_roro!wtb_roro@wtb_roro.tmi.twitch.tv PRIVMSG #slipix :Suuuussssssssssssssssssss
# 💬 [2025-03-20 22:51:45] [League of Legends] [slipix] [wtb_roro]: Suuuussssssssssssssssssss
# 📩 Meta data (357 byte): :juli987654!juli987654@juli987654.tmi.twitch.tv PRIVMSG #noway4u_sir :jetzt mittlerweile 11 oder nicht?
# :criminalburrito!criminalburrito@criminalburrito.tmi.twitch.tv PRIVMSG #olesha :73784
# :chantellerose!chantellerose@chantellerose.tmi.twitch.tv PRIVMSG #happyhappygal :LOL. Does he still play?
# :xriot8!xriot8@xriot8.tmi.twitch.tv PRIVMSG #vadeal ::dion
# 💬 [2025-03-20 22:51:45] [League of Legends] [noway4u_sir] [juli987654]: jetzt mittlerweile 11 oder nicht?
# 📩 Meta data (447 byte): :kanuutuupk!kanuutuupk@kanuutuupk.tmi.twitch.tv PRIVMSG #mictia00 :wut?
# :edgar_onecc!edgar_onecc@edgar_onecc.tmi.twitch.tv PRIVMSG #mictia00 :Esprin
# :the_jq!the_jq@the_jq.tmi.twitch.tv PRIVMSG #tvander :@SoulHunter31 es que es eso, me hace gracia lo de "no puedo hacer nada, soy supp" en vez de "soy supp, pero solo para tirarme o protejero, no sé ser mago de apoyo" xdd
# :kanpeki____!kanpeki____@kanpeki____.tmi.twitch.tv PRIVMSG #olesha :88822
# 💬 [2025-03-20 22:51:45] [VALORANT] [mictia00] [kanuutuupk]: wut?
# ✅ Data loaded into BigQuery: 20 rows
# 📩 Meta data (492 byte): :nekokiti_jp!nekokiti_jp@nekokiti_jp.tmi.twitch.tv PRIVMSG #cr_rion :ゆのしーは抜ける
# :ezeew01!ezeew01@ezeew01.tmi.twitch.tv PRIVMSG #strakatv :torada
# :ysha03!ysha03@ysha03.tmi.twitch.tv PRIVMSG #cr_rion :えへへ
# :shaddrakon!shaddrakon@shaddrakon.tmi.twitch.tv PRIVMSG #blackoutz :cade a tela
# :soraaskyy!soraaskyy@soraaskyy.tmi.twitch.tv PRIVMSG #rugaal :!join
# :loganjay321!loganjay321@loganjay321.tmi.twitch.tv PRIVMSG #happyhappygal :type
# :ccor3xx!ccor3xx@ccor3xx.tmi.twitch.tv PRIVMSG #olesha :0
# 💬 [2025-03-20 22:51:45] [VALORANT] [cr_rion] [nekokiti_jp]: ゆのしーは抜ける
# 📩 Meta data (523 byte): :azethelost!azethelost@azethelost.tmi.twitch.tv PRIVMSG #jxness7 :Chat só pra mim q a qualidade tá ruim?
# :soiyer12!soiyer12@soiyer12.tmi.twitch.tv PRIVMSG #cr_rion :朝か
# :nakedbugz!nakedbugz@nakedbugz.tmi.twitch.tv PRIVMSG #olesha :984422
# :snrmirony!snrmirony@snrmirony.tmi.twitch.tv PRIVMSG #olesha :107
# :vi1m!vi1m@vi1m.tmi.twitch.tv PRIVMSG #noway4u_sir :Droppt doch bravery
# :savageronim0!savageronim0@savageronim0.tmi.twitch.tv PRIVMSG #happyhappygal :VirtualHug VirtualHug VirtualHug VirtualHug VirtualHug VirtualHug
# 💬 [2025-03-20 22:51:45] [Fortnite] [jxness7] [azethelost]: Chat só pra mim q a qualidade tá ruim?
# 📩 Meta data (331 byte): :tom270206!tom270206@tom270206.tmi.twitch.tv PRIVMSG #k1ng :jajajaja
# :fodziis_mentzen2025!fodziis_mentzen2025@fodziis_mentzen2025.tmi.twitch.tv PRIVMSG #mrdzinold :mychaaa
# :lui2k_beans!lui2k_beans@lui2k_beans.tmi.twitch.tv PRIVMSG #clix :when does the merch drop??
# :nickxzz_!nickxzz_@nickxzz_.tmi.twitch.tv PRIVMSG #suetam1v4 :K
# 💬 [2025-03-20 22:51:45] [Fortnite] [k1ng] [tom270206]: jajajaja
# 📩 Meta data (457 byte): :magazencs!magazencs@magazencs.tmi.twitch.tv PRIVMSG #lobanjicaa :float 4x , Shaken 3x , valhalla 3x 3v3  󠀀
# :aschfn!aschfn@aschfn.tmi.twitch.tv PRIVMSG #clix :eu
# :bashmak0310!bashmak0310@bashmak0310.tmi.twitch.tv PRIVMSG #olesha :48748
# :no_imeating!no_imeating@no_imeating.tmi.twitch.tv PRIVMSG #tubbo :ohno
# :ryftzk!ryftzk@ryftzk.tmi.twitch.tv PRIVMSG #pulgaboy :@fabricioymm delicia
# :unnamepro!unnamepro@unnamepro.tmi.twitch.tv PRIVMSG #olesha :999993
# 💬 [2025-03-20 22:51:45] [Counter-Strike] [lobanjicaa] [magazencs]: float 4x , Shaken 3x , valhalla 3x 3v3  󠀀
# 📩 Meta data (143 byte): :fyf4s!fyf4s@fyf4s.tmi.twitch.tv PRIVMSG #pobelter :kaiser soze Pog
# :dr_zhokovka!dr_zhokovka@dr_zhokovka.tmi.twitch.tv PRIVMSG #olesha :999998
# 💬 [2025-03-20 22:51:45] [League of Legends] [pobelter] [fyf4s]: kaiser soze Pog
# 📩 Meta data (260 byte): :mollita8!mollita8@mollita8.tmi.twitch.tv PRIVMSG #strakatv :que esta comiendo la gorda
# :pijayzinkk!pijayzinkk@pijayzinkk.tmi.twitch.tv PRIVMSG #xarola_ :que negócio horroroso
# :the_driver_123!the_driver_123@the_driver_123.tmi.twitch.tv PRIVMSG #mooda :PORCH?
# 💬 [2025-03-20 22:51:45] [Counter-Strike] [strakatv] [mollita8]: que esta comiendo la gorda
# 📩 Meta data (321 byte): :goddess__nyx!goddess__nyx@goddess__nyx.tmi.twitch.tv PRIVMSG #sgares :LETSGO
# :mr_dr_psinka!mr_dr_psinka@mr_dr_psinka.tmi.twitch.tv PRIVMSG #olesha :1716
# :pruzlaa!pruzlaa@pruzlaa.tmi.twitch.tv PRIVMSG #tvander :ojooooooooooo
# :rihazu!rihazu@rihazu.tmi.twitch.tv PRIVMSG #reventxz :poner la cancion de Ibai en el directo
# 💬 [2025-03-20 22:51:45] [VALORANT] [sgares] [goddess__nyx]: LETSGO
# 📩 Meta data (58 byte): :vykegod!vykegod@vykegod.tmi.twitch.tv PRIVMSG #olesha :28
# 💬 [2025-03-20 22:51:46] [Counter-Strike] [olesha] [vykegod]: 28
# 📩 Meta data (405 byte): :jim_picklecat00!jim_picklecat00@jim_picklecat00.tmi.twitch.tv PRIVMSG #mictia00 :JAKJSJAKSJAJSKAJSJAS
# :adriielo!adriielo@adriielo.tmi.twitch.tv PRIVMSG #strakatv :mentira q matee, se fue a buscar una docena de miga
# :svyatoy_otets02!svyatoy_otets02@svyatoy_otets02.tmi.twitch.tv PRIVMSG #olesha :96253
# :nend0la!nend0la@nend0la.tmi.twitch.tv PRIVMSG #mooda :@mooda Why not streaming with Yassin anymore?
# 💬 [2025-03-20 22:51:46] [VALORANT] [mictia00] [jim_picklecat00]: JAKJSJAKSJAJSKAJSJAS
# 📩 Meta data (230 byte): :itachik_tsuki!itachik_tsuki@itachik_tsuki.tmi.twitch.tv PRIVMSG #olesha :678543
# :abobarich!abobarich@abobarich.tmi.twitch.tv PRIVMSG #olesha :465454
# :gokuladasan!gokuladasan@gokuladasan.tmi.twitch.tv PRIVMSG #itsryanhiga :fishh
# 💬 [2025-03-20 22:51:46] [Counter-Strike] [olesha] [itachik_tsuki]: 678543
# 📩 Meta data (72 byte): :sants166!sants166@sants166.tmi.twitch.tv PRIVMSG #olui :mostra a tabela
# 💬 [2025-03-20 22:51:46] [Fortnite] [olui] [sants166]: mostra a tabela
# 📩 Meta data (471 byte): :pisceees!pisceees@pisceees.tmi.twitch.tv PRIVMSG #kamet0 :Clu3tiK j'ai tjrs pas lu en gros benzARRETE
# :magazencs!magazencs@magazencs.tmi.twitch.tv PRIVMSG #lobanjicaa :float 4x , Shaken 3x , valhalla 3x 3v3
# :sighxkatie!sighxkatie@sighxkatie.tmi.twitch.tv PRIVMSG #happyhappygal :mood
# :nicassj!nicassj@nicassj.tmi.twitch.tv PRIVMSG #k1ng :q onda thiago td bien
# :aucoeurlunaire!aucoeurlunaire@aucoeurlunaire.tmi.twitch.tv PRIVMSG #loupiote3 :Tu es en forme ce soir Lou
# 💬 [2025-03-20 22:51:46] [League of Legends] [kamet0] [pisceees]: Clu3tiK j'ai tjrs pas lu en gros benzARRETE
# 📩 Meta data (358 byte): :flux1lr!flux1lr@flux1lr.tmi.twitch.tv PRIVMSG #drututt :@rekkarten lube up your ass and widen those cheeks
# :mar0_r0!mar0_r0@mar0_r0.tmi.twitch.tv PRIVMSG #synd1cat :я догадывался что у мурза
# :titanfra!titanfra@titanfra.tmi.twitch.tv PRIVMSG #drututt :@47xbilal @47xbilal STONING
# :jjgapwdapjm!jjgapwdapjm@jjgapwdapjm.tmi.twitch.tv PRIVMSG #cr_rion :道を切り開く
# 💬 [2025-03-20 22:51:46] [League of Legends] [drututt] [flux1lr]: @rekkarten lube up your ass and widen those cheeks
# 📩 Meta data (413 byte): :iagolas_!iagolas_@iagolas_.tmi.twitch.tv PRIVMSG #tvander :El hacha por favor
# :streamelements!streamelements@streamelements.tmi.twitch.tv PRIVMSG #itsryanhiga :No luck, @GOKUladasan
# :nepridumalkekw!nepridumalkekw@nepridumalkekw.tmi.twitch.tv PRIVMSG #olesha :816612
# :brilacrf!brilacrf@brilacrf.tmi.twitch.tv PRIVMSG #blackoutz :gg
# :majcherokok!majcherokok@majcherokok.tmi.twitch.tv PRIVMSG #mrdzinold :MYCHAA
# 💬 [2025-03-20 22:51:46] [League of Legends] [tvander] [iagolas_]: El hacha por favor
# 📩 Meta data (392 byte): :krowlime!krowlime@krowlime.tmi.twitch.tv PRIVMSG #olesha :500000
# :techno_ac!techno_ac@techno_ac.tmi.twitch.tv PRIVMSG #reetlol :@scrge6 how?
# :pollomcfly!pollomcfly@pollomcfly.tmi.twitch.tv PRIVMSG #tvander :el hacha*
# :amedelavallee!amedelavallee@amedelavallee.tmi.twitch.tv PRIVMSG #slipix :ils sont si forts
# :panelinha_hd!panelinha_hd@panelinha_hd.tmi.twitch.tv PRIVMSG #olui :A exótica
# 💬 [2025-03-20 22:51:46] [Counter-Strike] [olesha] [krowlime]: 500000
# 📩 Meta data (364 byte): :kutob!kutob@kutob.tmi.twitch.tv PRIVMSG #olesha :666
# :gunner4ever95!gunner4ever95@gunner4ever95.tmi.twitch.tv PRIVMSG #velja_lol :Are u gonna ask for jg
# :wishkish!wishkish@wishkish.tmi.twitch.tv PRIVMSG #happyhappygal :real
# :1dozr!1dozr@1dozr.tmi.twitch.tv PRIVMSG #mooda :bro is rich
# :justxgolden!justxgolden@justxgolden.tmi.twitch.tv PRIVMSG #foolish :danse
# 💬 [2025-03-20 22:51:46] [Counter-Strike] [olesha] [kutob]: 666
# 📩 Meta data (788 byte): :vortex6924!vortex6924@vortex6924.tmi.twitch.tv PRIVMSG #mooda :porch??
# :cbbgamer!cbbgamer@cbbgamer.tmi.twitch.tv PRIVMSG #arrowcs :DARRYL
# :rain125_!rain125_@rain125_.tmi.twitch.tv PRIVMSG #lobanjicaa :7 2 1 4 5 LOBA TRY CRAZY MODE 3х Loba 3х GK68 3х Enchanted @Lobanjicaa
# :astigw!astigw@astigw.tmi.twitch.tv PRIVMSG #blackoutz :NICE PLAY
# :danicosmic00!danicosmic00@danicosmic00.tmi.twitch.tv PRIVMSG #mictia00 :que pudo?
# :kylmius!kylmius@kylmius.tmi.twitch.tv PRIVMSG #cr_rion :俺がやる！w
# :l1terz!l1terz@l1terz.tmi.twitch.tv PRIVMSG #olesha :123
# :samurmax!samurmax@samurmax.tmi.twitch.tv PRIVMSG #olesha :22814
# :taroteo!taroteo@taroteo.tmi.twitch.tv PRIVMSG #meilizzz :mp
# :ipk_1s!ipk_1s@ipk_1s.tmi.twitch.tv PRIVMSG #drututt :@47xbilal one day, one day i'll get it just wait STONING
# 💬 [2025-03-20 22:51:46] [VALORANT] [mooda] [vortex6924]: porch??
# 📩 Meta data (64 byte): :eql1pse_!eql1pse_@eql1pse_.tmi.twitch.tv PRIVMSG #clix :Capping
# 💬 [2025-03-20 22:51:46] [Fortnite] [clix] [eql1pse_]: Capping
# 📩 Meta data (158 byte): :amanduhz!amanduhz@amanduhz.tmi.twitch.tv PRIVMSG #foolish :Pog 40
# :caramelcookies923!caramelcookies923@caramelcookies923.tmi.twitch.tv PRIVMSG #cr_rion :えへへ
# 💬 [2025-03-20 22:51:46] [VALORANT] [foolish] [amanduhz]: Pog 40
# 📩 Meta data (287 byte): :goldmarystan!goldmarystan@goldmarystan.tmi.twitch.tv PRIVMSG #loltyler1 :help her you asshole
# :touakhang!touakhang@touakhang.tmi.twitch.tv PRIVMSG #xarola_ :çim
# :kedr1922!kedr1922@kedr1922.tmi.twitch.tv PRIVMSG #olesha :2010
# :uxiec!uxiec@uxiec.tmi.twitch.tv PRIVMSG #cr_rion :ヨルだの夜だの
# 💬 [2025-03-20 22:51:46] [League of Legends] [loltyler1] [goldmarystan]: help her you asshole
# ✅ Data loaded into BigQuery: 20 rows
# 📩 Meta data (80 byte): :ouchememe!ouchememe@ouchememe.tmi.twitch.tv PRIVMSG #drututt :@47xbilal STONING
# 💬 [2025-03-20 22:51:47] [League of Legends] [drututt] [ouchememe]: @47xbilal STONING
# 📩 Meta data (596 byte): :daniil_kabanelo!daniil_kabanelo@daniil_kabanelo.tmi.twitch.tv PRIVMSG #k1nzxn1kki :а не жадан фамилия
# :fanniereyes!fanniereyes@fanniereyes.tmi.twitch.tv PRIVMSG #foolish :@parsipator he wants to try the iso ult bait with E thats what i meant lol
# :override2095!override2095@override2095.tmi.twitch.tv PRIVMSG #tenz :!rank
# :nojitv1!nojitv1@nojitv1.tmi.twitch.tv PRIVMSG #cr_rion :朝だからいいんやで
# :lauwden!lauwden@lauwden.tmi.twitch.tv PRIVMSG #k1nzxn1kki :давай заику пж
# :airveste!airveste@airveste.tmi.twitch.tv PRIVMSG #olesha :0
# :backtoam!backtoam@backtoam.tmi.twitch.tv PRIVMSG #kubafps :!song
# 💬 [2025-03-20 22:51:47] [Fortnite] [k1nzxn1kki] [daniil_kabanelo]: а не жадан фамилия
# 📩 Meta data (544 byte): :marsik2751!marsik2751@marsik2751.tmi.twitch.tv PRIVMSG #olesha :0
# :jerzyyyyyyyy!jerzyyyyyyyy@jerzyyyyyyyy.tmi.twitch.tv PRIVMSG #kamet0 :Pisceees PepoDance qq
# :roik3en!roik3en@roik3en.tmi.twitch.tv PRIVMSG #meilizzz :what other sapnap is there
# :sandwichlemma!sandwichlemma@sandwichlemma.tmi.twitch.tv PRIVMSG #velja_lol :@clcifr because there is no rumblemut
# :briimoe!briimoe@briimoe.tmi.twitch.tv PRIVMSG #happyhappygal :love him to this day tho
# :mayumi397!mayumi397@mayumi397.tmi.twitch.tv PRIVMSG #cr_rion :リオンって舘野ひろとって名前なんや BloodTrail
# 💬 [2025-03-20 22:51:47] [Counter-Strike] [olesha] [marsik2751]: 0
# 📩 Meta data (230 byte): :ggugf875!ggugf875@ggugf875.tmi.twitch.tv PRIVMSG #mictia00 :JAJAJAJA
# :lilpullouttv2!lilpullouttv2@lilpullouttv2.tmi.twitch.tv PRIVMSG #loltyler1 :@woozypng LMFAO
# :splicemo!splicemo@splicemo.tmi.twitch.tv PRIVMSG #olesha :654321
# 💬 [2025-03-20 22:51:47] [VALORANT] [mictia00] [ggugf875]: JAJAJAJA
# 📩 Meta data (576 byte): :bridgette8!bridgette8@bridgette8.tmi.twitch.tv PRIVMSG #sommerset :i am so curious on who is #1 for points
# :rafikdz09!rafikdz09@rafikdz09.tmi.twitch.tv PRIVMSG #lobanjicaa :7 can you try mental,goalie,dig deep 3v3 on win @Lobanjicaa
# :rafazerazx!rafazerazx@rafazerazx.tmi.twitch.tv PRIVMSG #blackoutz :amasso
# :k7edi!k7edi@k7edi.tmi.twitch.tv PRIVMSG #lobanjicaa :trust nikoo brateee
# :kirohigesc!kirohigesc@kirohigesc.tmi.twitch.tv PRIVMSG #sacy :bao ta comendo esse bolo tem 2hr CORN
# :tryharddaestrela!tryharddaestrela@tryharddaestrela.tmi.twitch.tv PRIVMSG #suetam1v4 :K
# 💬 [2025-03-20 22:51:47] [Fortnite] [sommerset] [bridgette8]: i am so curious on who is #1 for points
# 📩 Meta data (148 byte): :maybesujan!maybesujan@maybesujan.tmi.twitch.tv PRIVMSG #mooda :NOWAYING
# :alexunstable!alexunstable@alexunstable.tmi.twitch.tv PRIVMSG #olesha :240
# 💬 [2025-03-20 22:51:47] [VALORANT] [mooda] [maybesujan]: NOWAYING
# 📩 Meta data (146 byte): :kot0psina!kot0psina@kot0psina.tmi.twitch.tv PRIVMSG #olesha :999999
# :beefman11211!beefman11211@beefman11211.tmi.twitch.tv PRIVMSG #rugaal :4Head
# 💬 [2025-03-20 22:51:47] [Counter-Strike] [olesha] [kot0psina]: 999999
# 📩 Meta data (591 byte): :leandro_f04!leandro_f04@leandro_f04.tmi.twitch.tv PRIVMSG #mictia00 :jajajajajaa
# :sugii11!sugii11@sugii11.tmi.twitch.tv PRIVMSG #mooda :porch
# :igabrielsilva_!igabrielsilva_@igabrielsilva_.tmi.twitch.tv PRIVMSG #xarola_ :Aproveita e corta o pé de pau do covil fazendo um favor
# :incarnar!incarnar@incarnar.tmi.twitch.tv PRIVMSG #drututt :DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM DRIP EDM
# :nicko1ai!nicko1ai@nicko1ai.tmi.twitch.tv PRIVMSG #arrowcs :?
# :sergdt1!sergdt1@sergdt1.tmi.twitch.tv PRIVMSG #strakatv :atragantuzzi
# 💬 [2025-03-20 22:51:47] [VALORANT] [mictia00] [leandro_f04]: jajajajajaa
# 📩 Meta data (194 byte): :freakcube_!freakcube_@freakcube_.tmi.twitch.tv PRIVMSG #kubafps :hast du mittlerweile den tactibear ? Kuba
# :lucaas_040!lucaas_040@lucaas_040.tmi.twitch.tv PRIVMSG #vadeal :@lumen_ayao UltraMad
# 💬 [2025-03-20 22:51:47] [VALORANT] [kubafps] [freakcube_]: hast du mittlerweile den tactibear ? Kuba
# 📩 Meta data (208 byte): :frizdoto12!frizdoto12@frizdoto12.tmi.twitch.tv PRIVMSG #olesha :53800
# :thiaguinhooloko2!thiaguinhooloko2@thiaguinhooloko2.tmi.twitch.tv PRIVMSG #xarola_ :reze do outro lado vc vai amassar ele toda hora kkkk
# 💬 [2025-03-20 22:51:47] [Counter-Strike] [olesha] [frizdoto12]: 53800
# 📩 Meta data (84 byte): :malenkiy_solovey!malenkiy_solovey@malenkiy_solovey.tmi.twitch.tv PRIVMSG #olesha :5
# 💬 [2025-03-20 22:51:47] [Counter-Strike] [olesha] [malenkiy_solovey]: 5
# 📩 Meta data (122 byte): :kvakags!kvakags@kvakags.tmi.twitch.tv PRIVMSG #olesha :098
# :h0pe1ka!h0pe1ka@h0pe1ka.tmi.twitch.tv PRIVMSG #olesha :15478
# 💬 [2025-03-20 22:51:47] [Counter-Strike] [olesha] [kvakags]: 098
# 📩 Meta data (668 byte): :streamelements!streamelements@streamelements.tmi.twitch.tv PRIVMSG #olesha :ТЕЛЕГРАМСКИЙ КАНАЛ: https://t.me/etoolesha uterShocked
# :duwap!duwap@duwap.tmi.twitch.tv PRIVMSG #arrowcs :i love unboxing videos
# :akaiyya!akaiyya@akaiyya.tmi.twitch.tv PRIVMSG #mooda :porch? whats that
# :hursopolar!hursopolar@hursopolar.tmi.twitch.tv PRIVMSG #xarola_ :Para de chorar e vai jogar carai
# :ak1or!ak1or@ak1or.tmi.twitch.tv PRIVMSG #olesha :69069
# :xalis_00!xalis_00@xalis_00.tmi.twitch.tv PRIVMSG #mictia00 :de la nada
# :alberquex!alberquex@alberquex.tmi.twitch.tv PRIVMSG #drututt :glorpNotL
# :helenwalkerwca!helenwalkerwca@helenwalkerwca.tmi.twitch.tv PRIVMSG #rugaal :!when
# 💬 [2025-03-20 22:51:48] [Counter-Strike] [olesha] [streamelements]: ТЕЛЕГРАМСКИЙ КАНАЛ: https://t.me/etoolesha uterShocked
# 📩 Meta data (311 byte): :facunitz!facunitz@facunitz.tmi.twitch.tv PRIVMSG #strakatv :Menos mal que esta a dieta la neta
# :angel_0600k!angel_0600k@angel_0600k.tmi.twitch.tv PRIVMSG #mictia00 :que pudo?
# :deddudka!deddudka@deddudka.tmi.twitch.tv PRIVMSG #olesha :5102013
# :cherufee!cherufee@cherufee.tmi.twitch.tv PRIVMSG #nissaxter :204
# 💬 [2025-03-20 22:51:48] [Counter-Strike] [strakatv] [facunitz]: Menos mal que esta a dieta la neta
# 📩 Meta data (556 byte): :fossabot!fossabot@fossabot.tmi.twitch.tv PRIVMSG #kubafps :▶️ blink-182 - "I Miss You" -> open.spotify.com/track/1AdYZ6X00nXmO613Y7GJOl | @backtoam
# :outputojisan!outputojisan@outputojisan.tmi.twitch.tv PRIVMSG #cr_rion :まだ余裕がある
# ...
# :nicko1ai!nicko1ai@nicko1ai.tmi.twitch.tv PRIVMSG #arrowcs :Ghost
# 💬 [2025-03-20 22:53:06] [Fortnite] [k1nzxn1kki] [ewei0ne2004]: некит пей  таблетки  пж, я переживаю за твое здоровье, мне кажется что ты можешь скончаться от передлоза спермы семикса во рту BigSad    BigSad
# 📩 Meta data (674 byte): :magistr2333!magistr2333@magistr2333.tmi.twitch.tv PRIVMSG #olesha :777777
# :kanpeki____!kanpeki____@kanpeki____.tmi.twitch.tv PRIVMSG #olesha :512431
# :obchan!obchan@obchan.tmi.twitch.tv PRIVMSG #otplol_ :@kouchnouf piero est trop intimidé par les énormes bras d'exa (ce que je peux comprendre)
# :mog1la_belausa!mog1la_belausa@mog1la_belausa.tmi.twitch.tv PRIVMSG #olesha :192837
# :bech_is_me!bech_is_me@bech_is_me.tmi.twitch.tv PRIVMSG #tenz :13 what chat??? whats 13????
# :lettuce_tt_00!lettuce_tt_00@lettuce_tt_00.tmi.twitch.tv PRIVMSG #mictia00 :uno de chiquito se impresiona con cualquier cosa
# :ralfkick!ralfkick@ralfkick.tmi.twitch.tv PRIVMSG #irissiri129 :Very good
# 💬 [2025-03-20 22:53:06] [Counter-Strike] [olesha] [magistr2333]: 777777
# 📩 Meta data (793 byte): :xferrecordsserum!xferrecordsserum@xferrecordsserum.tmi.twitch.tv PRIVMSG #mooda :you guys think that tenz can drive a car?
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #rugaal :🍆🍅FREE MONTHLY SUBSCRIPTIONS with Prime Gaming, make sure you subscribe to RUGAAL https://www.twitch.tv/subs/RUGAAL with you FREE Prime subscription that you get if you have Prime with AMAZON, remember you get !free prime subscription to give away every month ! 🍆
# :egsooov!egsooov@egsooov.tmi.twitch.tv PRIVMSG #olesha :89
# :prrato!prrato@prrato.tmi.twitch.tv PRIVMSG #tubbo :PogYou shout out redbull
# :moobot!moobot@moobot.tmi.twitch.tv PRIVMSG #rugaal :@MyAiBot • NO ADS will show for Prime Subscribers, Normal Subscribers, Gifted Subscribers. Consider supporting RUGAAL https://www.twitch.tv/subs/RUGAAL §
# 💬 [2025-03-20 22:53:06] [VALORANT] [mooda] [xferrecordsserum]: you guys think that tenz can drive a car?
# 📩 Meta data (804 byte): :mattelini!mattelini@mattelini.tmi.twitch.tv PRIVMSG #velja_lol :Hwei lol
# :streamlabs!streamlabs@streamlabs.tmi.twitch.tv PRIVMSG #rugaal :!bingo twitch 888
# :w1npel96!w1npel96@w1npel96.tmi.twitch.tv PRIVMSG #overdrivezzz :+
# :slip_siola14!slip_siola14@slip_siola14.tmi.twitch.tv PRIVMSG #slipix :C BEAU
# :lordfarquaadjunior!lordfarquaadjunior@lordfarquaadjunior.tmi.twitch.tv PRIVMSG #clix :bro did kovaaks for 5 minutes and thinks he gonna have the best aim
# :streamelements!streamelements@streamelements.tmi.twitch.tv PRIVMSG #rugaal :🍆🍅FREE MONTHLY SUBSCRIPTIONS with Prime Gaming, make sure you subscribe to RUGAAL https://www.twitch.tv/subs/RUGAAL with you FREE Prime subscription that you get if you have Prime with AMAZON, remember you get !free prime subscription to give away every month !gw 🍆
# 💬 [2025-03-20 22:53:06] [League of Legends] [velja_lol] [mattelini]: Hwei lol
# 📩 Meta data (160 byte): :darkstrikex!darkstrikex@darkstrikex.tmi.twitch.tv PRIVMSG #loltyler1 :swifties is insane vs olaf
# :cecibaa!cecibaa@cecibaa.tmi.twitch.tv PRIVMSG #foolish :breh
# 💬 [2025-03-20 22:53:06] [League of Legends] [loltyler1] [darkstrikex]: swifties is insane vs olaf
# 📩 Meta data (231 byte): :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #rugaal :!bingo twitch 13
# :hasskatso!hasskatso@hasskatso.tmi.twitch.tv PRIVMSG #olesha :443370
# :rooronavazoroo!rooronavazoroo@rooronavazoroo.tmi.twitch.tv PRIVMSG #velja_lol :hwei
# 💬 [2025-03-20 22:53:06] [Fortnite] [rugaal] [nightbot]: !bingo twitch 13
# 📩 Meta data (457 byte): :lolo__ab!lolo__ab@lolo__ab.tmi.twitch.tv PRIVMSG #mictia00 :yo tengo mi wii del 2008 sana y salva, me estoy jugando el mario galaxy ahora, gran juego
# :tsuminara!tsuminara@tsuminara.tmi.twitch.tv PRIVMSG #arrowcs :what's the 10th GOLD
# :streamelements!streamelements@streamelements.tmi.twitch.tv PRIVMSG #rugaal :@Streamlabs, there is already a bingo running
# :leonardopetinellii!leonardopetinellii@leonardopetinellii.tmi.twitch.tv PRIVMSG #blackoutz :tela
# 💬 [2025-03-20 22:53:06] [VALORANT] [mictia00] [lolo__ab]: yo tengo mi wii del 2008 sana y salva, me estoy jugando el mario galaxy ahora, gran juego
# 📩 Meta data (509 byte): :yazminn_juarez!yazminn_juarez@yazminn_juarez.tmi.twitch.tv PRIVMSG #mictia00 :HOLAA VENGO DE TIK TOK
# :popstar66!popstar66@popstar66.tmi.twitch.tv PRIVMSG #tubbo :FeelsWeakMan
# :exdraw_00!exdraw_00@exdraw_00.tmi.twitch.tv PRIVMSG #mictia00 :mictiPayaso mictiEstres mictiEstres mictiEstres
# :fossabot!fossabot@fossabot.tmi.twitch.tv PRIVMSG #rugaal :@Streamlabs Did you hear about the guy who invented Lifesavers? They say he made a mint.
# :ned0state!ned0state@ned0state.tmi.twitch.tv PRIVMSG #overdrivezzz :+
# 💬 [2025-03-20 22:53:06] [VALORANT] [mictia00] [yazminn_juarez]: HOLAA VENGO DE TIK TOK
# 📩 Meta data (843 byte): :malenkiy_solovey!malenkiy_solovey@malenkiy_solovey.tmi.twitch.tv PRIVMSG #olesha :555557
# :reskyone!reskyone@reskyone.tmi.twitch.tv PRIVMSG #smurf_tv :почему не ботинки? @Smurf_tv
# :auntjeansslave!auntjeansslave@auntjeansslave.tmi.twitch.tv PRIVMSG #loltyler1 :kurwa
# :kenjiro2023!kenjiro2023@kenjiro2023.tmi.twitch.tv PRIVMSG #cr_rion :仕事行ってくるわ。案件配信楽しみにしてるぜ。
# :amanduhz!amanduhz@amanduhz.tmi.twitch.tv PRIVMSG #foolish :foolishPrime foolishPrime
# :nathanjzn!nathanjzn@nathanjzn.tmi.twitch.tv PRIVMSG #xarola_ :vai deixar, hellen?
# :wmwmwmwmwmwmmmwmwmwmwmwmw!wmwmwmwmwmwmmmwmwmwmwmwmw@wmwmwmwmwmwmmmwmwmwmwmwmw.tmi.twitch.tv PRIVMSG #olesha :112176
# :streamelements!streamelements@streamelements.tmi.twitch.tv PRIVMSG #rugaal :@Nightbot, there is already a bingo running
# :didiercito!didiercito@didiercito.tmi.twitch.tv PRIVMSG #tvander :KOMO
# 💬 [2025-03-20 22:53:06] [Counter-Strike] [olesha] [malenkiy_solovey]: 555557
# 📩 Meta data (325 byte): :tiori1708!tiori1708@tiori1708.tmi.twitch.tv PRIVMSG #overdrivezzz :+
# :nekeramdit227!nekeramdit227@nekeramdit227.tmi.twitch.tv PRIVMSG #k1nzxn1kki :САБАЙТЕСЬ НА ЮТУБ ГДЕ ВЫХОДЯТ ЗАПИСИ И НАРЕЗКИ ПО НЕКЕТУ: https://www.youtube.com/@n1kkifn_fan_narezki
# :lencon_na!lencon_na@lencon_na.tmi.twitch.tv PRIVMSG #cr_rion :デデンデデン👈うそ
# 💬 [2025-03-20 22:53:06] [Counter-Strike] [overdrivezzz] [tiori1708]: +
# 📩 Meta data (381 byte): :bracizo!bracizo@bracizo.tmi.twitch.tv PRIVMSG #mictia00 :Cuando creces todo se hace deprimente
# :yoconduscoloko!yoconduscoloko@yoconduscoloko.tmi.twitch.tv PRIVMSG #tvander :KEK
# :fossabot!fossabot@fossabot.tmi.twitch.tv PRIVMSG #rugaal :@Nightbot What do you call a monkey in a mine field? A babooooom!
# :yutsuki_0331!yutsuki_0331@yutsuki_0331.tmi.twitch.tv PRIVMSG #cr_rion :マ！？
# 💬 [2025-03-20 22:53:06] [VALORANT] [mictia00] [bracizo]: Cuando creces todo se hace deprimente
# 📩 Meta data (132 byte): :nushoniok!nushoniok@nushoniok.tmi.twitch.tv PRIVMSG #olesha :828404
# :value1x!value1x@value1x.tmi.twitch.tv PRIVMSG #clix :Clueless
# 💬 [2025-03-20 22:53:06] [Counter-Strike] [olesha] [nushoniok]: 828404
# 📩 Meta data (262 byte): :yuan_yuan08!yuan_yuan08@yuan_yuan08.tmi.twitch.tv PRIVMSG #mictia00 :jajjaja
# :llabut!llabut@llabut.tmi.twitch.tv PRIVMSG #overdrivezzz :+
# :ryoumal!ryoumal@ryoumal.tmi.twitch.tv PRIVMSG #cr_rion :慢心
# :nyan184!nyan184@nyan184.tmi.twitch.tv PRIVMSG #cr_rion :慢心王
# 💬 [2025-03-20 22:53:07] [VALORANT] [mictia00] [yuan_yuan08]: jajjaja
# 📩 Meta data (215 byte): :lilowr1!lilowr1@lilowr1.tmi.twitch.tv PRIVMSG #dynquedo1 :k
# :sceurbe!sceurbe@sceurbe.tmi.twitch.tv PRIVMSG #kamet0 :0-7 awaree
# :taroteo!taroteo@taroteo.tmi.twitch.tv PRIVMSG #meilizzz :thirsting over a mans voice
# 💬 [2025-03-20 22:53:07] [League of Legends] [dynquedo1] [lilowr1]: k
# 📩 Meta data (305 byte): :h0pe1ka!h0pe1ka@h0pe1ka.tmi.twitch.tv PRIVMSG #olesha :45624
# :kronosxz7!kronosxz7@kronosxz7.tmi.twitch.tv PRIVMSG #olui :Opa
# :heit0rfn!heit0rfn@heit0rfn.tmi.twitch.tv PRIVMSG #olui :GANHARAM COM MINGUIN HIGH E TUDO  GG
# :llmousexll!llmousexll@llmousexll.tmi.twitch.tv PRIVMSG #tvander :rey de realities
# 💬 [2025-03-20 22:53:07] [Counter-Strike] [olesha] [h0pe1ka]: 45624
# 📩 Meta data (272 byte): :arsen00122!arsen00122@arsen00122.tmi.twitch.tv PRIVMSG #overdrivezzz :+
# :sinui_yong!sinui_yong@sinui_yong.tmi.twitch.tv PRIVMSG #olesha :12355
# :w3ula!w3ula@w3ula.tmi.twitch.tv PRIVMSG #olesha :434343
# :unnamepro!unnamepro@unnamepro.tmi.twitch.tv PRIVMSG #olesha :736245
# 💬 [2025-03-20 22:53:07] [Counter-Strike] [overdrivezzz] [arsen00122]: +
# 📩 Meta data (543 byte): :isabellou!isabellou@isabellou.tmi.twitch.tv PRIVMSG #velja_lol :HWEI VELJAAA ITS TIME
# :melentiy!melentiy@melentiy.tmi.twitch.tv PRIVMSG #olesha :576432
# :nekeramdit227!nekeramdit227@nekeramdit227.tmi.twitch.tv PRIVMSG #k1nzxn1kki :САБАЙТЕСЬ НА ЮТУБ ГДЕ ВЫХОДЯТ ЗАПИСИ И НАРЕЗКИ ПО НЕКЕТУ: https://www.youtube.com/@n1kkifn_fan_narezki 󠀀
# :pipapipipupu!pipapipipupu@pipapipipupu.tmi.twitch.tv PRIVMSG #olesha :476321
# :crippledgrandson!crippledgrandson@crippledgrandson.tmi.twitch.tv PRIVMSG #batmanbugha :i'd win lan with visual and carry him
# 💬 [2025-03-20 22:53:07] [League of Legends] [velja_lol] [isabellou]: HWEI VELJAAA ITS TIME
# ✅ Data loaded into BigQuery: 20 rows
# 📩 Meta data (380 byte): :sherl0kbr!sherl0kbr@sherl0kbr.tmi.twitch.tv PRIVMSG #olui :susu no end.
# :redupse!redupse@redupse.tmi.twitch.tv PRIVMSG #olesha :100100
# :gunner4ever95!gunner4ever95@gunner4ever95.tmi.twitch.tv PRIVMSG #velja_lol :Karma.
# :allieee____!allieee____@allieee____.tmi.twitch.tv PRIVMSG #sommerset :wtf is the command
# :mrpatchjo!mrpatchjo@mrpatchjo.tmi.twitch.tv PRIVMSG #tenz :13 ???
# 💬 [2025-03-20 22:53:07] [Fortnite] [olui] [sherl0kbr]: susu no end.
# 📩 Meta data (658 byte): :koga4070!koga4070@koga4070.tmi.twitch.tv PRIVMSG #cr_rion :慢心
# :l1terz!l1terz@l1terz.tmi.twitch.tv PRIVMSG #olesha :4747
# :nombremuyloco!nombremuyloco@nombremuyloco.tmi.twitch.tv PRIVMSG #arrowcs :@LeeFall1 CS never gets merch. He needs to farm this.
# :thepxrker!thepxrker@thepxrker.tmi.twitch.tv PRIVMSG #blackoutz :Chique demais essa testa
# :mayhr42!mayhr42@mayhr42.tmi.twitch.tv PRIVMSG #happyhappygal :5k???
# :ninelpo!ninelpo@ninelpo.tmi.twitch.tv PRIVMSG #olesha :123987
# :nekeramdit227!nekeramdit227@nekeramdit227.tmi.twitch.tv PRIVMSG #k1nzxn1kki :САБАЙТЕСЬ НА ЮТУБ ГДЕ ВЫХОДЯТ ЗАПИСИ И НАРЕЗКИ ПО НЕКЕТУ: https://www.youtube.com/@n1kkifn_fan_narezki
# 💬 [2025-03-20 22:53:07] [VALORANT] [cr_rion] [koga4070]: 慢心
# 📩 Meta data (106 byte): :heronhykeiloveurmom!heronhykeiloveurmom@heronhykeiloveurmom.tmi.twitch.tv PRIVMSG #synd1cat :1070 moment?
# 💬 [2025-03-20 22:53:07] [Counter-Strike] [synd1cat] [heronhykeiloveurmom]: 1070 moment?
# 📩 Meta data (502 byte): :killerschep!killerschep@killerschep.tmi.twitch.tv PRIVMSG #eggsterr :flyin
# :thatvivtor1!thatvivtor1@thatvivtor1.tmi.twitch.tv PRIVMSG #sommerset :Sommerset, are you A RUSSIAN SPY, OR A RUSSIAN MONKEY?
# :anticonned!anticonned@anticonned.tmi.twitch.tv PRIVMSG #clix :Clueless
# :truefirestarter!truefirestarter@truefirestarter.tmi.twitch.tv PRIVMSG #overdrivezzz :+
# :bks_eduu!bks_eduu@bks_eduu.tmi.twitch.tv PRIVMSG #blackoutz :Se continuar essa tela até o final eu nn vou aguentar a minha ereção black
# 💬 [2025-03-20 22:53:07] [VALORANT] [eggsterr] [killerschep]: flyin
# 📩 Meta data (325 byte): :rgnirn!rgnirn@rgnirn.tmi.twitch.tv PRIVMSG #reventxz :Jajaj
# :nekeramdit227!nekeramdit227@nekeramdit227.tmi.twitch.tv PRIVMSG #k1nzxn1kki :САБАЙТЕСЬ НА ЮТУБ ГДЕ ВЫХОДЯТ ЗАПИСИ И НАРЕЗКИ ПО НЕКЕТУ: https://www.youtube.com/@n1kkifn_fan_narezki 󠀀
# :julianojjpro!julianojjpro@julianojjpro.tmi.twitch.tv PRIVMSG #blackoutz :calma
# 💬 [2025-03-20 22:53:07] [League of Legends] [reventxz] [rgnirn]: Jajaj
# 📩 Meta data (110 byte): :hernannnnnn_!hernannnnnn_@hernannnnnn_.tmi.twitch.tv PRIVMSG #nikomfps :¡Feliz aniversario de socio! PartyHat
# 💬 [2025-03-20 22:53:07] [Counter-Strike] [nikomfps] [hernannnnnn_]: ¡Feliz aniversario de socio! PartyHat
# 📩 Meta data (233 byte): :motionjon!motionjon@motionjon.tmi.twitch.tv PRIVMSG #aussieantics :eugh
# :pipimpoli!pipimpoli@pipimpoli.tmi.twitch.tv PRIVMSG #olesha :1456
# :pxon_!pxon_@pxon_.tmi.twitch.tv PRIVMSG #clix :pls give me the bundle bro i will send 100$
# 💬 [2025-03-20 22:53:07] [Fortnite] [aussieantics] [motionjon]: eugh
# 📩 Meta data (365 byte): :pruzlaa!pruzlaa@pruzlaa.tmi.twitch.tv PRIVMSG #tvander :HUH
# :twilightlight3!twilightlight3@twilightlight3.tmi.twitch.tv PRIVMSG #zemie :where can we get mythic minigun
# :prikollisik!prikollisik@prikollisik.tmi.twitch.tv PRIVMSG #olesha :31 042
# :orozimbotryhard!orozimbotryhard@orozimbotryhard.tmi.twitch.tv PRIVMSG #blackoutz :Assistir fncs❌assistir o blackoutz❎
# 💬 [2025-03-20 22:53:07] [League of Legends] [tvander] [pruzlaa]: HUH
# 📩 Meta data (75 byte): :gabrielpcms01!gabrielpcms01@gabrielpcms01.tmi.twitch.tv PRIVMSG #olui :ixi
# 💬 [2025-03-20 22:53:08] [Fortnite] [olui] [gabrielpcms01]: ixi
# 📩 Meta data (55 byte): :ntnak!ntnak@ntnak.tmi.twitch.tv PRIVMSG #cr_rion :マー？！
# 💬 [2025-03-20 22:53:08] [VALORANT] [cr_rion] [ntnak]: マー？！
# 📩 Meta data (60 byte): :unaqu_!unaqu_@unaqu_.tmi.twitch.tv PRIVMSG #olesha :4075151
# 💬 [2025-03-20 22:53:08] [Counter-Strike] [olesha] [unaqu_]: 4075151
# 📩 Meta data (254 byte): :fittlallarn!fittlallarn@fittlallarn.tmi.twitch.tv PRIVMSG #drututt :@47xbilal STONING
# :fortnitenoobsnetwork!fortnitenoobsnetwork@fortnitenoobsnetwork.tmi.twitch.tv PRIVMSG #clix :oh man
# :esus1337!esus1337@esus1337.tmi.twitch.tv PRIVMSG #olesha :322322
# 💬 [2025-03-20 22:53:08] [League of Legends] [drututt] [fittlallarn]: @47xbilal STONING
# 📩 Meta data (145 byte): :silentarks!silentarks@silentarks.tmi.twitch.tv PRIVMSG #velja_lol :Xddd
# :stinnnaler!stinnnaler@stinnnaler.tmi.twitch.tv PRIVMSG #olesha :464839
# 💬 [2025-03-20 22:53:08] [League of Legends] [velja_lol] [silentarks]: Xddd
# 📩 Meta data (73 byte): :zhentekk!zhentekk@zhentekk.tmi.twitch.tv PRIVMSG #stewie2k :Wooting only
# 💬 [2025-03-20 22:53:08] [Counter-Strike] [stewie2k] [zhentekk]: Wooting only
# 📩 Meta data (289 byte): :chopy00!chopy00@chopy00.tmi.twitch.tv PRIVMSG #mictia00 :XDDDD
# :0haytex0!0haytex0@0haytex0.tmi.twitch.tv PRIVMSG #olesha :885433
# :bracizo!bracizo@bracizo.tmi.twitch.tv PRIVMSG #mictia00 :She
# :juseterror!juseterror@juseterror.tmi.twitch.tv PRIVMSG #smurf_tv :Что не гнара первым тарить?
# 💬 [2025-03-20 22:53:08] [VALORANT] [mictia00] [chopy00]: XDDDD
# 📩 Meta data (181 byte): :aguirredylan16!aguirredylan16@aguirredylan16.tmi.twitch.tv PRIVMSG #mictia00 :Poco a poco se apaga todo XD
# :kostyan2757!kostyan2757@kostyan2757.tmi.twitch.tv PRIVMSG #olesha :4460
# 💬 [2025-03-20 22:53:08] [VALORANT] [mictia00] [aguirredylan16]: Poco a poco se apaga todo XD
# 📩 Meta data (178 byte): :fredocalol!fredocalol@fredocalol.tmi.twitch.tv PRIVMSG #dynquedo1 :DYNKAS O ABSOL TA EM UMA CONTA CHAMADA RESENHUDA JOGANDO DE AKALI FICANDO 0/10 SUJANDO SEU NOME VEI @Dynquedo1
# 💬 [2025-03-20 22:53:08] [League of Legends] [dynquedo1] [fredocalol]: DYNKAS O ABSOL TA EM UMA CONTA CHAMADA RESENHUDA JOGANDO DE AKALI FICANDO 0/10 SUJANDO SEU NOME VEI @Dynquedo1
# 📩 Meta data (233 byte): :kirill229856!kirill229856@kirill229856.tmi.twitch.tv PRIVMSG #overdrivezzz :+
# :nepridumalkekw!nepridumalkekw@nepridumalkekw.tmi.twitch.tv PRIVMSG #olesha :228
# :zard_d!zard_d@zard_d.tmi.twitch.tv PRIVMSG #overdrivezzz :шахта теплая
# 💬 [2025-03-20 22:53:08] [Counter-Strike] [overdrivezzz] [kirill229856]: +
# 📩 Meta data (215 byte): :ki11beun!ki11beun@ki11beun.tmi.twitch.tv PRIVMSG #olesha :0,5
# :r_ddevil!r_ddevil@r_ddevil.tmi.twitch.tv PRIVMSG #tvander :HUH
# :alexyach!alexyach@alexyach.tmi.twitch.tv PRIVMSG #nissaxter :que buena F seño ramadam
# 💬 [2025-03-20 22:53:08] [Counter-Strike] [olesha] [ki11beun]: 0,5
# 📩 Meta data (103 byte): :roberthernandezmva!roberthernandezmva@roberthernandezmva.tmi.twitch.tv PRIVMSG #rugaal :Ночь или день?
# 💬 [2025-03-20 22:53:08] [Fortnite] [rugaal] [roberthernandezmva]: Ночь или день?
# ✅ Data loaded into BigQuery: 20 rows
# 📩 Meta data (282 byte): :hertezx!hertezx@hertezx.tmi.twitch.tv PRIVMSG #suetam1v4 :@
# :vince7482!vince7482@vince7482.tmi.twitch.tv PRIVMSG #clix :when does FNCS start’
# :lis8dil!lis8dil@lis8dil.tmi.twitch.tv PRIVMSG #cr_rion :日本語で頼むわ
# :foxyghosty!foxyghosty@foxyghosty.tmi.twitch.tv PRIVMSG #olesha :880055
# 💬 [2025-03-20 22:53:09] [Fortnite] [suetam1v4] [hertezx]: @
