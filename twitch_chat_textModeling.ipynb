# %% [markdown]
# # Environment setup

# %%
# !pip install irc
# Out:
# Collecting irc
#   Downloading irc-20.5.0-py3-none-any.whl.metadata (10 kB)
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting jaraco.collections (from irc)
#   Downloading jaraco.collections-5.1.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting jaraco.text>=3.14 (from irc)
#   Downloading jaraco.text-4.0.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting jaraco.logging (from irc)
#   Downloading jaraco.logging-3.3.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jaraco.functools>=1.20 in /usr/local/lib/python3.11/dist-packages (from irc) (4.1.0)
# Collecting jaraco.stream (from irc)
#   Downloading jaraco.stream-3.0.4-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from irc) (2025.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from irc) (10.7.0)
# Collecting tempora>=1.6 (from irc)
#   Downloading tempora-5.8.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from irc) (6.5.2)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.31.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.5.0)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/local/lib/python3.11/dist-packages (from jaraco.text>=3.14->irc) (6.0.1)
# Collecting autocommand (from jaraco.text>=3.14->irc)
#   Downloading autocommand-2.2.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: backports.tarfile in /usr/local/lib/python3.11/dist-packages (from jaraco.context>=4.1->jaraco.text>=3.14->irc) (1.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Downloading irc-20.5.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 5.5 MB/s eta 0:00:00
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 11.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/363.4 MB 144.0 MB/s eta 0:00:03
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.0 MB/s eta 0:00:00
# Downloading jaraco.text-4.0.0-py3-none-any.whl (11 kB)
# Downloading tempora-5.8.0-py3-none-any.whl (14 kB)
# Downloading jaraco.collections-5.1.0-py3-none-any.whl (11 kB)
# Downloading jaraco.logging-3.3.0-py3-none-any.whl (4.8 kB)
# Downloading jaraco.stream-3.0.4-py3-none-any.whl (6.1 kB)
# Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# ERROR: THESE PACKAGES DO NOT MATCH THE HASHES FROM THE REQUIREMENTS FILE. If you have updated the package versions, please update the hashes. Otherwise, examine the package contents carefully; someone may have tampered with them.
#     unknown package:
#         Expected sha256 2fc8da60df463fdefa81e323eef2e36489e1c94335b5358bcb38360adf75ac9b
#              Got        8cdf8ff2b7168f5a1e1532a919960345bca70345c76820c8d4b5decaf5f85940

# %%
# !pip install bertopic sentence-transformers transformers torch
# Out:
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.31.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 9.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 836.3 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bertopic
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bertopic-0.17.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
import re
import time
import socket
import requests
import pandas as pd
from datetime import datetime
from threading import Thread, Lock
import pytz
from google.colab import drive

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ================== Google Drive Mount ==================
drive.mount('/content/drive')

# ================== Configuration ==================
CLIENT_ID = "gp762nuuoqcoxypju8c569th9wz7q5"
OAUTH_TOKEN = "oauth:mb053vdgfqc0u2m7folpig78vgxdke"
USERNAME = "danieljia36"
IRC_SERVER = "irc.chat.twitch.tv"
IRC_PORT = 6667

GAME_LIST = [
    "League of Legends", "Counter-Strike", "Grand Theft Auto V",
    "Assassin's Creed Shadows", "Fortnite", "VALORANT",
    "Marvel Rivals", "Apex Legends", "Rainbow Six Siege"
]

MAX_CHANNELS = 100
OUTPUT_DIR = "/content/drive/MyDrive/twitch_chat_logs"
os.makedirs(OUTPUT_DIR, exist_ok=True)
local_tz = pytz.timezone("Europe/London")

sock = None
sock_lock = Lock()
joined_channels = {}
last_message_time = time.time()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Store data into Google drive

# %% [markdown]
# ## New version of data aquisition

# %%
def get_output_file():
    today = datetime.now(local_tz).strftime("%Y%m%d")
    return os.path.join(OUTPUT_DIR, f"twitch_chat_log_{today}.csv")

def insert_chat_data_batch(rows):
    if not rows:
        return
    output_file = get_output_file()
    if os.path.isdir(output_file):
        print(f"❌ Error: {output_file} is a directory.")
        return
    df = pd.DataFrame(rows)
    file_exists = os.path.isfile(output_file)
    df.to_csv(output_file, mode='a', index=False, encoding='utf-8', header=not file_exists)
    print(f"✅ Appended {len(rows)} rows to {output_file}")

# ================== Twitch IRC Connection ==================
def connect():
    global sock
    while True:
        try:
            s = socket.socket()
            s.settimeout(60)
            s.connect((IRC_SERVER, IRC_PORT))
            s.send(f"PASS {OAUTH_TOKEN}\n".encode("utf-8"))
            s.send(f"NICK {USERNAME}\n".encode("utf-8"))
            print("✅ Connected to Twitch IRC")
            with sock_lock:
                sock = s
            return s
        except Exception as e:
            print(f"⚠️ connect() error: {e}, retrying in 10s")
            time.sleep(10)

# ================== Twitch API ==================
def get_game_ids(game_names):
    headers = {
        "Client-ID": CLIENT_ID,
        "Authorization": f"Bearer {OAUTH_TOKEN.split(':')[1]}"
    }
    game_ids = {}
    for name in game_names:
        response = requests.get("https://api.twitch.tv/helix/games", headers=headers, params={"name": name})
        if response.status_code == 200:
            data = response.json()
            for game in data.get("data", []):
                game_ids[game["name"]] = game["id"]
        else:
            print(f"❌ Failed to get game ID: {name} → {response.text}")
    return game_ids

def get_live_channels(game_ids):
    headers = {
        "Client-ID": CLIENT_ID,
        "Authorization": f"Bearer {OAUTH_TOKEN.split(':')[1]}"
    }
    live_channels = {}
    for game_name, game_id in game_ids.items():
        params = {"game_id": game_id, "first": 20}
        response = requests.get("https://api.twitch.tv/helix/streams", headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()
            live_channels[game_name] = [stream["user_login"] for stream in data.get("data", [])]
        else:
            print(f"❌ Failed to get streams for {game_name}: {response.text}")
    return live_channels

# ================== Channel Connection ==================
def connect_to_channel(s, channel, game_name):
    try:
        s.send(f"JOIN #{channel}\n".encode("utf-8"))
        joined_channels[channel] = game_name
        print(f"✅ Joined channel: {channel} (game: {game_name})")
    except Exception as e:
        print(f"❌ Join error: {channel} → {e}")
        new_sock = connect()
        connect_to_channel(new_sock, channel, game_name)

# ================== Chat Listening ==================
def listen_chat():
    global sock, last_message_time
    buffer = []
    last_flush = time.time()
    while True:
        print("💬 Listening to chat...")
        try:
            with sock_lock:
                s = sock
            try:
                resp = s.recv(2048).decode("utf-8").strip()
            except socket.timeout:
                print("⚠️ 60s no messages, reconnecting...")
                s = connect()
                continue

            if not resp:
                print("⚠️ Empty message, reconnecting...")
                s = connect()
                continue

            last_message_time = time.time()

            if resp.startswith("PING"):
                s.send("PONG :tmi.twitch.tv\n".encode("utf-8"))
                continue

            if "JOIN" in resp:
                print(f"✅ Join confirmation: {resp}")
                continue

            if "PRIVMSG" in resp:
                try:
                    user_name = re.search(r":(\w+)!", resp).group(1)
                    message_match = re.search(r"PRIVMSG #([\w]+) :(.*)", resp)
                    channel = message_match.group(1)
                    chat_message = message_match.group(2)
                    timestamp = datetime.now(local_tz).strftime("%Y-%m-%d %H:%M:%S")
                    game_name = joined_channels.get(channel, "Unknown Game")
                    row = {
                        "timestamp": timestamp,
                        "game_name": game_name,
                        "channel": channel,
                        "user_name": user_name,
                        "message": chat_message
                    }
                    buffer.append(row)
                    if len(buffer) >= 20 or (time.time() - last_flush) >= 5:
                        insert_chat_data_batch(buffer)
                        buffer.clear()
                        last_flush = time.time()
                except Exception as parse_e:
                    print(f"❌ Parse error: {parse_e}")
                    continue

        except (socket.error, BrokenPipeError) as e:
            print(f"⚠️ Connection error: {e}, reconnecting...")
            s = connect()
            continue
        except Exception as e:
            print(f"⚠️ Unexpected error: {e}")
            time.sleep(5)
            continue

# ================== Channel Updater ==================
def update_channels():
    global sock
    game_ids = get_game_ids(GAME_LIST)
    while True:
        if len(joined_channels) >= MAX_CHANNELS:
            print(f"⚠️ Reached max channels {MAX_CHANNELS}, sleeping 5 mins...")
            time.sleep(300)
            continue

        live_channels = get_live_channels(game_ids)
        for game_name, channels in live_channels.items():
            for channel in channels:
                if len(joined_channels) >= MAX_CHANNELS:
                    break
                with sock_lock:
                    s = sock
                if channel not in joined_channels:
                    connect_to_channel(s, channel, game_name)
                    time.sleep(2)
        time.sleep(60)

# ================== Watchdog Thread ==================
def watchdog():
    global sock, last_message_time
    while True:
        if time.time() - last_message_time > 120:
            print("⚠️ 120s no messages, watchdog triggering reconnect...")
            with sock_lock:
                try:
                    sock.close()
                except:
                    pass
                sock = connect()
            last_message_time = time.time()
        time.sleep(30)

# %%
# ================== Main Entry ==================
if __name__ == "__main__":
    sock = connect()
    Thread(target=listen_chat, daemon=True).start()
    Thread(target=update_channels, daemon=True).start()
    Thread(target=watchdog, daemon=True).start()
    while True:
        time.sleep(60)
# Out:
# ✅ Connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: thebausffs (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #thebausffs
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: caedrel (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #caedrel
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: lol_nemesis (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #lol_nemesis
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #lol_nemesis :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #lol_nemesis :End of /NAMES list
# 💬 Listening to chat...
# ✅ Appended 6 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: alfrea (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #alfrea
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: traytonlol (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #traytonlol
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Appended 14 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: yoda (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #yoda
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: esportmaniacos (game: League of Legends)
# 💬 Listening to chat...
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #esportmaniacos
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #esportmaniacos :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #esportmaniacos :End of /NAMES list
# :berran1999!berran1999@berran1999.tmi.twitch.tv PRIVMSG #caedrel :EWWW
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Appended 20 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: rekkles (game: League of Legends)
# 💬 Listening to chat...
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #rekkles
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #rekkles :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #rekkles :End of /NAMES list
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Appended 20 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: miiisyan (game: League of Legends)
# 💬 Listening to chat...
# ✅ Join confirmation: :tonygb231!tonygb231@tonygb231.tmi.twitch.tv PRIVMSG #caedrel :EWWW
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #miiisyan
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #miiisyan :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #miiisyan :End of /NAMES list
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: waolol1 (game: League of Legends)
# 💬 Listening to chat...
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #waolol1
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Appended 20 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: tolkin (game: League of Legends)
# 💬 Listening to chat...
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #tolkin
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #tolkin :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #tolkin :End of /NAMES list
# :spongbo8!spongbo8@spongbo8.tmi.twitch.tv PRIVMSG #thebausffs :LO
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: rybsonlol_ (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #rybsonlol_
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Appended 20 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: asiagodtonegg3be0 (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #asiagodtonegg3be0
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: yukiofps14 (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #yukiofps14
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #yukiofps14 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #yukiofps14 :End of /NAMES list
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Appended 20 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: karni (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #karni
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: wakzlol (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #wakzlol
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Appended 20 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: santorin (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #santorin
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ✅ Joined channel: crownie_lol (game: League of Legends)
# ✅ Join confirmation: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #crownie_lol
# 💬 Listening to chat...
# ✅ Appended 20 rows to /content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250512.csv
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# 💬 Listening to chat...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e119270f3846> in <cell line: 0>()
#       6     Thread(target=watchdog, daemon=True).start()
#       7     while True:
# ----> 8         time.sleep(60)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Old version

# %%
def connect():
    global sock
    while True:
        try:
            s = socket.socket()
            s.settimeout(60)
            s.connect((IRC_SERVER, IRC_PORT))
            s.send(f"PASS {OAUTH_TOKEN}\n".encode("utf-8"))
            s.send(f"NICK {USERNAME}\n".encode("utf-8"))
            print("✅ connected to Twitch IRC")
            with sock_lock:
                sock = s
            return s
        except Exception as e:
            print(f"⚠ connection failed，try again in 10s...: {e}")
            time.sleep(10)

OUTPUT_FILE = "/content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv"
def insert_chat_data_batch(rows):
    """ 追加聊天数据到同一个 CSV 文件 """
    if not rows:
        return
    df = pd.DataFrame(rows)
    # 检查文件是否存在
    file_exists = os.path.isfile(OUTPUT_FILE)
    # 追加写入，第一次写入时带 header，之后不带 header
    df.to_csv(OUTPUT_FILE, mode='a', index=False, encoding='utf-8', header=not file_exists)
    print(f"✅ inserted {len(rows)} of data into {OUTPUT_FILE}")

def get_game_ids(game_names):
    headers = {
        "Client-ID": CLIENT_ID,
        "Authorization": f"Bearer {OAUTH_TOKEN.split(':')[1]}"
    }
    game_ids = {}
    for name in game_names:
        response = requests.get(GAMES_API_URL, headers=headers, params={"name": name})
        if response.status_code == 200:
            data = response.json()
            for game in data.get("data", []):
                game_ids[game["name"]] = game["id"]
        else:
            print(f"failed to get game id ({name}): {response.text}")
    return game_ids

def get_live_channels(game_ids):
    headers = {
        "Client-ID": CLIENT_ID,
        "Authorization": f"Bearer {OAUTH_TOKEN.split(':')[1]}"
    }
    live_channels = {}
    for game_name, game_id in game_ids.items():
        params = {"game_id": game_id, "first": 20}
        response = requests.get(API_URL, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()
            live_channels[game_name] = [stream["user_login"] for stream in data.get("data", [])]
        else:
            print(f"get {game_name} stream list failed: {response.text}")
    return live_channels

def connect_to_channel(s, channel, game_name):
    try:
        s.send(f"JOIN #{channel}\n".encode("utf-8"))
        joined_channels[channel] = game_name
        print(f"joined channel: {channel} (game: {game_name})")
    except Exception as e:
        print(f"join channel {channel} fail: {e}")
        new_sock = connect()
        connect_to_channel(new_sock, channel, game_name)


# Max channel number
MAX_CHANNELS = 100

# the last timestamp received
last_message_time = time.time()

def listen_chat():
    global sock, last_message_time
    buffer = []
    last_flush = time.time()
    while True:
        print("💬 Listening to chat...")
        try:
            with sock_lock:
                s = sock
            try:
                resp = s.recv(2048).decode("utf-8").strip()
            except socket.timeout:
                print("⚠️ socket timeout，reconnecting...")
                s = connect()
                continue

            if not resp:
                print("⚠️ empty message，reconnecting...")
                s = connect()
                continue

            last_message_time = time.time()

            if resp.startswith("PING"):
                s.send("PONG :tmi.twitch.tv\n".encode("utf-8"))
                continue

            if "JOIN" in resp:
                print(f"✅ Joined channel: {resp}")
                continue

            if "PRIVMSG" in resp:
                try:
                    user_name = re.search(r":(\w+)!", resp).group(1)
                    message_match = re.search(r"PRIVMSG #([\w]+) :(.*)", resp)
                    channel = message_match.group(1)
                    chat_message = message_match.group(2)
                    timestamp = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
                    game_name = joined_channels.get(channel, "Unknown Game")
                    row = {
                        "timestamp": timestamp,
                        "game_name": game_name,
                        "channel": channel,
                        "user_name": user_name,
                        "message": chat_message
                    }
                    buffer.append(row)
                    if len(buffer) >= 20 or (time.time() - last_flush) >= 5:
                        insert_chat_data_batch(buffer)
                        buffer.clear()
                        last_flush = time.time()
                except Exception as parse_e:
                    print(f"❌ Parse message filed: {parse_e}")
                    continue

        except (socket.error, BrokenPipeError) as e:
            print(f"⚠️ Connection error: {e}，reconnecting...")
            s = connect()
            continue
        except Exception as e:
            print(f"⚠️ Unknown error in listening process: {e}")
            time.sleep(5)
            continue

def update_channels():
    global sock
    game_ids = get_game_ids(GAME_LIST)
    while True:
        live_channels = get_live_channels(game_ids)
        for game_name, channels in live_channels.items():
            for channel in channels:
                if len(joined_channels) >= MAX_CHANNELS:
                    print(f"⚠️ Reached maximum channels {MAX_CHANNELS}，stop joining new channels")
                    break
                with sock_lock:
                    s = sock
                if channel not in joined_channels:
                    connect_to_channel(s, channel, game_name)
                    time.sleep(2)
        time.sleep(60)

def watchdog():
    global sock, last_message_time
    while True:
        if time.time() - last_message_time > 120:
            print("⚠️ 120 s no new messages，force to reconnect...")
            with sock_lock:
                try:
                    sock.close()
                except Exception:
                    pass
                sock = connect()
            last_message_time = time.time()
        time.sleep(30)  # check every 30s

# %%
if __name__ == "__main__":
    sock = connect()
    t_listen = Thread(target=listen_chat, daemon=True)
    t_update = Thread(target=update_channels, daemon=True)
    t_watchdog = Thread(target=watchdog, daemon=True)
    t_listen.start()
    t_update.start()
    t_watchdog.start()
    t_listen.join()
    t_update.join()
    t_watchdog.join()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ socket timeout，reconnecting...
# ✅ connected to Twitch IRC
# 💬 Listening to chat...
# 💬 Listening to chat...
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels
# ⚠️ Reached maximum channels 100，stop joining new channels

# %% [markdown]
# # EDA

# %%
# Define file paths in Google Drive
file1 = "/content/drive/MyDrive/twitch_chat_logs/twitch_chat_log20250509.csv"
file2 = "/content/drive/MyDrive/twitch_chat_logs/twitch_chat_log_20250511.csv"

# Read CSV files
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Combine into a single DataFrame
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.dtypes
# Out:
# timestamp    object
# game_name    object
# channel      object
# user_name    object
# message      object
# dtype: object

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.dtypes
# Out:
# timestamp    datetime64[ns]
# game_name            object
# channel              object
# user_name            object
# message              object
# dtype: object

# %%
df.head()
# Out:
#             timestamp          game_name  channel         user_name  \
# 0 2025-05-09 10:49:34  League of Legends  caedrel  darkness_enjoyer
# 1 2025-05-09 10:49:35  League of Legends  caedrel             caypr
# 2 2025-05-09 10:49:36  League of Legends  caedrel      sherlocksone
# 3 2025-05-09 10:49:36  League of Legends  caedrel          nemzza98
# 4 2025-05-09 10:49:36  League of Legends  caedrel             gcsam
#
#                                              message
# 0  UltraMad "plinkers"    UltraMad "plinkers"    ...
# 1        https://www.youtube.com/watch?v=zbtenEGXpoM
# 2                                              DORAT
# 3  showmaker STINKERS showmaker STINKERS showmake...
# 4                                              DORAT

# %%
df.isnull().sum()
# Out:
# timestamp     0
# game_name     0
# channel       0
# user_name     0
# message      18
# dtype: int64

# %%
# Pivot for plotting
pivot = message_counts.pivot(index='hour', columns='date', values='message_count')

# Plot with markers
ax = pivot.plot(kind='line', marker='o', figsize=(12, 6))
plt.title("Message Volume per Hour by Date")
plt.xlabel("Hour of Day")
plt.ylabel("Message Count")
plt.grid(True)
plt.legend(title="Date")
plt.tight_layout()

# Add data labels
for date in pivot.columns:
    for hour, count in pivot[date].dropna().items():
        ax.text(hour, count + 1000, f'{int(count)}', ha='center', fontsize=8)

plt.show()

# %%
# Group by game_name and channel to count messages
game_channel_counts = df.groupby(['game_name', 'channel']).size().reset_index(name='message_count')

# Pivot for heatmap
heatmap_data = game_channel_counts.pivot(index='game_name', columns='channel', values='message_count').fillna(0)

# Plot heatmap
plt.figure(figsize=(14, 6))
sns.heatmap(heatmap_data, cmap="YlGnBu", linewidths=0.5)
plt.title("Message Count by Game and Channel")
plt.xlabel("Channel")
plt.ylabel("Game")
plt.tight_layout()
plt.show()

# %%
df["date"] = df["timestamp"].dt.date
df["hour"] = df["timestamp"].dt.hour

# %%
df1 = df[
    (df["date"] == pd.to_datetime("2025-05-09").date()) &
    (df["hour"].between(14, 15))
]

# %%
df2 = df[
    (df["date"] == pd.to_datetime("2025-05-11").date()) &
    (df["hour"].between(21, 22))
]

# %%
def plot_heatmap(dataframe, title):
    count_matrix = dataframe.groupby(["game_name", "channel"]).size().unstack(fill_value=0)
    plt.figure(figsize=(10, 6))
    sns.heatmap(count_matrix,
                annot=False, # do not show data values.
                fmt="d",
                cmap="YlOrRd")
    plt.title(title)
    plt.xlabel("Channel")
    plt.ylabel("Game Name")
    plt.tight_layout()
    plt.show()

# %%
plot_heatmap(df1, "Message Count Heatmap (2025-05-09 14:00–16:00)")

# %%
plot_heatmap(df2, "Message Count Heatmap (2025-05-11 21:00–23:00)")

# %% [markdown]
# check how many messages each user generate during each session.

# %%
user_msg_count_1 = df1["user_name"].value_counts()
user_msg_count_2 = df2["user_name"].value_counts()

# %%
plt.figure(figsize=(14, 5))

# Session 1
plt.subplot(1, 2, 1)
user_msg_count_1.plot(kind="hist", bins=30, color="skyblue", edgecolor="black")
plt.title("Message Count Distribution per User (2025-05-09 14:00–16:00)")
plt.xlabel("Message Count")
plt.ylabel("Number of Users")

# Session 2
plt.subplot(1, 2, 2)
user_msg_count_2.plot(kind="hist", bins=30, color="salmon", edgecolor="black")
plt.title("Message Count Distribution per User (2025-05-11 21:00–23:00)")
plt.xlabel("Message Count")
plt.ylabel("Number of Users")

plt.tight_layout()
plt.show()

# %%
print("Session 1（2025-05-09 14–16）")
print(user_msg_count_1.describe())
# Out:
# Session 1（2025-05-09 14–16）
# count    22634.000000
# mean         6.886631
# std         37.046123
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max       3925.000000
# Name: count, dtype: float64

# %%
print("\nSession 2（2025-05-11 21–23）")
print(user_msg_count_2.describe())
# Out:
# Session 2（2025-05-11 21–23）
# count    26673.000000
# mean         5.416526
# std         20.227178
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max       1863.000000
# Name: count, dtype: float64

# %% [markdown]
# check how many words each message contain.

# %%
# length of each message
df1.loc[:, "msg_length"] = df1["message"].str.len()
print(df1["msg_length"].describe())
# Out:
# count    155871.000000
# mean         23.992468
# std          37.252603
# min           1.000000
# 25%           5.000000
# 50%          12.000000
# 75%          28.000000
# max         501.000000
# Name: msg_length, dtype: float64

# %%
# length of each message
df2.loc[:, "msg_length"] = df2["message"].str.len()
print(df2["msg_length"].describe())
# Out:
# count    144463.000000
# mean         25.427570
# std          35.595809
# min           1.000000
# 25%           6.000000
# 50%          15.000000
# 75%          31.000000
# max         500.000000
# Name: msg_length, dtype: float64
# <ipython-input-27-563444e180db>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:, "msg_length"] = df2["message"].str.len()

# %%
plt.figure(figsize=(12, 5))

# message length of df1
plt.subplot(1, 2, 1)
df1["msg_length"].plot(kind="hist", bins=50, color="skyblue", edgecolor="black")
plt.title("Message Length Distribution (2025-05-09 14–16)")
plt.xlabel("Message Length (chars)")
plt.ylabel("Number of Messages")

# message length of df2
plt.subplot(1, 2, 2)
df2["msg_length"].plot(kind="hist", bins=50, color="salmon", edgecolor="black")
plt.title("Message Length Distribution (2025-05-11 21–23)")
plt.xlabel("Message Length (chars)")
plt.ylabel("Number of Messages")

plt.tight_layout()
plt.show()

# %% [markdown]
# check for some active games, the distribution of message amounts and length.

# %%
games_df1 = ["Counter-Strike", "Fortnite", "Grand Theft Auto V", "Marvel Rivals", "VALORANT"]
games_df2 = ["Counter-Strike", "Fortnite", "Grand Theft Auto V", "League of Legends", "VALORANT"]

# %%
def print_game_describe(df, games, session_name):
    for game in games:
        print(f"\n====== {session_name} - {game} ======")

        game_df = df[df["game_name"] == game]

        # message count per user
        user_counts = game_df["user_name"].value_counts()
        print("\nUser Message Count (per user):")
        print(user_counts.describe())

        # messagen length descriptives.
        msg_lengths = game_df["message"].str.len()
        print("\nMessage Length (per message):")
        print(msg_lengths.describe())

# %%
print_game_describe(df1, games_df1, "Session 1 (2025-05-09)")
# Out:
# ====== Session 1 (2025-05-09) - Counter-Strike ======
#
# User Message Count (per user):
# count    5950.000000
# mean        5.415294
# std        17.947959
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max       857.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    32221.000000
# mean        24.746315
# std         32.523298
# min          1.000000
# 25%          5.000000
# 50%         14.000000
# 75%         30.000000
# max        497.000000
# Name: message, dtype: float64
#
# ====== Session 1 (2025-05-09) - Fortnite ======
#
# User Message Count (per user):
# count    3858.000000
# mean       10.413427
# std        56.202013
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         7.000000
# max      2404.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    40175.000000
# mean        33.133815
# std         51.945414
# min          1.000000
# 25%          7.000000
# 50%         17.000000
# 75%         39.000000
# max        496.000000
# Name: message, dtype: float64
#
# ====== Session 1 (2025-05-09) - Grand Theft Auto V ======
#
# User Message Count (per user):
# count    5294.000000
# mean        6.394787
# std        13.457414
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       228.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    33854.000000
# mean        15.341614
# std         20.934689
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         18.000000
# max        499.000000
# Name: message, dtype: float64
#
# ====== Session 1 (2025-05-09) - Marvel Rivals ======
#
# User Message Count (per user):
# count    1918.000000
# mean        5.093848
# std        10.275524
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       161.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    9770.000000
# mean       23.452712
# std        40.984565
# min         1.000000
# 25%         6.000000
# 50%        13.000000
# 75%        26.000000
# max       499.000000
# Name: message, dtype: float64
#
# ====== Session 1 (2025-05-09) - VALORANT ======
#
# User Message Count (per user):
# count    6162.000000
# mean        6.080331
# std        18.510723
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       926.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    37466.00000
# mean        20.34223
# std         28.25591
# min          1.00000
# 25%          4.00000
# 50%         11.00000
# 75%         27.00000
# max        501.00000
# Name: message, dtype: float64

# %%
print_game_describe(df2, games_df2, "Session 2 (2025-05-11)")
# Out:
# ====== Session 2 (2025-05-11) - Counter-Strike ======
#
# User Message Count (per user):
# count    5286.000000
# mean        4.234960
# std        15.662259
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max       854.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    22386.000000
# mean        29.830564
# std         39.491132
# min          1.000000
# 25%          6.000000
# 50%         18.000000
# 75%         37.000000
# max        499.000000
# Name: message, dtype: float64
#
# ====== Session 2 (2025-05-11) - Fortnite ======
#
# User Message Count (per user):
# count    4486.000000
# mean        6.528979
# std        23.437089
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       991.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    29282.000000
# mean        27.277884
# std         41.391218
# min          1.000000
# 25%          6.000000
# 50%         15.000000
# 75%         32.000000
# max        499.000000
# Name: message, dtype: float64
#
# ====== Session 2 (2025-05-11) - Grand Theft Auto V ======
#
# User Message Count (per user):
# count    8874.000000
# mean        5.770228
# std        13.119424
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       248.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    51200.000000
# mean        23.305937
# std         29.340690
# min          1.000000
# 25%          6.000000
# 50%         14.000000
# 75%         30.000000
# max        500.000000
# Name: message, dtype: float64
#
# ====== Session 2 (2025-05-11) - League of Legends ======
#
# User Message Count (per user):
# count    5049.000000
# mean        5.404833
# std        13.271863
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max       311.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    27289.000000
# mean        24.240536
# std         35.137956
# min          1.000000
# 25%          6.000000
# 50%         14.000000
# 75%         29.000000
# max        496.000000
# Name: message, dtype: float64
#
# ====== Session 2 (2025-05-11) - VALORANT ======
#
# User Message Count (per user):
# count    2912.000000
# mean        4.120536
# std         9.372271
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max       205.000000
# Name: count, dtype: float64
#
# Message Length (per message):
# count    11999.000000
# mean        19.774398
# std         30.398781
# min          1.000000
# 25%          4.000000
# 50%         11.000000
# 75%         24.000000
# max        464.000000
# Name: message, dtype: float64

# %%
def plot_game_stats(df, games, title_prefix):
    fig, axes = plt.subplots(2, len(games), figsize=(5 * len(games), 8))

    for i, game in enumerate(games):
        game_df = df[df["game_name"] == game]

        # message count per user
        user_counts = game_df["user_name"].value_counts()
        axes[0, i].hist(user_counts, bins=30, color="skyblue", edgecolor="black")
        axes[0, i].set_title(f"{title_prefix} - {game}\nUser Message Count")
        axes[0, i].set_xlabel("Messages per User")
        axes[0, i].set_ylabel("User Count")

        # messagen length descriptives.
        msg_lengths = game_df["message"].str.len()
        axes[1, i].hist(msg_lengths, bins=50, color="salmon", edgecolor="black")
        axes[1, i].set_title(f"{title_prefix} - {game}\nMessage Length")
        axes[1, i].set_xlabel("Message Length (chars)")
        axes[1, i].set_ylabel("Message Count")

    plt.tight_layout()
    plt.show()

# %%
plot_game_stats(df1, games_df1, "Session 1 (2025-05-09)")

# %%
plot_game_stats(df2, games_df2, "Session 2 (2025-05-11)")

# %% [markdown]
# We choose active games with longer messages (median no less than 15 words) to do text modeling after studying the distribution of message amount and length.

# %% [markdown]
# # Text modeling

# %% [markdown]
# ## Pipeline

# %% [markdown]
# **1. Text Preprocessing**
#
# Normalize text: lowercasing, punctuation removal, optional emoji preservation
#
# Remove stopwords and domain-specific noise (e.g., “lol”, “ez”, streamer names)
#
# Tokenization and optional lemmatization/stemming
#
# Optionally, construct a domain-aware vocabulary (e.g., game slang, emotes)
#
# **2. Exploratory Text Analysis**
#
# Word frequency analysis (unigrams, bigrams)
#
# Frequency comparison across games, time segments, or user types
#
# Visualizations: bar plots, word clouds, time-trend plots
#
# **3. Sentiment Analysis**
#
# Apply pretrained social-media-specific sentiment models (e.g., cardiffnlp/twitter-roberta-base-sentiment)
#
# Analyze sentiment distribution across time, games, or channels
#
# Visualizations: sentiment timelines, pie charts, histograms
#
# **4. Semantic Topic Modeling & Clustering**
#
# Generate dense embeddings using Sentence-BERT (all-MiniLM-L6-v2, etc.)
#
# Perform topic modeling with BERTopic (BERT + clustering + topic keywords)
#
# Optional alternatives: HDBSCAN + UMAP or KMeans
#
# Visualize topic structures and topic evolution over time
#
# **5. Text Clustering & Similarity Analysis**
#
# Use semantic embeddings for clustering chats by content similarity
#
# Identify patterns across user segments, games, or message intent
#
# Visualizations: t-SNE/UMAP plots, cluster-level heatmaps
#
# **6. Toxicity & Emotion Classification**
#
# Use open-source models like unitary/toxic-bert to detect harmful content
#
# Fine-tune classifiers for multi-class emotion detection (optional)
#
# Flag messages for moderation or user profiling
#
# **7. LLM-based Topic Extraction (Optional)**
#
# Leverage open-source LLMs (e.g., NousResearch/Hermes-2-Mistral-7B) to extract topic summaries in natural language
#
# Prompt LLMs to produce keywords or structured themes from chat windows
#
# Suitable for zero-shot or few-shot topic summarization
#
# **8. Temporal Analysis**
#
# Track word/topic/sentiment changes over time intervals
#
# Detect temporal bursts, hype spikes, or sentiment drops
#
# Visualizations: time-series plots, animated topic flows
#
# **9. Interactive Visualization (Optional)**
#
# Build dashboards or visual reports using:
#
# pyLDAvis (for topics)
#
# plotly, Altair, or streamlit (for user-facing UIs)
#
# Word clouds, cluster projections, trend plots

# %% [markdown]
# ## Ssession2 Counter-Strike

# %%
df2_cs = df[
    (df["date"] == pd.to_datetime("2025-05-11").date()) &
    (df["hour"].between(21, 22)) &
    (df["game_name"] == "Counter-Strike")
].copy()

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch

# 1. 准备数据
texts = df2_cs["message"].astype(str).tolist()

# 2. 情绪分析模型加载（CardiffNLP）
tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
labels = ['negative', 'neutral', 'positive']
device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

def get_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=128).to(device)
    with torch.no_grad():
        logits = model(**inputs).logits
    scores = softmax(logits.cpu().numpy()[0])
    return labels[np.argmax(scores)]

# 3. 执行情绪预测（可选：抽样处理或 tqdm）
df2_cs["sentiment"] = df2_cs["message"].apply(get_sentiment)

# 4. 使用 Sentence-BERT 提取语义嵌入
embedding_model = SentenceTransformer("all-MiniLM-L6-v2", device="cuda")
embeddings = embedding_model.encode(texts, show_progress_bar=True)

# 5. BERTopic 建模
topic_model = BERTopic(verbose=True)
topics, probs = topic_model.fit_transform(texts, embeddings)

# 6. 可视化话题结构
topic_model.visualize_barchart(top_n_topics=10)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/700 [00:00<?, ?it/s]
# 2025-05-16 13:35:05,712 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-16 13:35:55,314 - BERTopic - Dimensionality - Completed ✓
# 2025-05-16 13:35:55,316 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-16 13:36:00,155 - BERTopic - Cluster - Completed ✓
# 2025-05-16 13:36:00,167 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-16 13:36:00,510 - BERTopic - Representation - Completed ✓
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="58749b5c-b5de-4b00-a4db-038fc1ff2ef4" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58749b5c-b5de-4b00-a4db-038fc1ff2ef4")) {                    Plotly.newPlot(                        "58749b5c-b5de-4b00-a4db-038fc1ff2ef4",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.00001,0.5794631412812086,0.5975726683532878,0.6637014216458494,1.1968729356955115],"y":["  ","save  ","life  ","please  ","pleasure  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.021554372003130994,0.021567962719261397,0.02203035214116906,0.034283638960608195,0.036219236700682174],"y":["ideomitsu  ","raybetboom  ","gbcccccc666  ","roman7781  ","mirioshi  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.010933405969303369,0.011219217087717686,0.011565132249583021,0.012945936783890942,0.013952548287845224],"y":["mas  ","sporting  ","para  ","de  ","que  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.01687955460344812,0.017653803454727755,0.01865634982486371,0.018886211895329828,0.02492047016482862],"y":["jak  ","ale  ","si  ","bo  ","nie  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.06652720178684249,0.07562058685847238,0.08159108651217437,0.08372741561299583,0.08372741561299583],"y":["sergizwf  ","evilsecret  ","leniniw  ","yourwaterfull  ","bronadotrenirovatsya  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.05311457355430274,0.0644788074939484,0.07967186033145411,0.14462916110426774,0.14712232806217657],"y":["passion  ","stilltriplev  ","000  ","leniniw  ","popnemo  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.01728341758752664,0.018103954683071005,0.02088600609270016,0.02197854795780587,0.027893640592555672],"y":["hat  ","noch  ","ist  ","das  ","ich  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.17644803600310222,0.2279757972753355,0.2279757972753355,0.2279757972753355,1.4348611117439452],"y":["doom  ","2322  ","exile  ","condom  ","gaypride  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.12432252621323625,0.12432252621323625,0.13802519400337482,0.15572227246602394,0.20762969662136527],"y":["28112024  ","forz9r  ","usps  ","theilluminati  ","httpstmekasanof33  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.00001,0.00001,0.00001,0.00001,0.5455804698190392],"y":["  ","  ","  ","  ","winline  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...

# %%
df2_cs["sentiment"].value_counts()
# Out:
# sentiment
# neutral     21025
# negative      816
# positive      545
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="sentiment", data=df2_cs)
plt.title("Sentiment Distribution in Counter-Strike Chat")
plt.show()

# %%
df2_cs["topic"] = topics

# %%
df2_cs["topic"].value_counts().head(10)
# Out:
# topic
# -1    5779
#  0    1474
#  1    1209
#  2     537
#  3     347
#  4     291
#  5     196
#  6     187
#  7     180
#  8     179
# Name: count, dtype: int64

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                         Name  \
# 0       -1   5779                    -1_wedidthat_der_was_they
# 1        0   1474                  0_pleasure_please_life_save
# 2        1   1209  1_mirioshi_roman7781_gbcccccc666_raybetboom
# 3        2    537                       2_que_de_para_sporting
# 4        3    347                              3_nie_bo_si_ale
# ..     ...    ...                                          ...
# 412    411     10       411_dendiface_morgan_dendiwave_degster
# 413    412     10               412_jametime_timeee_bos_jammer
# 414    413     10              413_win_choices_bronze_opponent
# 415    414     10                                      414____
# 416    415     10     415_chatsen_frosty_ratdance_makson41kkkk
#
#                                         Representation  \
# 0    [wedidthat, der, was, they, that, bro, he, the...
# 1           [pleasure, please, life, save, , , , , , ]
# 2    [mirioshi, roman7781, gbcccccc666, raybetboom,...
# 3    [que, de, para, sporting, mas, com, jogo, se, ...
# 4      [nie, bo, si, ale, jak, czy, na, jest, sie, ze]
# ..                                                 ...
# 412  [dendiface, morgan, dendiwave, degster, leg1on...
# 413  [jametime, timeee, bos, jammer, jame, young, m...
# 414  [win, choices, bronze, opponent, order, vigila...
# 415                               [, , , , , , , , , ]
# 416  [chatsen, frosty, ratdance, makson41kkkk, ios,...
#
#                                    Representative_Docs
# 0    [Hier habt ihr eine Übersicht zum Retro Setup:...
# 1                                       [+, +, please]
# 2    [@Mirioshi бля я забыл сори что напомнил, @mir...
# 3    [Eu como benfiquista sou da opiniao que tanto ...
# 4    [bo kurwa biegłes, ale jak ty nie masz drivero...
# ..                                                 ...
# 412  [DendiFace, DendiFace, DendiFace DendiFace Den...
# 413                     [JAMETIME, jametime, Jametime]
# 414  [didnt gla1ve win 4 majors, GAMBA "does he win...
# 415  [ОСУЖДАЮ, СТИРМЕРСА, так и можно, королевский?...
# 416  [А я пойду смотреть в Праге финальный плейоф т...
#
# [417 rows x 5 columns]

# %%
for i in range(10):
    print(f"\nTopic {i}:")
    print(topic_model.get_topic(i))
# Out:
# Topic 0:
# [('pleasure', np.float64(0.955824698622306)), ('skills', np.float64(0.955824698622306)), ('great', np.float64(0.6057044192753964)), ('life', np.float64(0.4765255601335165)), ('save', np.float64(0.462049593147923)), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05)]
#
# Topic 1:
# [('mirioshi', np.float64(0.03823584264179676)), ('gbcccccc666', np.float64(0.035480672853113356)), ('rutulskiy1', np.float64(0.02661850279383762)), ('btdevv', np.float64(0.02548181281798435)), ('tortik11223', np.float64(0.022735382481455294)), ('icetwo112', np.float64(0.02243009052993277)), ('raybetboom', np.float64(0.020850046930466326)), ('kel1k', np.float64(0.019977058683225475)), ('tixiyogonek', np.float64(0.019977058683225475)), ('shiiitshtiiir', np.float64(0.019626329213691174))]
#
# Topic 2:
# [('que', np.float64(0.013816483889932951)), ('de', np.float64(0.012743063308014809)), ('para', np.float64(0.011338291983381283)), ('sporting', np.float64(0.011122808624512977)), ('mas', np.float64(0.010840598261617403)), ('com', np.float64(0.010740932674642899)), ('jogo', np.float64(0.01036731058492764)), ('se', np.float64(0.010291675260622753)), ('benfica', np.float64(0.010252810155825602)), ('do', np.float64(0.009654684649931205))]
#
# Topic 3:
# [('nie', np.float64(0.02599742900979924)), ('ale', np.float64(0.021788174365714813)), ('si', np.float64(0.01828471762485878)), ('bo', np.float64(0.01767135573078325)), ('jak', np.float64(0.01745359409645611)), ('jest', np.float64(0.015716660836056523)), ('na', np.float64(0.015576608168606839)), ('co', np.float64(0.014449305974743873)), ('sie', np.float64(0.014144994752450872)), ('za', np.float64(0.014040777725392705))]
#
# Topic 4:
# [('morphintime', np.float64(0.19034740677102752)), ('6a6ulllka101', np.float64(0.09064376725297124)), ('yourwaterfull', np.float64(0.07725178419286982)), ('bronadotrenirovatsya', np.float64(0.07725178419286982)), ('evilsecret', np.float64(0.06975808031940814)), ('murcs2', np.float64(0.062273785343910405)), ('leniniw', np.float64(0.059952849151307275)), ('stilltriplev', np.float64(0.05864324814289284)), ('popnemo', np.float64(0.05484655335688751)), ('vikusechkaukr', np.float64(0.05131883984289675))]
#
# Topic 5:
# [('httpstmekasanof33', np.float64(0.14093718282941714)), ('usps', np.float64(0.12488750912894771)), ('csgopositivemekasanofff', np.float64(0.11434571928645251)), ('theilluminati', np.float64(0.10570288712206287)), ('blueprint', np.float64(0.09526795735008721)), ('richman', np.float64(0.08441947550973403)), ('httpsbitly3ecsoel', np.float64(0.08441947550973403)), ('gta5rp', np.float64(0.08441947550973403)), ('forz9r', np.float64(0.08441947550973403)), ('28112024', np.float64(0.08441947550973403))]
#
# Topic 6:
# [('ich', np.float64(0.02302169932891347)), ('ist', np.float64(0.02200850543115809)), ('das', np.float64(0.02182109655042793)), ('die', np.float64(0.018198875585541764)), ('nicht', np.float64(0.016927720094789316)), ('noch', np.float64(0.01485529769833239)), ('wie', np.float64(0.013559733667574436)), ('doch', np.float64(0.013389128057903252)), ('schon', np.float64(0.01303700366652431)), ('hat', np.float64(0.012768119136815678))]
#
# Topic 7:
# [('kokonut9146', np.float64(0.026414403653099522)), ('oearthes555o', np.float64(0.024977501825789544)), ('dobracatcry', np.float64(0.0228691438572905)), ('jalinm32', np.float64(0.0228691438572905)), ('garvard98', np.float64(0.022736827754817668)), ('yht444', np.float64(0.020304471188150944)), ('aurafarmer69', np.float64(0.01981080273982464)), ('allyleena', np.float64(0.018733126369342157)), ('mmafcn', np.float64(0.016883895101946805)), ('smokywizard8', np.float64(0.016883895101946805))]
#
# Topic 8:
# [('gaypride', np.float64(1.5401653104930766)), ('condom', np.float64(0.2655068607284183)), ('doom', np.float64(0.20539879205159062)), ('240', np.float64(0.1779303579410176)), ('roman7781', np.float64(0.058062422428729075)), ('10', np.float64(0.0277653215321892)), ('b8', np.float64(0.021407983606041295)), ('', 1e-05), ('', 1e-05), ('', 1e-05)]
#
# Topic 9:
# [('winline', np.float64(0.5420406431139152)), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05)]

# %%
sns.heatmap(
    pd.crosstab(df2_cs["topic"], df2_cs["sentiment"]),
    cmap="YlGnBu", annot=True, fmt="d"
)
plt.title("Topic vs. Sentiment")
plt.show()

# %%
# 生成话题-时间关系数据
topics_over_time = topic_model.topics_over_time(
    docs=df2_cs["message"].tolist(),
    topics=topics,
    timestamps=df2_cs["timestamp"].tolist(),
    nr_bins=10,        # 时间分为 20 段，可调
    evolution_tuning=True,
    global_tuning=True
)
# Out:
# 10it [00:02,  4.45it/s]

# %%
# 绘制演变图
topic_model.visualize_topics_over_time(topics_over_time)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bd422576-3bda-4efe-a0bb-5e8baf4cd3c3" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd422576-3bda-4efe-a0bb-5e8baf4cd3c3")) {                    Plotly.newPlot(                        "bd422576-3bda-4efe-a0bb-5e8baf4cd3c3",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: skills, pleasure, great, life, save","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pleasure, skills, great, life, save","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: skills, pleasure, great, life, save","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: skills, pleasure, great, life, save","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: skills, great, pleasure, life, save","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: life, save, skills, pleasure, great"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_pleasure_skills_great_life","x":["2025-05-11T20:59:52.801000","2025-05-11T21:11:59.900000","2025-05-11T21:23:59.800000","2025-05-11T21:47:59.600000","2025-05-11T21:59:59.500000","2025-05-11T22:23:59.300000"],"y":[1376,88,2,11,1,3],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: rutulskiy1, tixiyogonek, btdevv, slndsi, svyatohka","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: zxrosen, chernayaboroda174, rigononetap, lixach, bekzhanbissembeyev","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: prostoybtw, kypitmanww, latin0zzz, xnurba, mus1khaha1221","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: gbcccccc666, takemarurf, polodin, timoshkaxgenius, docziro20","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: kel1k, gbcccccc666, liaguuh, r3i, 20heavenss","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: s1lonn, iarkko, maxko1o, mirioshi, oldbutovski","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: yxo7, lord6257, zlostnik777, deathaddeer, vrnchihpih","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: shiiitshtiiir, 3328koten, rewinchnat, tortik11223, resolckaisa","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: sigmakrytoibro, poslanddd, oz1k, mirioshi, tortik11223","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: taylanof, everydayr, raybetboom, qw1xee, chachavitsa"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_mirioshi_gbcccccc666_rutulskiy1_btdevv","x":["2025-05-11T20:59:52.801000","2025-05-11T21:11:59.900000","2025-05-11T21:23:59.800000","2025-05-11T21:35:59.700000","2025-05-11T21:47:59.600000","2025-05-11T21:59:59.500000","2025-05-11T22:11:59.400000","2025-05-11T22:23:59.300000","2025-05-11T22:35:59.200000","2025-05-11T22:47:59.100000"],"y":[125,76,83,44,52,47,67,62,80,64],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: n0kse, ronaldo, agcunha7, nao, perde","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: foi, que, os, agcunha7, mais","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: de, que, para, como, sporting","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: sporting, de, mas, jogo, que","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: nao, benfica, um, tem, golos","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: jogo, que, aos, mais, com","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: com, que, ter, se, de","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: que, de, sporting, zorlakoka, para","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: multa, casas, nehuen, moura, m ...

# %%
# 确保 timestamp 是 datetime 类型
df2_cs["timestamp"] = pd.to_datetime(df2_cs["timestamp"])

# 选取 Topic 0 且时间在 21:00–21:10 之间的消息
topic0_subset = df2_cs[
    (df2_cs["topic"] == 0) &
    (df2_cs["timestamp"].dt.time >= pd.to_datetime("21:00").time()) &
    (df2_cs["timestamp"].dt.time < pd.to_datetime("21:10").time())
]

# 查看前几条代表消息
topic0_subset["message"].head(10).to_list()
# Out:
# ['+', '+', '+', '+', '+', '+', '+', '+', '+', '+']

# %%
# 条件筛选：非 + 类型刷屏内容
topic0_real_msgs = df2_cs[
    (df2_cs["topic"] == 0) &
    (df2_cs["message"].str.strip() != '+') &
    (df2_cs["message"].str.len() > 3)
]

# 查看前10条真实评论
topic0_real_msgs["message"].head(10).to_list()
# Out:
# ['Pleasure', 'save', 'life*\r', 'please']

# %%
topic0_real_msgs = df2_cs[
    (df2_cs["topic"] == 0) &
    (df2_cs["message"].str.strip() != '+') &
    (df2_cs["message"].str.len() > 3)
]

# 改用这一列
topic0_msgs = topic0_real_msgs["message"].astype(str)

# %%
# 创建透视表：每个话题下，不同情绪的消息数
topic_sentiment_dist = pd.crosstab(df2_cs["topic"], df2_cs["sentiment"])

# 只取 top 10 话题（按出现频率）
top10_topics = df2_cs["topic"].value_counts().head(10).index
top10_dist = topic_sentiment_dist.loc[top10_topics]

# 添加占比列
top10_dist["total"] = top10_dist.sum(axis=1)
top10_dist["pos_ratio"] = top10_dist.get("positive", 0) / top10_dist["total"]
top10_dist["neg_ratio"] = top10_dist.get("negative", 0) / top10_dist["total"]

# 排序：谁更容易产生正面或负面情绪
top10_pos_sorted = top10_dist.sort_values("pos_ratio", ascending=False)
top10_neg_sorted = top10_dist.sort_values("neg_ratio", ascending=False)

# 输出前几行结果
print("🔼 Top topics with highest positive ratio:")
print(top10_pos_sorted[["positive", "total", "pos_ratio"]].head())

print("\n🔽 Top topics with highest negative ratio:")
print(top10_neg_sorted[["negative", "total", "neg_ratio"]].head())
# Out:
# 🔼 Top topics with highest positive ratio:
# sentiment  positive  total  pos_ratio
# topic
#  6                5    187   0.026738
# -1              122   5779   0.021111
#  3                3    347   0.008646
#  2                4    537   0.007449
#  1                4   1209   0.003309
#
# 🔽 Top topics with highest negative ratio:
# sentiment  negative  total  neg_ratio
# topic
# -1              282   5779   0.048797
#  6                5    187   0.026738
#  4                3    291   0.010309
#  5                1    196   0.005102
#  3                1    347   0.002882

# %%
# Topic 6 且情绪为 positive 的样本
topic6_pos = df2_cs[(df2_cs["topic"] == 6) & (df2_cs["sentiment"] == "positive")]
print("🔹 Topic 6 – Positive Samples:")
print(topic6_pos["message"].head(5).to_list())

# Topic 6 且情绪为 negative 的样本
topic6_neg = df2_cs[(df2_cs["topic"] == 6) & (df2_cs["sentiment"] == "negative")]
print("🔻 Topic 6 – Negative Samples:")
print(topic6_neg["message"].head(5).to_list())
# Out:
# 🔹 Topic 6 – Positive Samples:
# ['@mundane1337 doch scheiss auf serbien ;)', 'Ich hab so eine Erhöhung von Ikea, die ist nice und hat 2 höhen', 'Danke für die Antwort ;)', 'wenn die godlike hittet will ich praise haha', 'ja meine :D']
# 🔻 Topic 6 – Negative Samples:
# ['das auch noch ey NotLikeThis\r', 'einfach nich so gross sein 4Head', 'also der war egal was insane teuer. dafür hätt man gefühlt neuwagen bekommen', 'das ist so rigged', 'die seite ist so scuffed']

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm

# 初始化情绪模型
tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
labels = ['negative', 'neutral', 'positive']
device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
# 情绪分析函数（支持 GPU）
def get_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=128)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        logits = model(**inputs).logits
    scores = softmax(logits.cpu().numpy()[0])
    return labels[np.argmax(scores)]

# %%
# 嵌入模型
embedding_model = SentenceTransformer("all-MiniLM-L6-v2", device="cuda")

# 🎯 对每个频道执行完整 pipeline
def process_channel(channel_name, channel_df):
    print(f"\n🔍 Processing channel: {channel_name} — messages: {len(channel_df)}")

    # Step 1: 情绪分析
    tqdm.pandas(desc="Sentiment analysis")
    channel_df["sentiment"] = channel_df["message"].progress_apply(get_sentiment)

    # Step 2: 文本嵌入
    texts = channel_df["message"].astype(str).tolist()
    embeddings = embedding_model.encode(texts, show_progress_bar=True)

    # Step 3: BERTopic 建模
    topic_model = BERTopic(verbose=False)
    topics, probs = topic_model.fit_transform(texts, embeddings)

    # Step 4: 可选可视化（只显示 Top 10）
    fig = topic_model.visualize_barchart(top_n_topics=10)
    fig.write_html(f"channel_{channel_name}_barchart.html")  # 可选保存

    # 返回结果用于进一步分析（可选）
    return topic_model, topics, probs, channel_df
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# 对每个频道执行分析
results_by_channel = {}
for channel in df2_cs["channel"].unique():
    df_channel = df2_cs[df2_cs["channel"] == channel].copy()
    if len(df_channel) >= 100:  # 跳过太小的频道
        topic_model, topics, probs, enriched_df = process_channel(channel, df_channel)
        results_by_channel[channel] = {
            "model": topic_model,
            "topics": topics,
            "probs": probs,
            "data": enriched_df
        }
# Out:
# 🔍 Processing channel: leniniw — messages: 2977
# Sentiment analysis: 100%|██████████| 2977/2977 [00:40<00:00, 74.34it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# 🔍 Processing channel: megarushplay — messages: 3504
# Sentiment analysis: 100%|██████████| 3504/3504 [00:34<00:00, 103.01it/s]
# Batches:   0%|          | 0/110 [00:00<?, ?it/s]
# 🔍 Processing channel: biba — messages: 1400
# Sentiment analysis: 100%|██████████| 1400/1400 [00:12<00:00, 111.70it/s]
# Batches:   0%|          | 0/44 [00:00<?, ?it/s]
# 🔍 Processing channel: m3wsu — messages: 2117
# Sentiment analysis: 100%|██████████| 2117/2117 [00:20<00:00, 103.09it/s]
# Batches:   0%|          | 0/67 [00:00<?, ?it/s]
# 🔍 Processing channel: kasanofff — messages: 668
# Sentiment analysis: 100%|██████████| 668/668 [00:07<00:00, 93.38it/s]
# Batches:   0%|          | 0/21 [00:00<?, ?it/s]
# 🔍 Processing channel: forzorezor — messages: 343
# Sentiment analysis: 100%|██████████| 343/343 [00:02<00:00, 116.78it/s]
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# 🔍 Processing channel: zorlakoka — messages: 654
# Sentiment analysis: 100%|██████████| 654/654 [00:06<00:00, 100.59it/s]
# Batches:   0%|          | 0/21 [00:00<?, ?it/s]
# 🔍 Processing channel: baz1221 — messages: 2342
# Sentiment analysis: 100%|██████████| 2342/2342 [00:21<00:00, 107.66it/s]
# Batches:   0%|          | 0/74 [00:00<?, ?it/s]
# 🔍 Processing channel: stewie2k — messages: 629
# Sentiment analysis: 100%|██████████| 629/629 [00:06<00:00, 101.71it/s]
# Batches:   0%|          | 0/20 [00:00<?, ?it/s]
# 🔍 Processing channel: watchfultv — messages: 3190
# Sentiment analysis: 100%|██████████| 3190/3190 [00:29<00:00, 109.83it/s]
# Batches:   0%|          | 0/100 [00:00<?, ?it/s]
# 🔍 Processing channel: degst3r — messages: 994
# Sentiment analysis: 100%|██████████| 994/994 [00:08<00:00, 110.51it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# 🔍 Processing channel: flusha — messages: 193
# Sentiment analysis: 100%|██████████| 193/193 [00:02<00:00, 90.05it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# 🔍 Processing channel: rallencs2 — messages: 423
# Sentiment analysis: 100%|██████████| 423/423 [00:03<00:00, 119.02it/s]
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# 🔍 Processing channel: treryk — messages: 175
# Sentiment analysis: 100%|██████████| 175/175 [00:01<00:00, 118.10it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# 🔍 Processing channel: eslcs — messages: 1393
# Sentiment analysis: 100%|██████████| 1393/1393 [00:12<00:00, 110.97it/s]
# Batches:   0%|          | 0/44 [00:00<?, ?it/s]
# 🔍 Processing channel: ozi_rider — messages: 506
# Sentiment analysis: 100%|██████████| 506/506 [00:04<00:00, 108.07it/s]
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# 🔍 Processing channel: rainbetesports — messages: 363
# Sentiment analysis: 100%|██████████| 363/363 [00:03<00:00, 120.49it/s]
# Batches:   0%|          | 0/12 [00:00<?, ?it/s]
# 🔍 Processing channel: trilluxe — messages: 426
# Sentiment analysis: 100%|██████████| 426/426 [00:04<00:00, 97.74it/s]
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]

# %% [markdown]
# 1. 每个频道的情绪分布图

# %%
import seaborn as sns

for channel, result in results_by_channel.items():
    df_channel = result["data"]

    plt.figure(figsize=(6,4))
    sns.countplot(x="sentiment", data=df_channel, order=["negative", "neutral", "positive"])
    plt.title(f"Sentiment Distribution – {channel}")
    plt.xlabel("Sentiment")
    plt.ylabel("Message Count")
    plt.tight_layout()
    plt.savefig(f"sentiment_dist_{channel}.png")  # 保存图像
    plt.close()

# %%
for channel, result in results_by_channel.items():
    df_channel = result["data"]

    plt.figure(figsize=(6,4))
    sns.countplot(x="sentiment", data=df_channel, order=["negative", "neutral", "positive"])
    plt.title(f"Sentiment Distribution – {channel}")
    plt.xlabel("Sentiment")
    plt.ylabel("Message Count")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 2. 所有频道对比的关键词 / 主题表格

# %%
# 提取每个频道 top 3 话题及关键词
topic_summary = []

for channel, result in results_by_channel.items():
    model = result["model"]
    info_df = model.get_topic_info().head(4)  # topic -1 + top3

    for _, row in info_df.iterrows():
        topic_summary.append({
            "channel": channel,
            "topic_id": row["Topic"],
            "count": row["Count"],
            "keywords": row["Name"]
        })

topic_summary_df = pd.DataFrame(topic_summary)
topic_summary_df = topic_summary_df[topic_summary_df["topic_id"] != -1]  # 去除 -1 噪音类
display(topic_summary_df.head())
# Out:
#         channel  topic_id  count                   keywords
# 1       leniniw         0    147   0_kutas_lijko_team_kutac
# 2       leniniw         1    135  1_500_300_passion_leniniw
# 3       leniniw         2     86  2_centimeter_size_is_dick
# 5  megarushplay         0   1307                      0____
# 6  megarushplay         1    141                      1____

# %%
topic_summary_df.to_csv("channel_topic_keywords.csv", index=False)

# %% [markdown]
# 3. 按频道保存 CSV 和 JSON

# %%
for channel, result in results_by_channel.items():
    df_channel = result["data"]

    # 保存 CSV
    df_channel.to_csv(f"channel_{channel}.csv", index=False)

    # 保存 JSON（按行存储，便于结构化处理）
    df_channel.to_json(f"channel_{channel}.json", orient="records", lines=True, force_ascii=False)

# %%
drive_path = "/content/drive/MyDrive/twitch_channel_exports"
os.makedirs(drive_path, exist_ok=True)

# %%
import shutil
import glob

# 拷贝所有相关文件（可按需要修改文件类型）
for file_path in glob.glob("channel_*.*"):
    shutil.copy(file_path, drive_path)

print("✅ 所有文件已复制到 Google Drive 目标路径。")
# Out:
# ✅ 所有文件已复制到 Google Drive 目标路径。

# %%
import zipfile
import glob

# 设定 zip 文件名
zip_filename = "twitch_channel_exports.zip"

# 创建并写入 zip
with zipfile.ZipFile(zip_filename, "w") as zipf:
    for file in glob.glob("channel_*.*"):
        zipf.write(file)

print(f"✅ 打包完成: {zip_filename}")
# Out:
# ✅ 打包完成: twitch_channel_exports.zip

# %%
# 确保你已挂载 Google Drive，如未挂载请先执行 drive.mount(...)
drive_path = "/content/drive/MyDrive/twitch_channel_exports"
os.makedirs(drive_path, exist_ok=True)

# 拷贝 zip 文件到目标路径
shutil.copy(zip_filename, drive_path)

print(f"✅ 文件已复制到 Google Drive: {drive_path}/{zip_filename}")
# Out:
# ✅ 文件已复制到 Google Drive: /content/drive/MyDrive/twitch_channel_exports/twitch_channel_exports.zip
