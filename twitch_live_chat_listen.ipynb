# %%
import socket
import re
import requests
import time
from datetime import datetime
from threading import Thread, Lock
from google.cloud import bigquery

# -------------------------------
# BigQuery configurations
PROJECT_ID = "twitch-realtime-chats"
DATASET_ID = "202503200809"
TABLE_ID = "twich_chat_log_partitioned"
CREDENTIALS_PATH = "/content/twitch-realtime-chats-e6edd4d2d2ab.json"

# Initialise BigQuery client
bq_client = bigquery.Client.from_service_account_json(CREDENTIALS_PATH)
table_ref = f"{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}"

# -------------------------------
# Twitch API
CLIENT_ID = "gp762nuuoqcoxypju8c569th9wz7q5"
OAUTH_TOKEN = "oauth:mb053vdgfqc0u2m7folpig78vgxdke"
USERNAME = "danieljia36"
API_URL = "https://api.twitch.tv/helix/streams"
GAMES_API_URL = "https://api.twitch.tv/helix/games"

# Twitch IRC
IRC_SERVER = "irc.chat.twitch.tv"
IRC_PORT = 6667

# game list
GAME_LIST = [
    "League of Legends",
    "Counter-Strike",
    "Grand Theft Auto V",
    "Assassin's Creed Shadows",
    "Fortnite",
    "VALORANT",
    "Marvel Rivals",
    "Apex Legends",
    "Rainbow Six Siege"
]

#
joined_channels = {}

#
sock = None
sock_lock = Lock()

# -------------------------------
def connect():
    """ connect to Twitch IRC server，update global sock """
    global sock
    while True:
        try:
            s = socket.socket()
            s.settimeout(60)
            s.connect((IRC_SERVER, IRC_PORT))
            s.send(f"PASS {OAUTH_TOKEN}\n".encode("utf-8"))
            s.send(f"NICK {USERNAME}\n".encode("utf-8"))
            print("✅ Connected to Twitch IRC")
            with sock_lock:
                sock = s
            return s
        except Exception as e:
            print(f"⚠ Connection failed，retry in 10s... error: {e}")
            time.sleep(10)

def insert_chat_data_batch(rows):
    """ write data into BigQuery by batch """
    if not rows:
        return
    errors = bq_client.insert_rows_json(table_ref, rows)
    if errors:
        print(f"❌ BigQuery write error: {errors}")
    else:
        print(f"✅ Write into BigQuery {len(rows)}  rows")

def get_game_ids(game_names):
    headers = {
        "Client-ID": CLIENT_ID,
        "Authorization": f"Bearer {OAUTH_TOKEN.split(':')[1]}"
    }
    params = [("name", game) for game in game_names]
    response = requests.get(GAMES_API_URL, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        return {game["name"]: game["id"] for game in data.get("data", [])}
    else:
        print(f"Failed to get game id: {response.text}")
        return {}

def get_live_channels(game_ids):
    headers = {
        "Client-ID": CLIENT_ID,
        "Authorization": f"Bearer {OAUTH_TOKEN.split(':')[1]}"
    }
    live_channels = {}
    for game_name, game_id in game_ids.items():
        params = {"game_id": game_id, "first": 20}
        response = requests.get(API_URL, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()
            live_channels[game_name] = [stream["user_login"] for stream in data.get("data", [])]
        else:
            print(f"Failed to get {game_name} channel: {response.text}")
    return live_channels

def connect_to_channel(s, channel, game_name):
    try:
        s.send(f"JOIN #{channel}\n".encode("utf-8"))
        joined_channels[channel] = game_name
        print(f"Joined: {channel} (Game: {game_name})")
    except Exception as e:
        print(f"Joined {channel} fail: {e}")
        new_sock = connect()
        connect_to_channel(new_sock, channel, game_name)

def listen_chat():
    """ listen to chats in multiple channels，write data into BigQuery by batch"""
    global sock
    buffer = []
    last_flush = time.time()
    while True:
        try:
            with sock_lock:
                s = sock
            # errors="replace" ,for encoding failure.
            raw_data = s.recv(2048)
            resp = raw_data.decode("utf-8", errors="replace").strip()

            if not resp:
                print("⚠ empty message, reconnecting...")
                s = connect()
                continue

            if resp.startswith("PING"):
                s.send("PONG :tmi.twitch.tv\n".encode("utf-8"))
                continue

            if "JOIN" in resp:
                print(f"✅ Join channel confirmed: {resp}")
                continue

            if "PRIVMSG" in resp:
                try:
                    user_name = re.search(r":(\w+)!", resp).group(1)
                    message_match = re.search(r"PRIVMSG #([\w]+) :(.*)", resp)
                    channel = message_match.group(1)
                    chat_message = message_match.group(2)
                    timestamp = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
                    game_name = joined_channels.get(channel, "Unknown Game")
                    row = {
                        "timestamp": timestamp,
                        "game_name": game_name,
                        "channel": channel,
                        "user_name": user_name,
                        "message": chat_message
                    }
                    buffer.append(row)
                    # Write data into table per 1000 rows
                    if len(buffer) >= 1000:
                        insert_chat_data_batch(buffer)
                        buffer.clear()
                        last_flush = time.time()
                except Exception as parse_e:
                    print(f"Parse message failure: {parse_e}")
                    continue
        except socket.timeout:
            print("⚠ No new message in 60s, reconnecting...")
            s = connect()
            continue
        except (socket.error, BrokenPipeError) as e:
            print(f"⚠ Connection error: {e}，reconneting...")
            s = connect()
            continue

def update_channels():
    global sock
    game_ids = get_game_ids(GAME_LIST)
    while True:
        live_channels = get_live_channels(game_ids)
        for game_name, channels in live_channels.items():
            for channel in channels:
                with sock_lock:
                    s = sock
                connect_to_channel(s, channel, game_name)
                time.sleep(2)
        time.sleep(60)

if __name__ == "__main__":
    sock = connect()
    t_listen = Thread(target=listen_chat, daemon=True)
    t_update = Thread(target=update_channels, daemon=True)
    t_listen.start()
    t_update.start()
    t_listen.join()
    t_update.join()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# :theazertio!theazertio@theazertio.tmi.twitch.tv PRIVMSG #midbeast :Deep
# Joined: martinmartin_m2x (Game: League of Legends)
# ✅ 加入频道确认: :dmeney!dmeney@dmeney.tmi.twitch.tv PRIVMSG #locking :cara ta em sp e n dá um salve pra nada
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #martinmartin_m2x
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #martinmartin_m2x :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #martinmartin_m2x :End of /NAMES list
# :zxsayonara!zxsayonara@zxsayonara.tmi.twitch.tv PRIVMSG #get_right :ahahaha :)))
# :elyogaming!elyogaming@elyogaming.tmi.twitch.tv PRIVMSG #strey_lol :Combien de games avant les ranked?
# Joined: clovaobengala (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #clovaobengala
# Joined: chap_gg (Game: League of Legends)
# ✅ 加入频道确认: :pakapakapackers!pakapakapackers@pakapakapackers.tmi.twitch.tv PRIVMSG #darkzelk :www
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #chap_gg
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #chap_gg :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #chap_gg :End of /NAMES list
# :marirurusan!marirurusan@marirurusan.tmi.twitch.tv PRIVMSG #kiruma_ch :カラーギャングなくなったんですか？
# Joined: autophil (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #autophil
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #autophil :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #autophil :End of /NAMES list
# :fehlfarben0815!fehlfarben0815@fehlfarben0815.tmi.twitch.tv PRIVMSG #katoo :Seit Wochen stürzt Fortnite ab, immer wieder Fehlerhafte Daten, einfach zum k.....
# :xxdestructor69xx!xxdestructor69xx@xxdestructor69xx.tmi.twitch.tv PRIVMSG #ache :Dale dale hermano jojojo acheBaile acheRojo
# :hvk_vls_velsatis!hvk_vls_velsatis@hvk_vls_velsatis.tmi.twitch.tv PRIVMSG #stizo_ :flm
# Joined: guanweiboy (Game: League of Legends)
# ✅ 加入频道确认: :charly98__!charly98__@charly98__.tmi.twitch.tv PRIVMSG #vetelcito01 :Pues llévame
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #guanweiboy
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #guanweiboy :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #guanweiboy :End of /NAMES list
# :sanoeko!sanoeko@sanoeko.tmi.twitch.tv PRIVMSG #stizo_ :oe il y a les nouvelles armes
# :pendulums_!pendulums_@pendulums_.tmi.twitch.tv PRIVMSG #vetelcito01 :no había otro país que tenéis que ir a rancia ?
# Joined: sixentv (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sixentv
# Joined: pcstw (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #pcstw
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #pcstw :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #pcstw :End of /NAMES list
# Joined: gobgg (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gobgg
# Joined: rybsonlol_ (Game: League of Legends)
# Joined: m3wsu (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #m3wsu
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #m3wsu :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #m3wsu :End of /NAMES list
# Joined: theburntpeanut (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #theburntpeanut
# Joined: hypetried (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #hypetried
# Joined: qrushcsgo (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #qrushcsgo
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #qrushcsgo :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #qrushcsgo :End of /NAMES list
# Joined: united21_en (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #united21_en
# Joined: szelioficjalnie (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #szelioficjalnie
# Joined: kotehok_gaf (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kotehok_gaf
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #kotehok_gaf :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #kotehok_gaf :End of /NAMES list
# :ikusa9150!ikusa9150@ikusa9150.tmi.twitch.tv PRIVMSG #pira_real :小物ね
# Joined: c0baka_kycaka (Game: Counter-Strike)
# ✅ 加入频道确认: :marcosvicente18!marcosvicente18@marcosvicente18.tmi.twitch.tv PRIVMSG #locking :E a live com Vini???
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #c0baka_kycaka
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #c0baka_kycaka :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #c0baka_kycaka :End of /NAMES list
# :swift14_!swift14_@swift14_.tmi.twitch.tv PRIVMSG #midbeast :damn
# Joined: margenalez (Game: Counter-Strike)
# Joined: gaules (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gaules
# Joined: pokanoname (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #pokanoname
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #pokanoname :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #pokanoname :End of /NAMES list
# :osushi252!osushi252@osushi252.tmi.twitch.tv PRIVMSG #fps__saku :あ
# Joined: locking (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #locking
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #locking :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #locking :End of /NAMES list
# Joined: eslcs (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #eslcs
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #eslcs :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #eslcs :End of /NAMES list
# Joined: get_right (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #get_right
# Joined: shhhifu (Game: Counter-Strike)
# ✅ 加入频道确认: :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #guanweiboy :訂閱者已驗證GZjar: 你是要玩游戏还是只会一直说些没用的？
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #shhhifu
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #shhhifu :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #shhhifu :End of /NAMES list
# Joined: landstop (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #landstop
# Joined: zonixxcs (Game: Counter-Strike)
# ✅ Write into BigQuery 1000  rows
# ✅ 加入频道确认: :iviaaat!iviaaat@iviaaat.tmi.twitch.tv PRIVMSG #martinmartin_m2x :tu devrais flux on the plux
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #zonixxcs
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #zonixxcs :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #zonixxcs :End of /NAMES list
# :streamelements!streamelements@streamelements.tmi.twitch.tv PRIVMSG #vetelcito01 :ACTION Unete a nuestra comunidad de Rainbow Six Siege DISCORD! -->  https://discord.gg/JbXawVzU2S
# Joined: fpssssssssssssssssssss (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fpssssssssssssssssssss
# Joined: nikimbo69 (Game: Counter-Strike)
# ✅ 加入频道确认: :capableplayer6!capableplayer6@capableplayer6.tmi.twitch.tv PRIVMSG #iwdominate :wtf
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #nikimbo69
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #nikimbo69 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #nikimbo69 :End of /NAMES list
# Joined: venavas (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #venavas
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #venavas :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #venavas :End of /NAMES list
# :pixy_rain!pixy_rain@pixy_rain.tmi.twitch.tv PRIVMSG #kiruma_ch :wwww
# :rythm36!rythm36@rythm36.tmi.twitch.tv PRIVMSG #iwdominate :This is so fking cringe
# Joined: skyte (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #skyte
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #skyte :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #skyte :End of /NAMES list
# Joined: senvale (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #senvale
# Joined: thegodlynoob (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #thegodlynoob
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #thegodlynoob :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #thegodlynoob :End of /NAMES list
# Joined: masamitzu (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #masamitzu
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #masamitzu :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #masamitzu :End of /NAMES list
# :kugyurururu!kugyurururu@kugyurururu.tmi.twitch.tv PRIVMSG #amauta_sau :多分サウ汰には飛行機が飛ぶメカニズムから教えんとなｗ
# Joined: fastanne (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fastanne
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #fastanne :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #fastanne :End of /NAMES list
# :the_maker01_!the_maker01_@the_maker01_.tmi.twitch.tv PRIVMSG #heystan :tableflip
# Joined: sha77etv (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sha77etv
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #sha77etv :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #sha77etv :End of /NAMES list
# Joined: airhead022 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #airhead022
# Joined: jynxziofflines_ (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :pk5278!pk5278@pk5278.tmi.twitch.tv PRIVMSG #guanweiboy :你是要玩遊戲 還是說些有的沒的?
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jynxziofflines_
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #jynxziofflines_ :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #jynxziofflines_ :End of /NAMES list
# Joined: jynxzioffline_ (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jynxzioffline_
# Joined: kinggeorgeoffline (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kinggeorgeoffline
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #kinggeorgeoffline :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #kinggeorgeoffline :End of /NAMES list
# :grimness35!grimness35@grimness35.tmi.twitch.tv PRIVMSG #shhhifu :DinoDance DinoDance DinoDance DinoDance
# :g8rweiqq123!g8rweiqq123@g8rweiqq123.tmi.twitch.tv PRIVMSG #guanweiboy :這豬有點猛
# :svx_on_60fps!svx_on_60fps@svx_on_60fps.tmi.twitch.tv PRIVMSG #sypherpk :yo sphyher im live
# Joined: s9eem (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #s9eem
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #s9eem :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #s9eem :End of /NAMES list
# Joined: vetelcito01 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #vetelcito01
# Joined: boooe (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #boooe
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #boooe :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #boooe :End of /NAMES list
# Joined: badrookie_1977 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #badrookie_1977
# Joined: cateye222 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #cateye222
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #cateye222 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #cateye222 :End of /NAMES list
# :jaen1203!jaen1203@jaen1203.tmi.twitch.tv PRIVMSG #khira_stb :55555
# Joined: bravenika (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :simblackss!simblackss@simblackss.tmi.twitch.tv PRIVMSG #strey_lol :clip du pet ?
# :oderlin_2!oderlin_2@oderlin_2.tmi.twitch.tv PRIVMSG #sypherpk :W being a good boy
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #bravenika
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #bravenika :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #bravenika :End of /NAMES list
# Joined: monkcer (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :dariusliveontwitch!dariusliveontwitch@dariusliveontwitch.tmi.twitch.tv PRIVMSG #abstaau :@hwrvey_ Send that shit 1 more time qr
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #monkcer
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #monkcer :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #monkcer :End of /NAMES list
# Joined: jmalttr (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jmalttr
# Joined: proxima (Game: Tom Clancy's Rainbow Six Siege)
# Joined: pascal0_4 (Game: Tom Clancy's Rainbow Six Siege)
# Joined: fps__saku (Game: Apex Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fps__saku
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #fps__saku :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #fps__saku :End of /NAMES list
# Joined: taxi2g (Game: Apex Legends)
# Joined: taaaao (Game: Apex Legends)
# Joined: dami_la (Game: Apex Legends)
# Joined: gdolphn (Game: Apex Legends)
# Joined: taidaaaa_ (Game: Apex Legends)
# Joined: curihara0807 (Game: Apex Legends)
# Joined: ranches (Game: Apex Legends)
# Joined: pinotr_ (Game: Apex Legends)
# Joined: lace (Game: Apex Legends)
# Joined: saxzu (Game: Apex Legends)
# Joined: ndodgee (Game: Apex Legends)
# Joined: hiswattson247 (Game: Apex Legends)
# Joined: irene28___ (Game: Apex Legends)
# Joined: shoooter_daddy (Game: Apex Legends)
# Joined: gprodaisuki (Game: Apex Legends)
# Joined: gospojaaaa (Game: Apex Legends)
# ✅ Write into BigQuery 1000  rows
# Joined: zakatix (Game: Apex Legends)
# Joined: moonzinha (Game: Apex Legends)
# Joined: oniyadayo (Game: VALORANT)
# Joined: prod (Game: VALORANT)
# Joined: yohdazo (Game: VALORANT)
# Joined: vodkavdk (Game: VALORANT)
# Joined: cr_rion (Game: VALORANT)
# Joined: kanpeki (Game: VALORANT)
# Joined: 9qoq (Game: VALORANT)
# Joined: rax1337 (Game: VALORANT)
# Joined: im_mittiii (Game: VALORANT)
# Joined: ade3_3 (Game: VALORANT)
# Joined: dethseiya (Game: VALORANT)
# Joined: yuseafn (Game: VALORANT)
# Joined: akash1vl (Game: VALORANT)
# Joined: kntsy (Game: VALORANT)
# Joined: b0rja (Game: VALORANT)
# Joined: danikongi (Game: VALORANT)
# Joined: unfair (Game: VALORANT)
# Joined: ragevl_ (Game: VALORANT)
# Joined: garnets__ (Game: VALORANT)
# Joined: harmii (Game: VALORANT)
# Joined: tonton (Game: Assassin's Creed Shadows)
# Joined: grimmmz (Game: Assassin's Creed Shadows)
# Joined: deadp47_ (Game: Assassin's Creed Shadows)
# Joined: singsing (Game: Assassin's Creed Shadows)
# Joined: teawithmandy (Game: Assassin's Creed Shadows)
# Joined: ilgattosultubo (Game: Assassin's Creed Shadows)
# Joined: doomedmeter (Game: Assassin's Creed Shadows)
# Joined: bajo (Game: Assassin's Creed Shadows)
# Joined: lilykonjo (Game: Assassin's Creed Shadows)
# Joined: raptor (Game: Assassin's Creed Shadows)
# Joined: fuzhpuzy (Game: Assassin's Creed Shadows)
# Joined: ten_wong (Game: Assassin's Creed Shadows)
# Joined: jtaz (Game: Assassin's Creed Shadows)
# Joined: neelana (Game: Assassin's Creed Shadows)
# Joined: mirageeputo_ (Game: Assassin's Creed Shadows)
# Joined: deadfox15 (Game: Assassin's Creed Shadows)
# Joined: lusorkoeffizient (Game: Assassin's Creed Shadows)
# Joined: aiola (Game: Assassin's Creed Shadows)
# Joined: paranoidpixi3_za (Game: Assassin's Creed Shadows)
# ✅ 加入频道确认: :drbatman69!drbatman69@drbatman69.tmi.twitch.tv PRIVMSG #iwdominate :JOIN THE GOOD SIDE
# Joined: gtimetv (Game: Assassin's Creed Shadows)
# Joined: dokibird (Game: Marvel Rivals)
# Joined: sinatraavod (Game: Marvel Rivals)
# ✅ Write into BigQuery 1000  rows
# Joined: ratirl (Game: Marvel Rivals)
# Joined: gale (Game: Marvel Rivals)
# Joined: timthetatmanvods (Game: Marvel Rivals)
# Joined: kalei (Game: Marvel Rivals)
# ✅ 加入频道确认: :hexaflur_!hexaflur_@hexaflur_.tmi.twitch.tv PRIVMSG #m3wsu :Диман априори долбаеб,у меня кореш такой же
# :drbatman69!drbatman69@drbatman69.tmi.twitch.tv PRIVMSG #iwdominate :JOIN THE WINNER SIDE EZ Clap
# Joined: marvelrivals (Game: Marvel Rivals)
# Joined: guru (Game: Marvel Rivals)
# Joined: ariasaki (Game: Marvel Rivals)
# Joined: agbin3r (Game: Marvel Rivals)
# Joined: dropped (Game: Marvel Rivals)
# Joined: slater (Game: Marvel Rivals)
# Joined: zondalol (Game: Marvel Rivals)
# Joined: andr3wow (Game: Marvel Rivals)
# Joined: fazesway (Game: Marvel Rivals)
# Joined: aceofspades (Game: Marvel Rivals)
# Joined: louikey (Game: Marvel Rivals)
# Joined: luka (Game: Marvel Rivals)
# Joined: i__ate (Game: Marvel Rivals)
# Joined: anibae_vt (Game: Marvel Rivals)
# ✅ Write into BigQuery 1000  rows
# Joined: kiruma_ch (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kiruma_ch
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #kiruma_ch :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #kiruma_ch :End of /NAMES list
# Joined: pira_real (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #pira_real
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #pira_real :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #pira_real :End of /NAMES list
# Joined: middleeetv (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :maikenzo!maikenzo@maikenzo.tmi.twitch.tv PRIVMSG #get_right :!sens
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #middleeetv
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #middleeetv :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #middleeetv :End of /NAMES list
# Joined: r_k7den (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #r_k7den
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #r_k7den :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #r_k7den :End of /NAMES list
# Joined: darkzelk (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #darkzelk
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #darkzelk :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #darkzelk :End of /NAMES list
# :nicczxx!nicczxx@nicczxx.tmi.twitch.tv PRIVMSG #locking :redação hj
# Joined: m2_kento_heluan (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #m2_kento_heluan
# Joined: suzune_rabbit (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #suzune_rabbit
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #suzune_rabbit :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #suzune_rabbit :End of /NAMES list
# :elnino13100!elnino13100@elnino13100.tmi.twitch.tv PRIVMSG #traytonlol :en plus il a fait un arc corée full tryhard hate de voir si il step up ce split
# :syousa_alterego!syousa_alterego@syousa_alterego.tmi.twitch.tv PRIVMSG #kiruma_ch :ラクダのコブは珍味らしい
# Joined: kaiking1101 (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :p1xsma_!p1xsma_@p1xsma_.tmi.twitch.tv PRIVMSG #abstaau :absta au
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kaiking1101
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #kaiking1101 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #kaiking1101 :End of /NAMES list
# :exrecuhaterriverinn!exrecuhaterriverinn@exrecuhaterriverinn.tmi.twitch.tv PRIVMSG #recuerd0p :k locurote primiseleeee
# :elijah_samu!elijah_samu@elijah_samu.tmi.twitch.tv PRIVMSG #baiano :Vamos voltar pros desenhos
# Joined: gotsukishima (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gotsukishima
# Joined: stray_whitecat_ (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #stray_whitecat_
# Joined: amal_3rd (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :lanhild!lanhild@lanhild.tmi.twitch.tv PRIVMSG #traytonlol :@SVKurama vrai
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #amal_3rd
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #amal_3rd :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #amal_3rd :End of /NAMES list
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #m2_kento_heluan :配信の切り抜き動画はYoutubeで！https://www.youtube.com/channel/UCt8xPNGuJ1N6n5xmprZceYw?view_as=subscriber
# Joined: amauta_sau (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :puwawaaa!puwawaaa@puwawaaa.tmi.twitch.tv PRIVMSG #m2_kento_heluan :www
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #amauta_sau
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #amauta_sau :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #amauta_sau :End of /NAMES list
# :mameshiba048!mameshiba048@mameshiba048.tmi.twitch.tv PRIVMSG #amauta_sau :直った
# Joined: yaicin_heros (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :zegwtf!zegwtf@zegwtf.tmi.twitch.tv PRIVMSG #sphinx :222
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #yaicin_heros
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #yaicin_heros :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #yaicin_heros :End of /NAMES list
# Joined: foxrabbit (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :ihasatypo!ihasatypo@ihasatypo.tmi.twitch.tv PRIVMSG #ranger :you mean some streamers are losing rangers game
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #foxrabbit
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #foxrabbit :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #foxrabbit :End of /NAMES list
# Joined: solionzi (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #solionzi
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #solionzi :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #solionzi :End of /NAMES list
# :bababiru!bababiru@bababiru.tmi.twitch.tv PRIVMSG #iwdominate :power move
# :hapi7!hapi7@hapi7.tmi.twitch.tv PRIVMSG #iwdominate :the grey box at the bottom calling for jomash resignation has me dead
# :99samar!99samar@99samar.tmi.twitch.tv PRIVMSG #landstop :цирк уродов 😁😁😁
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #oatley :Legend!
# Joined: ajikichi (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ajikichi
# Joined: khira_stb (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #khira_stb
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #khira_stb :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #khira_stb :End of /NAMES list
# Joined: judyconsz (Game: Grand Theft Auto V)
# Joined: curvyelephant (Game: Grand Theft Auto V)
# Joined: itgirl (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #itgirl
# Joined: sypherpk (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sypherpk
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #sypherpk :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #sypherpk :End of /NAMES list
# :wizebot!wizebot@wizebot.tmi.twitch.tv PRIVMSG #strey_lol :ACTION ⭐️ NEW SUB ⭐️ Lchamois (+13) ⭐️
# Joined: loeya (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #loeya
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #loeya :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #loeya :End of /NAMES list
# :micro1000!micro1000@micro1000.tmi.twitch.tv PRIVMSG #united21_en :Е че кубиксы так против коно не камбекали?
# :una_nemumi!una_nemumi@una_nemumi.tmi.twitch.tv PRIVMSG #m2_kento_heluan :m2kentKusa
# Joined: oatley (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #oatley
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #oatley :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #oatley :End of /NAMES list
# Joined: ache (Game: Fortnite)
# ✅ 加入频道确认: :nlpeye123!nlpeye123@nlpeye123.tmi.twitch.tv PRIVMSG #guanweiboy :我最恨的
# :zalmost2023!zalmost2023@zalmost2023.tmi.twitch.tv PRIVMSG #guanweiboy :!運勢
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ache
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #ache :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #ache :End of /NAMES list
# Joined: upol0 (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #upol0
# Joined: katoo (Game: Fortnite)
# ✅ 加入频道确认: :lafibredetartine!lafibredetartine@lafibredetartine.tmi.twitch.tv PRIVMSG #gobgg :bonjour gob on pourra !JOIN aujourd'hui ou pas ?
# ✅ 加入频道确认: :mamapro456!mamapro456@mamapro456.tmi.twitch.tv PRIVMSG #ranger :bless you
# :monomi_nemuru!monomi_nemuru@monomi_nemuru.tmi.twitch.tv PRIVMSG #syaruru3 :J4も今かなり上がってきてる
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #katoo
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #katoo :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #katoo :End of /NAMES list
# Joined: msomp1 (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #msomp1
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #msomp1 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #msomp1 :End of /NAMES list
# Joined: recuerd0p (Game: Fortnite)
# ✅ 加入频道确认: :marz37!marz37@marz37.tmi.twitch.tv PRIVMSG #sphinx :yoooooooooooo
# :straatuss!straatuss@straatuss.tmi.twitch.tv PRIVMSG #strey_lol :LEZGGOOO LARC COREE
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #recuerd0p
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #recuerd0p :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #recuerd0p :End of /NAMES list
# Joined: heystan (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #heystan
# Joined: mrlust (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #mrlust
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #mrlust :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #mrlust :End of /NAMES list
# :krutoy_pampers1337!krutoy_pampers1337@krutoy_pampers1337.tmi.twitch.tv PRIVMSG #hypetried :@sano_mandj1ro ну как будто похуй
# Joined: levilaingarc0n (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #levilaingarc0n
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #levilaingarc0n :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #levilaingarc0n :End of /NAMES list
# Joined: sphinx (Game: Fortnite)
# ✅ 加入频道确认: :grandgueux!grandgueux@grandgueux.tmi.twitch.tv PRIVMSG #chap_gg :GP GP GP GP GP
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sphinx
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #sphinx :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #sphinx :End of /NAMES list
# Joined: xiuder_ (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #xiuder_
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #xiuder_ :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #xiuder_ :End of /NAMES list
# ✅ Write into BigQuery 1000  rows
# Joined: enylast (Game: Fortnite)
# ✅ 加入频道确认: :shrimproll322_mr_mycop!shrimproll322_mr_mycop@shrimproll322_mr_mycop.tmi.twitch.tv PRIVMSG #hypetried :!viewmodel
# :marz37!marz37@marz37.tmi.twitch.tv PRIVMSG #sphinx :11111111
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #enylast
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #enylast :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #enylast :End of /NAMES list
# Joined: stizo_ (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #stizo_
# Joined: jiozi (Game: Fortnite)
# ✅ 加入频道确认: :apachii___!apachii___@apachii___.tmi.twitch.tv PRIVMSG #sphinx :111111111
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jiozi
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #jiozi :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #jiozi :End of /NAMES list
# Joined: ranger (Game: Fortnite)
# ✅ 加入频道确认: :kikori_ossan!kikori_ossan@kikori_ossan.tmi.twitch.tv PRIVMSG #pira_real :えぐいえぐいｗｗｗｗｗ
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ranger
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #ranger :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #ranger :End of /NAMES list
# Joined: abstaau (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #abstaau
# Joined: ops1x (Game: Fortnite)
# Joined: kieskauer (Game: Fortnite)
# Joined: iwdominate (Game: League of Legends)
# ✅ 加入频道确认: :stan777!stan777@stan777.tmi.twitch.tv PRIVMSG #qrushcsgo :А че плакать?
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #iwdominate
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #iwdominate :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #iwdominate :End of /NAMES list
# Joined: broxah (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #broxah
# Joined: lplenglish (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #lplenglish
# Joined: traytonlol (Game: League of Legends)
# ✅ 加入频道确认: :ilaypaez!ilaypaez@ilaypaez.tmi.twitch.tv PRIVMSG #boooe :Martín tronco
# :kokonobi2525!kokonobi2525@kokonobi2525.tmi.twitch.tv PRIVMSG #pira_real :どんだけ金もってたんだｗｗｗ
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #traytonlol
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #traytonlol :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #traytonlol :End of /NAMES list
# Joined: crownie_lol (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #crownie_lol
# Joined: midbeast (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #midbeast
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #midbeast :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #midbeast :End of /NAMES list
# Joined: agurin (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #agurin
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #agurin :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #agurin :End of /NAMES list
# :creedzz_!creedzz_@creedzz_.tmi.twitch.tv PRIVMSG #autophil :null komma neun
# Joined: baiano (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #baiano
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #baiano :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #baiano :End of /NAMES list
# Joined: syaruru3 (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #syaruru3
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #syaruru3 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #syaruru3 :End of /NAMES list
# :shunrai963!shunrai963@shunrai963.tmi.twitch.tv PRIVMSG #middleeetv :ごにょごにょ
# :chaccha85!chaccha85@chaccha85.tmi.twitch.tv PRIVMSG #middleeetv :ラ？ジ？オ？
# Joined: strey_lol (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #strey_lol
# Joined: nitenightkid (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #nitenightkid
# Joined: autophil (Game: League of Legends)
# ✅ 加入频道确认: :jp144hz!jp144hz@jp144hz.tmi.twitch.tv PRIVMSG #clovaobengala :vc q sabe
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #autophil
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #autophil :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #autophil :End of /NAMES list
# :candyoverdose_!candyoverdose_@candyoverdose_.tmi.twitch.tv PRIVMSG #iwdominate :I mean tell that to Nico Harrison xdd
# :leablo!leablo@leablo.tmi.twitch.tv PRIVMSG #broxah :@SlenddermanR personally won 1 game lost 2 against kindred but i think it depends how good you can play the champ
# Joined: guanweiboy (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #guanweiboy
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #guanweiboy :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #guanweiboy :End of /NAMES list
# :moobot!moobot@moobot.tmi.twitch.tv PRIVMSG #gobgg :Je suis officiellement partenaire Corsair ! gobDab si vous voulez des périphériques de BG (claviers, casques, tapis...) Commandez sur le site : go.corsair.com/gobgg ! gobStonks (Si vous avez AdBlock, vous devez faire un copier-coller)
# :streamelements!streamelements@streamelements.tmi.twitch.tv PRIVMSG #gobgg :Salut FedochStick !
# Joined: martinmartin_m2x (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #martinmartin_m2x
# Joined: chap_gg (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #chap_gg
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #chap_gg :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #chap_gg :End of /NAMES list
# Joined: sixentv (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sixentv
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #sixentv :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #sixentv :End of /NAMES list
# :angelo2096yt!angelo2096yt@angelo2096yt.tmi.twitch.tv PRIVMSG #xiuder_ :ma dove state che avete il sole?
# Joined: clovaobengala (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #clovaobengala
# Joined: pcstw (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #pcstw
# Joined: gobgg (Game: League of Legends)
# ✅ 加入频道确认: :mendessxsx!mendessxsx@mendessxsx.tmi.twitch.tv PRIVMSG #locking :valeuuuuu
# :leosorre!leosorre@leosorre.tmi.twitch.tv PRIVMSG #xiuder_ :la giochi solo, questi la fregano
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gobgg
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #gobgg :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #gobgg :End of /NAMES list
# Joined: rybsonlol_ (Game: League of Legends)
# Joined: m3wsu (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #m3wsu
# Joined: theburntpeanut (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #theburntpeanut
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #theburntpeanut :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #theburntpeanut :End of /NAMES list
# Joined: hypetried (Game: Counter-Strike)
# ✅ 加入频道确认: :pixy_rain!pixy_rain@pixy_rain.tmi.twitch.tv PRIVMSG #kiruma_ch :あーなるほどねw
# :gouwyak!gouwyak@gouwyak.tmi.twitch.tv PRIVMSG #strey_lol :AAAAAA
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #hypetried
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #hypetried :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #hypetried :End of /NAMES list
# Joined: qrushcsgo (Game: Counter-Strike)
# ✅ 加入频道确认: :quis1dde!quis1dde@quis1dde.tmi.twitch.tv PRIVMSG #hypetried :!crosshair
# :asashinsa!asashinsa@asashinsa.tmi.twitch.tv PRIVMSG #amauta_sau :ｗ押しすぎてるのかｗ
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #qrushcsgo
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #qrushcsgo :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #qrushcsgo :End of /NAMES list
# :alanainmymind!alanainmymind@alanainmymind.tmi.twitch.tv PRIVMSG #sypherpk :oh Yea
# :jahsoonn!jahsoonn@jahsoonn.tmi.twitch.tv PRIVMSG #oatley :L ad
# Joined: united21_en (Game: Counter-Strike)
# ✅ 加入频道确认: :deathfv_!deathfv_@deathfv_.tmi.twitch.tv PRIVMSG #abstaau :L late reaction
# :host2s!host2s@host2s.tmi.twitch.tv PRIVMSG #iwdominate :Joever
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #united21_en
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #united21_en :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #united21_en :End of /NAMES list
# :deathfv_!deathfv_@deathfv_.tmi.twitch.tv PRIVMSG #abstaau :L late reaction
# Joined: szelioficjalnie (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #szelioficjalnie
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #szelioficjalnie :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #szelioficjalnie :End of /NAMES list
# :alka00asobi!alka00asobi@alka00asobi.tmi.twitch.tv PRIVMSG #m2_kento_heluan :w
# Joined: margenalez (Game: Counter-Strike)
# Joined: gaules (Game: Counter-Strike)
# ✅ 加入频道确认: :lonelyl1on!lonelyl1on@lonelyl1on.tmi.twitch.tv PRIVMSG #m3wsu :Я у руля
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gaules
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #gaules :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #gaules :End of /NAMES list
# :haris4x!haris4x@haris4x.tmi.twitch.tv PRIVMSG #abstaau :L LATE REACTION
# Joined: c0baka_kycaka (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #c0baka_kycaka
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #c0baka_kycaka :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #c0baka_kycaka :End of /NAMES list
# Joined: pokanoname (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #pokanoname
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #pokanoname :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #pokanoname :End of /NAMES list
# :hulk19957!hulk19957@hulk19957.tmi.twitch.tv PRIVMSG #guanweiboy :cmonBruh cmonBruh cmonBruh
# :harunoaa!harunoaa@harunoaa.tmi.twitch.tv PRIVMSG #solionzi :ww
# Joined: locking (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #locking
# Joined: kotehok_gaf (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kotehok_gaf
# Joined: get_right (Game: Counter-Strike)
# ✅ 加入频道确认: :giufzn!giufzn@giufzn.tmi.twitch.tv PRIVMSG #baiano :tu coloca o pagode pra arruma as carnes, as breja
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #get_right
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #get_right :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #get_right :End of /NAMES list
# ✅ Write into BigQuery 1000  rows
# Joined: landstop (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #landstop
# Joined: eslcs (Game: Counter-Strike)
# ✅ 加入频道确认: :gwa_0401!gwa_0401@gwa_0401.tmi.twitch.tv PRIVMSG #guanweiboy :用搶的算工作嗎？
# :zilchiz!zilchiz@zilchiz.tmi.twitch.tv PRIVMSG #syaruru3 :えら
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #eslcs
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #eslcs :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #eslcs :End of /NAMES list
# Joined: shhhifu (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #shhhifu
# Joined: zonixxcs (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #zonixxcs
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #zonixxcs :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #zonixxcs :End of /NAMES list
# Joined: fpssssssssssssssssssss (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fpssssssssssssssssssss
# Joined: nikimbo69 (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #nikimbo69
# Joined: fantazer_da (Game: Counter-Strike)
# Joined: skyte (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #skyte
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #skyte :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #skyte :End of /NAMES list
# Joined: senvale (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #senvale
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #senvale :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #senvale :End of /NAMES list
# Joined: thegodlynoob (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #thegodlynoob
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #thegodlynoob :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #thegodlynoob :End of /NAMES list
# :schwarzrose123!schwarzrose123@schwarzrose123.tmi.twitch.tv PRIVMSG #pcstw :@lfishl WP不是贏˙了嗎
# :kakashkagovnashka!kakashkagovnashka@kakashkagovnashka.tmi.twitch.tv PRIVMSG #hypetried :SabaPing SabaPing SabaPing SabaPing SabaPing SabaPing
# Joined: masamitzu (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #masamitzu
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #masamitzu :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #masamitzu :End of /NAMES list
# Joined: fastanne (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fastanne
# Joined: sha77etv (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sha77etv
# Joined: jynxziofflines_ (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jynxziofflines_
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #jynxziofflines_ :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #jynxziofflines_ :End of /NAMES list
# :maruko0613!maruko0613@maruko0613.tmi.twitch.tv PRIVMSG #pira_real :くじや
# Joined: jynxzioffline_ (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jynxzioffline_
# Joined: airhead022 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :ember01119!ember01119@ember01119.tmi.twitch.tv PRIVMSG #loeya :holo might get remove in a hotfix
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #airhead022
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #airhead022 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #airhead022 :End of /NAMES list
# ✅ 加入频道确认: :not_sarthak02!not_sarthak02@not_sarthak02.tmi.twitch.tv PRIVMSG #oatley :lol
# :jeffs_balls!jeffs_balls@jeffs_balls.tmi.twitch.tv PRIVMSG #oatley :OATLEY JOIN PWR OR A POPULAR ORG SO YOU GET ATTENTION FROM OTHER PEOPLE
# Joined: kinggeorgeoffline (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kinggeorgeoffline
# Joined: vetelcito01 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #vetelcito01
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #vetelcito01 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #vetelcito01 :End of /NAMES list
# Joined: s9eem (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #s9eem
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #s9eem :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #s9eem :End of /NAMES list
# Joined: badrookie_1977 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #badrookie_1977
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #badrookie_1977 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #badrookie_1977 :End of /NAMES list
# :donatelo_18!donatelo_18@donatelo_18.tmi.twitch.tv PRIVMSG #vetelcito01 :A mi el único Assasin que se me hizo una basura fue el Walhalla
# Joined: boooe (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #boooe
# Joined: cateye222 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #cateye222
# Joined: proxima (Game: Tom Clancy's Rainbow Six Siege)
# Joined: bravenika (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #bravenika
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #bravenika :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #bravenika :End of /NAMES list
# Joined: pascal0_4 (Game: Tom Clancy's Rainbow Six Siege)
# Joined: jmalttr (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :jieee77777!jieee77777@jieee77777.tmi.twitch.tv PRIVMSG #guanweiboy :cmonBruh cmonBruh cmonBruh cmonBruh
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jmalttr
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #jmalttr :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #jmalttr :End of /NAMES list
# Joined: fps__saku (Game: Apex Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fps__saku
# Joined: taxi2g (Game: Apex Legends)
# Joined: taaaao (Game: Apex Legends)
# Joined: gdolphn (Game: Apex Legends)
# Joined: dami_la (Game: Apex Legends)
# Joined: taidaaaa_ (Game: Apex Legends)
# Joined: curihara0807 (Game: Apex Legends)
# Joined: ranches (Game: Apex Legends)
# Joined: lace (Game: Apex Legends)
# Joined: pinotr_ (Game: Apex Legends)
# ✅ 加入频道确认: :alexander52233!alexander52233@alexander52233.tmi.twitch.tv PRIVMSG #united21_en :Лел мих не когда не закроют карту. Поверьте
# :jeffs_balls!jeffs_balls@jeffs_balls.tmi.twitch.tv PRIVMSG #oatley :OATLEY JOIN PWR OR A POPULAR ORG SO YOU GET ATTENTION FROM OTHER PEOPLE
# Joined: ndodgee (Game: Apex Legends)
# Joined: saxzu (Game: Apex Legends)
# Joined: hiswattson247 (Game: Apex Legends)
# Joined: irene28___ (Game: Apex Legends)
# ✅ Write into BigQuery 1000  rows
# Joined: shoooter_daddy (Game: Apex Legends)
# Joined: gprodaisuki (Game: Apex Legends)
# Joined: zakatix (Game: Apex Legends)
# Joined: gospojaaaa (Game: Apex Legends)
# Joined: moonzinha (Game: Apex Legends)
# Joined: oniyadayo (Game: VALORANT)
# Joined: prod (Game: VALORANT)
# Joined: vodkavdk (Game: VALORANT)
# Joined: yohdazo (Game: VALORANT)
# Joined: cr_rion (Game: VALORANT)
# Joined: 9qoq (Game: VALORANT)
# Joined: kanpeki (Game: VALORANT)
# Joined: rax1337 (Game: VALORANT)
# Joined: im_mittiii (Game: VALORANT)
# Joined: ade3_3 (Game: VALORANT)
# Joined: dethseiya (Game: VALORANT)
# Joined: yuseafn (Game: VALORANT)
# Joined: akash1vl (Game: VALORANT)
# Joined: b0rja (Game: VALORANT)
# Joined: harmii (Game: VALORANT)
# Joined: kntsy (Game: VALORANT)
# Joined: danikongi (Game: VALORANT)
# Joined: unfair (Game: VALORANT)
# Joined: garnets__ (Game: VALORANT)
# Joined: ragevl_ (Game: VALORANT)
# Joined: tonton (Game: Assassin's Creed Shadows)
# Joined: grimmmz (Game: Assassin's Creed Shadows)
# Joined: singsing (Game: Assassin's Creed Shadows)
# Joined: deadp47_ (Game: Assassin's Creed Shadows)
# Joined: teawithmandy (Game: Assassin's Creed Shadows)
# Joined: doomedmeter (Game: Assassin's Creed Shadows)
# Joined: ilgattosultubo (Game: Assassin's Creed Shadows)
# Joined: bajo (Game: Assassin's Creed Shadows)
# Joined: lilykonjo (Game: Assassin's Creed Shadows)
# Joined: raptor (Game: Assassin's Creed Shadows)
# Joined: ten_wong (Game: Assassin's Creed Shadows)
# Joined: fuzhpuzy (Game: Assassin's Creed Shadows)
# Joined: jtaz (Game: Assassin's Creed Shadows)
# Joined: neelana (Game: Assassin's Creed Shadows)
# ✅ Write into BigQuery 1000  rows
# Joined: mirageeputo_ (Game: Assassin's Creed Shadows)
# Joined: deadfox15 (Game: Assassin's Creed Shadows)
# Joined: lusorkoeffizient (Game: Assassin's Creed Shadows)
# Joined: paranoidpixi3_za (Game: Assassin's Creed Shadows)
# Joined: aiola (Game: Assassin's Creed Shadows)
# Joined: gtimetv (Game: Assassin's Creed Shadows)
# Joined: dokibird (Game: Marvel Rivals)
# Joined: sinatraavod (Game: Marvel Rivals)
# Joined: ratirl (Game: Marvel Rivals)
# Joined: timthetatmanvods (Game: Marvel Rivals)
# Joined: gale (Game: Marvel Rivals)
# Joined: kalei (Game: Marvel Rivals)
# Joined: marvelrivals (Game: Marvel Rivals)
# Joined: ariasaki (Game: Marvel Rivals)
# Joined: guru (Game: Marvel Rivals)
# Joined: minicake (Game: Marvel Rivals)
# Joined: agbin3r (Game: Marvel Rivals)
# Joined: andr3wow (Game: Marvel Rivals)
# Joined: slater (Game: Marvel Rivals)
# Joined: dropped (Game: Marvel Rivals)
# Joined: zondalol (Game: Marvel Rivals)
# Joined: aceofspades (Game: Marvel Rivals)
# Joined: fazesway (Game: Marvel Rivals)
# Joined: i__ate (Game: Marvel Rivals)
# Joined: luka (Game: Marvel Rivals)
# Joined: louikey (Game: Marvel Rivals)
# ✅ Write into BigQuery 1000  rows
# Joined: kiruma_ch (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kiruma_ch
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #kiruma_ch :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #kiruma_ch :End of /NAMES list
# Joined: pira_real (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #pira_real
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #pira_real :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #pira_real :End of /NAMES list
# Joined: middleeetv (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :matematicolr!matematicolr@matematicolr.tmi.twitch.tv PRIVMSG #baiano :@kayky_kunn bomdia
# :dailybuh!dailybuh@dailybuh.tmi.twitch.tv PRIVMSG #iwdominate :from 0-100 instantly KEKW
# :discofrogn!discofrogn@discofrogn.tmi.twitch.tv PRIVMSG #autophil :Ich bin halt sehr alt, meine ICQ-Nummer kenne ich nicht mehr, im Abi wurde das dann langsam nicht mehr genutzt
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #middleeetv
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #middleeetv :danieljia36
# ...
# :danieljia36.tmi.twitch.tv 366 danieljia36 #rarri :End of /NAMES list
# Joined: amauta_sau (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #amauta_sau
# Joined: dedadam (Game: Grand Theft Auto V)
# ✅ Write into BigQuery 1000  rows
# Joined: curvyelephant (Game: Grand Theft Auto V)
# Joined: solionzi (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #solionzi
# Joined: jerzy (Game: Grand Theft Auto V)
# Joined: stray_whitecat_ (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #stray_whitecat_
# Joined: gotsukishima (Game: Grand Theft Auto V)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gotsukishima
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #gotsukishima :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #gotsukishima :End of /NAMES list
# :motibe105!motibe105@motibe105.tmi.twitch.tv PRIVMSG #pira_real :うっまw
# Joined: loeya (Game: Fortnite)
# ✅ 加入频道确认: :lavilainenonoshe!lavilainenonoshe@lavilainenonoshe.tmi.twitch.tv PRIVMSG #levilaingarc0n :@jadouuprm peut être parce que t’es malpoli 🤷🏼‍♀️
# :hdmkarma!hdmkarma@hdmkarma.tmi.twitch.tv PRIVMSG #sixentv :salut à tous , on en parle de la phase d'invu de naafiri , ça me trigger chaque fois que je la vois sur ce patch
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #loeya
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #loeya :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #loeya :End of /NAMES list
# Joined: nickeh30 (Game: Fortnite)
# Joined: oatley (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #oatley
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #oatley :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #oatley :End of /NAMES list
# :notseynd!notseynd@notseynd.tmi.twitch.tv PRIVMSG #agurin :!dndnews
# Joined: ache (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #ache
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #ache :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #ache :End of /NAMES list
# Joined: upol0 (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #upol0
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #upol0 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #upol0 :End of /NAMES list
# Joined: katoo (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #katoo
# Joined: recuerd0p (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #recuerd0p
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #recuerd0p :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #recuerd0p :End of /NAMES list
# :messmo_88!messmo_88@messmo_88.tmi.twitch.tv PRIVMSG #oatley :!lb
# Joined: msomp1 (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #msomp1
# Joined: levilaingarc0n (Game: Fortnite)
# ✅ 加入频道确认: :redragnar!redragnar@redragnar.tmi.twitch.tv PRIVMSG #traytonlol :@CanHypeE jcrois ta pas regardé le first stnad
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #levilaingarc0n
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #levilaingarc0n :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #levilaingarc0n :End of /NAMES list
# Joined: mrlust (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #mrlust
# Joined: heystan (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #heystan
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #heystan :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #heystan :End of /NAMES list
# Joined: xiuder_ (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #xiuder_
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #xiuder_ :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #xiuder_ :End of /NAMES list
# Joined: chrizzyy (Game: Fortnite)
# Joined: imforeigndee (Game: Fortnite)
# Joined: building (Game: Fortnite)
# Joined: volx (Game: Fortnite)
# Joined: raskology (Game: Fortnite)
# Joined: stizo_ (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #stizo_
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #stizo_ :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #stizo_ :End of /NAMES list
# :gite556!gite556@gite556.tmi.twitch.tv PRIVMSG #pira_real :これ曲めっちゃちゃんとしてるのに動画のサムネがきついんだよな
# Joined: smacko (Game: Fortnite)
# Joined: peterbot247official (Game: Fortnite)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #peterbot247official
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #peterbot247official :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #peterbot247official :End of /NAMES list
# Joined: iwdominate (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #iwdominate
# Joined: lplenglish (Game: League of Legends)
# ✅ 加入频道确认: :sashaa___1!sashaa___1@sashaa___1.tmi.twitch.tv PRIVMSG #get_right :so many cheaters
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #lplenglish
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #lplenglish :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #lplenglish :End of /NAMES list
# Joined: traytonlol (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #traytonlol
# Joined: crownie_lol (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #crownie_lol
# Joined: baiano (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #baiano
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #baiano :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #baiano :End of /NAMES list
# Joined: strey_lol (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #strey_lol
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #strey_lol :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #strey_lol :End of /NAMES list
# Joined: broxah (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #broxah
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #broxah :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #broxah :End of /NAMES list
# :crazysaingah!crazysaingah@crazysaingah.tmi.twitch.tv PRIVMSG #xiuder_ :diventa papà?!
# Joined: guanweiboy (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #guanweiboy
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #guanweiboy :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #guanweiboy :End of /NAMES list
# :seqxyy!seqxyy@seqxyy.tmi.twitch.tv PRIVMSG #iwdominate :a b*tch
# Joined: agurin (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #agurin
# Joined: syaruru3 (Game: League of Legends)
# ✅ 加入频道确认: :akanomars!akanomars@akanomars.tmi.twitch.tv PRIVMSG #strey_lol :@Djemppp pour un ex plat en vrai si, surtout vu l'action sur le talon et la madro en général
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #syaruru3
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #syaruru3 :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #syaruru3 :End of /NAMES list
# Joined: chap_gg (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #chap_gg
# Joined: sixentv (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #sixentv
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #sixentv :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #sixentv :End of /NAMES list
# Joined: yoda (Game: League of Legends)
# Joined: splinter (Game: League of Legends)
# Joined: rybsonlol_ (Game: League of Legends)
# Joined: gobgg (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gobgg
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #gobgg :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #gobgg :End of /NAMES list
# :m1vr4ge!m1vr4ge@m1vr4ge.tmi.twitch.tv PRIVMSG #fpssssssssssssssssssss :у меня вот у самого был 2546к, а сейчас 2586х и я кайфую
# :xlayna!xlayna@xlayna.tmi.twitch.tv PRIVMSG #oatley :@baggysta it hasn't been hotfix time yet
# Joined: nitenightkid (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #nitenightkid
# Joined: autophil (Game: League of Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #autophil
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #autophil :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #autophil :End of /NAMES list
# :aozora112455!aozora112455@aozora112455.tmi.twitch.tv PRIVMSG #middleeetv :上手い
# Joined: humzh (Game: League of Legends)
# Joined: karni (Game: League of Legends)
# Joined: hypetried (Game: Counter-Strike)
# ✅ 加入频道确认: :bizonxxx!bizonxxx@bizonxxx.tmi.twitch.tv PRIVMSG #iwdominate :unc is bringing up topics himself
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #hypetried
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #hypetried :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #hypetried :End of /NAMES list
# Joined: rachelr (Game: Counter-Strike)
# Joined: united21_en (Game: Counter-Strike)
# ✅ 加入频道确认: :hockshaw!hockshaw@hockshaw.tmi.twitch.tv PRIVMSG #chap_gg :je l'ai utilisé il marchait très bien pourtant :/
# :skilllzyy!skilllzyy@skilllzyy.tmi.twitch.tv PRIVMSG #theburntpeanut :you're a good man ... you're a good man @ivoidsouls
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #united21_en
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #united21_en :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #united21_en :End of /NAMES list
# :enoch995!enoch995@enoch995.tmi.twitch.tv PRIVMSG #guanweiboy :上路虐線要輸
# Joined: szelioficjalnie (Game: Counter-Strike)
# ✅ 加入频道确认: :saura_s!saura_s@saura_s.tmi.twitch.tv PRIVMSG #darkzelk :終わってる二人組w
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #szelioficjalnie
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #szelioficjalnie :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #szelioficjalnie :End of /NAMES list
# :eyeshield___!eyeshield___@eyeshield___.tmi.twitch.tv PRIVMSG #traytonlol :LE GOAT
# Joined: pokanoname (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #pokanoname
# Joined: gaules (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #gaules
# Joined: get_right (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #get_right
# Joined: shoxiejesuss (Game: Counter-Strike)
# ✅ Write into BigQuery 1000  rows
# Joined: del1ght (Game: Counter-Strike)
# Joined: eslcs (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #eslcs
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #eslcs :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #eslcs :End of /NAMES list
# Joined: kotehok_gaf (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kotehok_gaf
# Joined: c0baka_kycaka (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #c0baka_kycaka
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #c0baka_kycaka :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #c0baka_kycaka :End of /NAMES list
# Joined: fpssssssssssssssssssss (Game: Counter-Strike)
# ✅ 加入频道确认: :fianso49000!fianso49000@fianso49000.tmi.twitch.tv PRIVMSG #stizo_ :ramadan>pate bolo
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fpssssssssssssssssssss
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #fpssssssssssssssssssss :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #fpssssssssssssssssssss :End of /NAMES list
# Joined: rndboy (Game: Counter-Strike)
# Joined: landstop (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #landstop
# Joined: toaststix (Game: Counter-Strike)
# Joined: zonixxcs (Game: Counter-Strike)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #zonixxcs
# Joined: hasty4 (Game: Counter-Strike)
# Joined: wabiiisabii (Game: Counter-Strike)
# Joined: 7tyyan (Game: Counter-Strike)
# Joined: skyte (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #skyte
# Joined: thegodlynoob (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danz75!danz75@danz75.tmi.twitch.tv PRIVMSG #crownie_lol :cuh Stab buh
# :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #thegodlynoob
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #thegodlynoob :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #thegodlynoob :End of /NAMES list
# Joined: fastanne (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fastanne
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #fastanne :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #fastanne :End of /NAMES list
# Joined: senvale (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #senvale
# Joined: masamitzu (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #masamitzu
# Joined: vetelcito01 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #vetelcito01
# Joined: wanted666_ (Game: Tom Clancy's Rainbow Six Siege)
# Joined: jynxzioffline_ (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jynxzioffline_
# Joined: jynxziofflines_ (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jynxziofflines_
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #jynxziofflines_ :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #jynxziofflines_ :End of /NAMES list
# :nightbot!nightbot@nightbot.tmi.twitch.tv PRIVMSG #peterbot247official :Be sure to follow me and get notifications!
# :ter51la!ter51la@ter51la.tmi.twitch.tv PRIVMSG #landstop :Всем привет
# Joined: proxima (Game: Tom Clancy's Rainbow Six Siege)
# Joined: kinggeorgeoffline (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #kinggeorgeoffline
# Joined: airhead022 (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #airhead022
# Joined: pascal0_4 (Game: Tom Clancy's Rainbow Six Siege)
# Joined: enemyn1 (Game: Tom Clancy's Rainbow Six Siege)
# Joined: valkja (Game: Tom Clancy's Rainbow Six Siege)
# Joined: natasa02 (Game: Tom Clancy's Rainbow Six Siege)
# Joined: scorcheddarrin (Game: Tom Clancy's Rainbow Six Siege)
# Joined: jmalttr (Game: Tom Clancy's Rainbow Six Siege)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #jmalttr
# :danieljia36.tmi.twitch.tv 353 danieljia36 = #jmalttr :danieljia36
# :danieljia36.tmi.twitch.tv 366 danieljia36 #jmalttr :End of /NAMES list
# Joined: apppplegaming (Game: Tom Clancy's Rainbow Six Siege)
# Joined: ruten_uho (Game: Tom Clancy's Rainbow Six Siege)
# Joined: fps__saku (Game: Apex Legends)
# ✅ 加入频道确认: :danieljia36!danieljia36@danieljia36.tmi.twitch.tv JOIN #fps__saku
# Joined: taaaao (Game: Apex Legends)
# Joined: gdolphn (Game: Apex Legends)
# Joined: aoi_sakura3 (Game: Apex Legends)
# Joined: curihara0807 (Game: Apex Legends)
# Joined: taidaaaa_ (Game: Apex Legends)
# Joined: meltstera (Game: Apex Legends)
# Joined: hartly (Game: Apex Legends)
# Joined: pinotr_ (Game: Apex Legends)
# Joined: leamonhead (Game: Apex Legends)
# Joined: moonzinha (Game: Apex Legends)
# Joined: ttv_bolin (Game: Apex Legends)
# Joined: hiswattson247 (Game: Apex Legends)
# Joined: sudetakin (Game: Apex Legends)
# Joined: haltv (Game: Apex Legends)
# Joined: irene28___ (Game: Apex Legends)
# Joined: theexpiredbread (Game: Apex Legends)
# Joined: shoooter_daddy (Game: Apex Legends)
# Joined: gprodaisuki (Game: Apex Legends)
# Joined: miakhaleesi (Game: Apex Legends)
# Joined: cr_rion (Game: VALORANT)
# Joined: oniyadayo (Game: VALORANT)
# ✅ Write into BigQuery 1000  rows
# Joined: prod (Game: VALORANT)
# Joined: nats (Game: VALORANT)
# Joined: im_mittiii (Game: VALORANT)
# Joined: 9qoq (Game: VALORANT)
